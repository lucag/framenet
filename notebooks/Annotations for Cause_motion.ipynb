# %%
import xml.etree.ElementTree as et, os
import collections.abc       as abc
import pandas                as pd
import qgrid

from os.path                 import join
from framenet.util           import flatten, curry, flatmap, take
from framenet.builder        import build
from glob                    import iglob
from collections             import OrderedDict
from typing                  import Callable, List, Sequence
from multipledispatch        import dispatch
from framenet.util           import cata
from pprint                  import pformat, pprint
from framenet.ecg.generation import (root_for, base_for, Tree, T, 
                                     unstack, unstack_one, unstack_all,
                                     EtTree, TestTree as TT)

# For Pandas
pd.options.display.max_rows    = 99
pd.options.display.max_columns = 199

# tagify = lambda tag, item: '%sID' % tag if item == 'ID' else item

# The ICSI namespace we use below, as in 'fn:sentence'
fn = {'fn': 'http://framenet.icsi.berkeley.edu'}

lu10  = root_for['lu']('lu10')
asets = lu10.findall('.//fn:sentence', fn)

# %% [markdown]
# # Test: unstacking one XML file

# %%
# The ICSI namespace we use below, as in 'fn:sentence'
NS = {'fn': 'http://framenet.icsi.berkeley.edu'}

# This creates a loader for file 'lu10.xml' from the 'lu' folder 
lu10 = root_for['lu']('lu10')

# Find all <sentence ...> tags
lu10_sentences = lu10.findall('.//fn:sentence', fn)

lu10_df = pd.DataFrame(flatmap(unstack_one, asets))
# qgrid.nbinstall(overwrite=True)

# %%
qgrid.show_grid(lu10_df, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 100})

# %% [markdown]
# ## Now, let's define a function that does the above:
#
# Concretely, given an XML element, return a list of dictionaries. We need the list of dictionaries to finally create the `DataFrame` object.
#
# ### Algorithm:
#
# 1. Gather all the LU files by creating loaders for each one;
# 1. Extract the <sentence...> elements;
# 1. Apply the above to each one;
# 1. There's no 4!!!

# %%
from glob    import iglob 
from os.path import join

lu_roots = map(root_for['lu'], iglob(join(base_for['lu'], '*.xml')))
lu_sents = lambda: flatten(r.findall('.//fn:sentence', NS) for r in lu_roots)

ft_roots = map(root_for['fulltext'], iglob(join(base_for['fulltext'], '*.xml')))
ft_sents = lambda: flatten(r.findall('.//fn:sentence', NS) for r in ft_roots)

# %%
# Warning: this will take a long time. Only need to do this once!

LU_PICKLE = 'lu.pkl'

if os.access(LU_PICKLE, os.R_OK):
    # Read lu_df back in
    # %time lu_df = pd.read_pickle(LU_PICKLE)
else:
    # Save to a file in the current directory
    # %time lu_df = pd.DataFrame(list(unstack_all(lu_sents())))
    lu_df.to_pickle(LU_PICKLE)
# Out:
# CPU times: user 2.96 s, sys: 1.94 s, total: 4.91 s
# Wall time: 5.04 s

# %% [markdown]
# ## Let's do the same for the full text annotations

# %%
# Same as above
FT_PICKLE = 'fulltext.pkl'

if os.access(FT_PICKLE, os.R_OK):
    # Read lu_df back in
    # %time ft_df = pd.read_pickle(FT_PICKLE)
else:
    # Save to a file in the current directory
    # %time ft_df = pd.DataFrame(list(unstack_all(ft_sents())))
    ft_df.to_pickle(FT_PICKLE)
# Out:
# CPU times: user 317 ms, sys: 291 ms, total: 608 ms
# Wall time: 619 ms

# %% [markdown]
# ## TODO
#
# 1. function :: Frame -> Core FEs
# 1. Use them to select records

# %%
# Read FN data in 
# %time fn, fnb = build()
# Out:
# CPU times: user 31 µs, sys: 43 µs, total: 74 µs
# Wall time: 78.9 µs

# %%
# Load Cause_motion
Cause_motion   = fn.get_frame('Cause_motion')
cm_core_fe_ids = set(int(e.ID) for e in Cause_motion.elements if e.coreType == 'Core')
cm_nc_fe_ids   = set(int(e.ID) for e in Cause_motion.elements if e.coreType != 'Core')

# %%
# Test
assert len(Cause_motion.lexicalUnits) == 38
assert cm_core_fe_ids == {228, 229, 230, 231, 232, 234, 4991, 5532, 7031}

# %%
# LUs for Cause_motion
fnb.build_lus_for_frame('Cause_motion', fn)
# Out:
# These lexical units have already been built.

# %%
# Pick annotation IDs for Cause_motion
cm_aset_ids  = set(int(ann.ID) for ann in Cause_motion.annotations)
assert len(cm_aset_ids) == 823

# %% [markdown]
# ## Frame + ASet $\rightarrow$ DataFrame

# %%
from framenet.util import aget
from collections   import defaultdict

def lus_for(frame):
    "LUs for `frame` as a pd.DataFrame."
    cs = ('annotationSet.ID', 'annotationSet.LU')
    lu = aget('ID', 'lu')
    return pd.DataFrame([dict(zip(cs, lu(ann))) for ann in Cause_motion.annotations])
    

def select_by_annoset(df, aset_ids):
    return df.loc[df['annotationSet.ID'].isin(aset_ids)]

# %%
cm_df = select_by_annoset(lu_df, cm_aset_ids)

assert len(cm_df) == 10788

# %%
qgrid.show_grid(cm_df, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 100})

# %%
cm_plus_df = pd.merge(cm_df, lu_for_cm, how='outer', on='annotationSet.ID')

# %%
# Set layer.name to effective Target
cm_plus_df.loc[
    cm_plus_df['label.name'] == 'Target', 
    'label.name'
] = cm_plus_df['annotationSet.LU']

# %%
cm_plus_df
# Out:
#        annotationSet.ID annotationSet.status  label.end  label.feID  \
# 0               4530292               MANUAL      114.0         NaN
# 1               4530292               MANUAL      106.0       228.0
# 2               4530292               MANUAL      119.0       229.0
# 3               4530292               MANUAL      136.0       232.0
# 4               4530292               MANUAL      106.0         NaN
# 5               4530292               MANUAL      119.0         NaN
# 6               4530292               MANUAL      136.0         NaN
# 7               4530292               MANUAL      106.0         NaN
# 8               4530292               MANUAL      119.0         NaN
# 9               4530292               MANUAL      136.0         NaN
# 10              4530292               MANUAL        NaN         NaN
# 11              4530292               MANUAL        NaN         NaN
# 12              4530292               MANUAL        NaN         NaN
# 13              4530023               MANUAL       37.0         NaN
# 14              4530023               MANUAL       29.0      4991.0
# 15              4530023               MANUAL       44.0       229.0
# 16              4530023               MANUAL       60.0       232.0
# 17              4530023               MANUAL       29.0         NaN
# 18              4530023               MANUAL       44.0         NaN
# 19              4530023               MANUAL       60.0         NaN
# 20              4530023               MANUAL       29.0         NaN
# 21              4530023               MANUAL       44.0         NaN
# 22              4530023               MANUAL       60.0         NaN
# 23              4530023               MANUAL        NaN         NaN
# 24              4530023               MANUAL        NaN         NaN
# 25              4530023               MANUAL        NaN         NaN
# 26              4530024               MANUAL       59.0         NaN
# 27              4530024               MANUAL       45.0       229.0
# 28              4530024               MANUAL       81.0       232.0
# 29              4530024               MANUAL        NaN      4991.0
# 30              4530024               MANUAL       45.0         NaN
# 31              4530024               MANUAL       81.0         NaN
# 32              4530024               MANUAL       45.0         NaN
# 33              4530024               MANUAL       81.0         NaN
# 34              4530024               MANUAL        NaN         NaN
# 35              4530024               MANUAL        NaN         NaN
# 36              4530024               MANUAL        NaN         NaN
# 37              6536909               MANUAL       27.0         NaN
# 38              6536909               MANUAL        9.0       228.0
# 39              6536909               MANUAL       17.0       228.0
# 40              6536909               MANUAL       37.0       229.0
# 41              6536909               MANUAL       83.0       230.0
# 42              6536909               MANUAL        9.0         NaN
# 43              6536909               MANUAL       17.0         NaN
# 44              6536909               MANUAL       37.0         NaN
# 45              6536909               MANUAL       83.0         NaN
# 46              6536909               MANUAL        9.0         NaN
# 47              6536909               MANUAL       17.0         NaN
# 48              6536909               MANUAL       37.0         NaN
# ...                 ...                  ...        ...         ...
# 10739            659412               MANUAL        4.0         NaN
# 10740            659412               MANUAL       15.0         NaN
# 10741            659412               MANUAL       24.0         NaN
# 10742            659412               MANUAL        4.0         NaN
# 10743            659412               MANUAL       15.0         NaN
# 10744            659412               MANUAL       24.0         NaN
# 10745            659412               MANUAL        NaN         NaN
# 10746            659412               MANUAL        NaN         NaN
# 10747            659412               MANUAL       11.0         NaN
# 10748            659412               MANUAL        NaN         NaN
# 10749            659414               MANUAL        6.0       228.0
# 10750            659414               MANUAL       28.0       230.0
# 10751            659414               MANUAL       36.0       229.0
# 10752            659414               MANUAL        6.0         NaN
# 10753            659414               MANUAL       28.0         NaN
# 10754            659414               MANUAL       36.0         NaN
# 10755            659414               MANUAL        6.0         NaN
# 10756            659414               MANUAL       28.0         NaN
# 10757            659414               MANUAL       36.0         NaN
# 10758            659414               MANUAL        NaN         NaN
# 10759            659414               MANUAL        NaN         NaN
# 10760            659414               MANUAL       24.0         NaN
# 10761            659414               MANUAL        NaN         NaN
# 10762            659424               MANUAL        0.0       228.0
# 10763            659424               MANUAL       11.0       230.0
# 10764            659424               MANUAL       21.0       229.0
# 10765            659424               MANUAL        0.0         NaN
# 10766            659424               MANUAL       11.0         NaN
# 10767            659424               MANUAL       21.0         NaN
# 10768            659424               MANUAL        0.0         NaN
# 10769            659424               MANUAL       11.0         NaN
# 10770            659424               MANUAL       21.0         NaN
# 10771            659424               MANUAL        NaN         NaN
# 10772            659424               MANUAL        NaN         NaN
# 10773            659424               MANUAL        7.0         NaN
# 10774            659424               MANUAL        NaN         NaN
# 10775            659446               MANUAL        2.0       228.0
# 10776            659446               MANUAL       30.0      5532.0
# 10777            659446               MANUAL       75.0       229.0
# 10778            659446               MANUAL        2.0         NaN
# 10779            659446               MANUAL       30.0         NaN
# 10780            659446               MANUAL       75.0         NaN
# 10781            659446               MANUAL        2.0         NaN
# 10782            659446               MANUAL       30.0         NaN
# 10783            659446               MANUAL       75.0         NaN
# 10784            659446               MANUAL        NaN         NaN
# 10785            659446               MANUAL        NaN         NaN
# 10786            659446               MANUAL       25.0         NaN
# 10787            659446               MANUAL        NaN         NaN
#
#       label.itype label.name  label.start layer.name  layer.rank  sentence.ID  \
# 0             NaN    scoot.v        108.0    scoot.v           1      2824493
# 1             NaN      Agent        106.0         FE           1      2824493
# 2             NaN      Theme        116.0         FE           1      2824493
# 3             NaN       Goal        121.0         FE           1      2824493
# 4             NaN        Ext        106.0         GF           1      2824493
# 5             NaN        Obj        116.0         GF           1      2824493
# 6             NaN        Dep        121.0         GF           1      2824493
# 7             NaN         NP        106.0         PT           1      2824493
# 8             NaN         NP        116.0         PT           1      2824493
# 9             NaN         PP        121.0         PT           1      2824493
# 10            NaN        NaN          NaN      Other           1      2824493
# 11            NaN        NaN          NaN       Sent           1      2824493
# 12            NaN        NaN          NaN       Verb           1      2824493
# 13            NaN     draw.v         34.0     draw.v           1      2824245
# 14            NaN      Cause         25.0         FE           1      2824245
# 15            NaN      Theme         39.0         FE           1      2824245
# 16            NaN       Goal         46.0         FE           1      2824245
# 17            NaN        Ext         25.0         GF           1      2824245
# 18            NaN        Obj         39.0         GF           1      2824245
# 19            NaN        Dep         46.0         GF           1      2824245
# 20            NaN         NP         25.0         PT           1      2824245
# 21            NaN         NP         39.0         PT           1      2824245
# 22            NaN         PP         46.0         PT           1      2824245
# 23            NaN        NaN          NaN      Other           1      2824245
# 24            NaN        NaN          NaN       Sent           1      2824245
# 25            NaN        NaN          NaN       Verb           1      2824245
# 26            NaN     draw.v         55.0     draw.v           1      2824246
# 27            NaN      Theme         24.0         FE           1      2824246
# 28            NaN       Goal         61.0         FE           1      2824246
# 29            CNI      Cause          NaN         FE           1      2824246
# 30            NaN        Ext         24.0         GF           1      2824246
# 31            NaN        Dep         61.0         GF           1      2824246
# 32            NaN         NP         24.0         PT           1      2824246
# 33            NaN         PP         61.0         PT           1      2824246
# 34            NaN        NaN          NaN      Other           1      2824246
# 35            NaN        NaN          NaN       Sent           1      2824246
# 36            NaN        NaN          NaN       Verb           1      2824246
# 37            NaN     draw.v         23.0     draw.v           1      4099741
# 38            NaN      Agent          0.0         FE           1      4099741
# 39            NaN      Agent         13.0         FE           1      4099741
# 40            NaN      Theme         29.0         FE           1      4099741
# 41            NaN     Source         39.0         FE           1      4099741
# 42            NaN        Ext          0.0         GF           1      4099741
# 43            NaN        Ext         13.0         GF           1      4099741
# 44            NaN        Obj         29.0         GF           1      4099741
# 45            NaN        Dep         39.0         GF           1      4099741
# 46            NaN         NP          0.0         PT           1      4099741
# 47            NaN         NP         13.0         PT           1      4099741
# 48            NaN         NP         29.0         PT           1      4099741
# ...           ...        ...          ...        ...         ...          ...
# 10739         NaN        Ext          0.0         GF           1       588781
# 10740         NaN        Dep         13.0         GF           1       588781
# 10741         NaN        Obj         17.0         GF           1       588781
# 10742         NaN         NP          0.0         PT           1       588781
# 10743         NaN         PP         13.0         PT           1       588781
# 10744         NaN         NP         17.0         PT           1       588781
# 10745         NaN        NaN          NaN       Sent           1       588781
# 10746         NaN        NaN          NaN      Other           1       588781
# 10747         NaN     yank.v          6.0     yank.v           1       588781
# 10748         NaN        NaN          NaN       Verb           1       588781
# 10749         NaN      Agent          0.0         FE           1       588782
# 10750         NaN     Source         26.0         FE           1       588782
# 10751         NaN      Theme         30.0         FE           1       588782
# 10752         NaN        Ext          0.0         GF           1       588782
# 10753         NaN        Dep         26.0         GF           1       588782
# 10754         NaN        Obj         30.0         GF           1       588782
# 10755         NaN         NP          0.0         PT           1       588782
# 10756         NaN         PP         26.0         PT           1       588782
# 10757         NaN         NP         30.0         PT           1       588782
# 10758         NaN        NaN          NaN       Sent           1       588782
# 10759         NaN        NaN          NaN      Other           1       588782
# 10760         NaN     yank.v         19.0     yank.v           1       588782
# 10761         NaN        NaN          NaN       Verb           1       588782
# 10762         NaN      Agent          0.0         FE           1       588787
# 10763         NaN     Source          9.0         FE           1       588787
# 10764         NaN      Theme         13.0         FE           1       588787
# 10765         NaN        Ext          0.0         GF           1       588787
# 10766         NaN        Dep          9.0         GF           1       588787
# 10767         NaN        Obj         13.0         GF           1       588787
# 10768         NaN         NP          0.0         PT           1       588787
# 10769         NaN         PP          9.0         PT           1       588787
# 10770         NaN         NP         13.0         PT           1       588787
# 10771         NaN        NaN          NaN       Sent           1       588787
# 10772         NaN        NaN          NaN      Other           1       588787
# 10773         NaN     yank.v          2.0     yank.v           1       588787
# 10774         NaN        NaN          NaN       Verb           1       588787
# 10775         NaN      Agent          0.0         FE           1       588798
# 10776         NaN     Result         27.0         FE           1       588798
# 10777         NaN      Theme         32.0         FE           1       588798
# 10778         NaN        Ext          0.0         GF           1       588798
# 10779         NaN        Dep         27.0         GF           1       588798
# 10780         NaN        Obj         32.0         GF           1       588798
# 10781         NaN         NP          0.0         PT           1       588798
# 10782         NaN        AJP         27.0         PT           1       588798
# 10783         NaN         NP         32.0         PT           1       588798
# 10784         NaN        NaN          NaN       Sent           1       588798
# 10785         NaN        NaN          NaN      Other           1       588798
# 10786         NaN     yank.v         20.0     yank.v           1       588798
# 10787         NaN        NaN          NaN       Verb           1       588798
#
#        sentence.aPos  sentence.corpID  sentence.docID  sentence.paragNo  \
# 0                  0            115.0         23013.0              23.0
# 1                  0            115.0         23013.0              23.0
# 2                  0            115.0         23013.0              23.0
# 3                  0            115.0         23013.0              23.0
# 4                  0            115.0         23013.0              23.0
# 5                  0            115.0         23013.0              23.0
# 6                  0            115.0         23013.0              23.0
# 7                  0            115.0         23013.0              23.0
# 8                  0            115.0         23013.0              23.0
# 9                  0            115.0         23013.0              23.0
# 10                 0            115.0         23013.0              23.0
# 11                 0            115.0         23013.0              23.0
# 12                 0            115.0         23013.0              23.0
# 13                 0            115.0         23009.0              20.0
# 14                 0            115.0         23009.0              20.0
# 15                 0            115.0         23009.0              20.0
# 16                 0            115.0         23009.0              20.0
# 17                 0            115.0         23009.0              20.0
# 18                 0            115.0         23009.0              20.0
# 19                 0            115.0         23009.0              20.0
# 20                 0            115.0         23009.0              20.0
# 21                 0            115.0         23009.0              20.0
# 22                 0            115.0         23009.0              20.0
# 23                 0            115.0         23009.0              20.0
# 24                 0            115.0         23009.0              20.0
# 25                 0            115.0         23009.0              20.0
# 26                 0            115.0         23009.0              20.0
# 27                 0            115.0         23009.0              20.0
# 28                 0            115.0         23009.0              20.0
# 29                 0            115.0         23009.0              20.0
# 30                 0            115.0         23009.0              20.0
# 31                 0            115.0         23009.0              20.0
# 32                 0            115.0         23009.0              20.0
# 33                 0            115.0         23009.0              20.0
# 34                 0            115.0         23009.0              20.0
# 35                 0            115.0         23009.0              20.0
# 36                 0            115.0         23009.0              20.0
# 37                 0            135.0         23621.0               3.0
# 38                 0            135.0         23621.0               3.0
# 39                 0            135.0         23621.0               3.0
# 40                 0            135.0         23621.0               3.0
# 41                 0            135.0         23621.0               3.0
# 42                 0            135.0         23621.0               3.0
# 43                 0            135.0         23621.0               3.0
# 44                 0            135.0         23621.0               3.0
# 45                 0            135.0         23621.0               3.0
# 46                 0            135.0         23621.0               3.0
# 47                 0            135.0         23621.0               3.0
# 48                 0            135.0         23621.0               3.0
# ...              ...              ...             ...               ...
# 10739       15109000              NaN             NaN               NaN
# 10740       15109000              NaN             NaN               NaN
# 10741       15109000              NaN             NaN               NaN
# 10742       15109000              NaN             NaN               NaN
# 10743       15109000              NaN             NaN               NaN
# 10744       15109000              NaN             NaN               NaN
# 10745       15109000              NaN             NaN               NaN
# 10746       15109000              NaN             NaN               NaN
# 10747       15109000              NaN             NaN               NaN
# 10748       15109000              NaN             NaN               NaN
# 10749       23048445              NaN             NaN               NaN
# 10750       23048445              NaN             NaN               NaN
# 10751       23048445              NaN             NaN               NaN
# 10752       23048445              NaN             NaN               NaN
# 10753       23048445              NaN             NaN               NaN
# 10754       23048445              NaN             NaN               NaN
# 10755       23048445              NaN             NaN               NaN
# 10756       23048445              NaN             NaN               NaN
# 10757       23048445              NaN             NaN               NaN
# 10758       23048445              NaN             NaN               NaN
# 10759       23048445              NaN             NaN               NaN
# 10760       23048445              NaN             NaN               NaN
# 10761       23048445              NaN             NaN               NaN
# 10762       72665863              NaN             NaN               NaN
# 10763       72665863              NaN             NaN               NaN
# 10764       72665863              NaN             NaN               NaN
# 10765       72665863              NaN             NaN               NaN
# 10766       72665863              NaN             NaN               NaN
# 10767       72665863              NaN             NaN               NaN
# 10768       72665863              NaN             NaN               NaN
# 10769       72665863              NaN             NaN               NaN
# 10770       72665863              NaN             NaN               NaN
# 10771       72665863              NaN             NaN               NaN
# 10772       72665863              NaN             NaN               NaN
# 10773       72665863              NaN             NaN               NaN
# 10774       72665863              NaN             NaN               NaN
# 10775       57469283              NaN             NaN               NaN
# 10776       57469283              NaN             NaN               NaN
# 10777       57469283              NaN             NaN               NaN
# 10778       57469283              NaN             NaN               NaN
# 10779       57469283              NaN             NaN               NaN
# 10780       57469283              NaN             NaN               NaN
# 10781       57469283              NaN             NaN               NaN
# 10782       57469283              NaN             NaN               NaN
# 10783       57469283              NaN             NaN               NaN
# 10784       57469283              NaN             NaN               NaN
# 10785       57469283              NaN             NaN               NaN
# 10786       57469283              NaN             NaN               NaN
# 10787       57469283              NaN             NaN               NaN
#
#        sentence.sentNo                                      text.contents  \
# 0                    4  Cupboard doors were flying , the trash can in ...
# 1                    4  Cupboard doors were flying , the trash can in ...
# 2                    4  Cupboard doors were flying , the trash can in ...
# 3                    4  Cupboard doors were flying , the trash can in ...
# 4                    4  Cupboard doors were flying , the trash can in ...
# 5                    4  Cupboard doors were flying , the trash can in ...
# 6                    4  Cupboard doors were flying , the trash can in ...
# 7                    4  Cupboard doors were flying , the trash can in ...
# 8                    4  Cupboard doors were flying , the trash can in ...
# 9                    4  Cupboard doors were flying , the trash can in ...
# 10                   4  Cupboard doors were flying , the trash can in ...
# 11                   4  Cupboard doors were flying , the trash can in ...
# 12                   4  Cupboard doors were flying , the trash can in ...
# 13                   2  `` The sound of bells is a net to draw people ...
# 14                   2  `` The sound of bells is a net to draw people ...
# 15                   2  `` The sound of bells is a net to draw people ...
# 16                   2  `` The sound of bells is a net to draw people ...
# 17                   2  `` The sound of bells is a net to draw people ...
# 18                   2  `` The sound of bells is a net to draw people ...
# 19                   2  `` The sound of bells is a net to draw people ...
# 20                   2  `` The sound of bells is a net to draw people ...
# 21                   2  `` The sound of bells is a net to draw people ...
# 22                   2  `` The sound of bells is a net to draw people ...
# 23                   2  `` The sound of bells is a net to draw people ...
# 24                   2  `` The sound of bells is a net to draw people ...
# 25                   2  `` The sound of bells is a net to draw people ...
# 26                   3  `` I live in hopes that the ringers themselves...
# 27                   3  `` I live in hopes that the ringers themselves...
# 28                   3  `` I live in hopes that the ringers themselves...
# 29                   3  `` I live in hopes that the ringers themselves...
# 30                   3  `` I live in hopes that the ringers themselves...
# 31                   3  `` I live in hopes that the ringers themselves...
# 32                   3  `` I live in hopes that the ringers themselves...
# 33                   3  `` I live in hopes that the ringers themselves...
# 34                   3  `` I live in hopes that the ringers themselves...
# 35                   3  `` I live in hopes that the ringers themselves...
# 36                   3  `` I live in hopes that the ringers themselves...
# 37                   2  The center , which has drawn criticism from ar...
# 38                   2  The center , which has drawn criticism from ar...
# 39                   2  The center , which has drawn criticism from ar...
# 40                   2  The center , which has drawn criticism from ar...
# 41                   2  The center , which has drawn criticism from ar...
# 42                   2  The center , which has drawn criticism from ar...
# 43                   2  The center , which has drawn criticism from ar...
# 44                   2  The center , which has drawn criticism from ar...
# 45                   2  The center , which has drawn criticism from ar...
# 46                   2  The center , which has drawn criticism from ar...
# 47                   2  The center , which has drawn criticism from ar...
# 48                   2  The center , which has drawn criticism from ar...
# ...                ...                                                ...
# 10739                0  Henry yanked out the jack , groped for the pap...
# 10740                0  Henry yanked out the jack , groped for the pap...
# 10741                0  Henry yanked out the jack , groped for the pap...
# 10742                0  Henry yanked out the jack , groped for the pap...
# 10743                0  Henry yanked out the jack , groped for the pap...
# 10744                0  Henry yanked out the jack , groped for the pap...
# 10745                0  Henry yanked out the jack , groped for the pap...
# 10746                0  Henry yanked out the jack , groped for the pap...
# 10747                0  Henry yanked out the jack , groped for the pap...
# 10748                0  Henry yanked out the jack , groped for the pap...
# 10749                0  The man screamed , yanked out the pin and thre...
# 10750                0  The man screamed , yanked out the pin and thre...
# 10751                0  The man screamed , yanked out the pin and thre...
# 10752                0  The man screamed , yanked out the pin and thre...
# 10753                0  The man screamed , yanked out the pin and thre...
# 10754                0  The man screamed , yanked out the pin and thre...
# 10755                0  The man screamed , yanked out the pin and thre...
# 10756                0  The man screamed , yanked out the pin and thre...
# 10757                0  The man screamed , yanked out the pin and thre...
# 10758                0  The man screamed , yanked out the pin and thre...
# 10759                0  The man screamed , yanked out the pin and thre...
# 10760                0  The man screamed , yanked out the pin and thre...
# 10761                0  The man screamed , yanked out the pin and thre...
# 10762                0  I yanked out my wallet and went through the cr...
# 10763                0  I yanked out my wallet and went through the cr...
# 10764                0  I yanked out my wallet and went through the cr...
# 10765                0  I yanked out my wallet and went through the cr...
# 10766                0  I yanked out my wallet and went through the cr...
# 10767                0  I yanked out my wallet and went through the cr...
# 10768                0  I yanked out my wallet and went through the cr...
# 10769                0  I yanked out my wallet and went through the cr...
# 10770                0  I yanked out my wallet and went through the cr...
# 10771                0  I yanked out my wallet and went through the cr...
# 10772                0  I yanked out my wallet and went through the cr...
# 10773                0  I yanked out my wallet and went through the cr...
# 10774                0  I yanked out my wallet and went through the cr...
# 10775                0  She turned back and yanked shut the door from ...
# 10776                0  She turned back and yanked shut the door from ...
# 10777                0  She turned back and yanked shut the door from ...
# 10778                0  She turned back and yanked shut the door from ...
# 10779                0  She turned back and yanked shut the door from ...
# 10780                0  She turned back and yanked shut the door from ...
# 10781                0  She turned back and yanked shut the door from ...
# 10782                0  She turned back and yanked shut the door from ...
# 10783                0  She turned back and yanked shut the door from ...
# 10784                0  She turned back and yanked shut the door from ...
# 10785                0  She turned back and yanked shut the door from ...
# 10786                0  She turned back and yanked shut the door from ...
# 10787                0  She turned back and yanked shut the door from ...
#
#       annotationSet.LU
# 0              scoot.v
# 1              scoot.v
# 2              scoot.v
# 3              scoot.v
# 4              scoot.v
# 5              scoot.v
# 6              scoot.v
# 7              scoot.v
# 8              scoot.v
# 9              scoot.v
# 10             scoot.v
# 11             scoot.v
# 12             scoot.v
# 13              draw.v
# 14              draw.v
# 15              draw.v
# 16              draw.v
# 17              draw.v
# 18              draw.v
# 19              draw.v
# 20              draw.v
# 21              draw.v
# 22              draw.v
# 23              draw.v
# 24              draw.v
# 25              draw.v
# 26              draw.v
# 27              draw.v
# 28              draw.v
# 29              draw.v
# 30              draw.v
# 31              draw.v
# 32              draw.v
# 33              draw.v
# 34              draw.v
# 35              draw.v
# 36              draw.v
# 37              draw.v
# 38              draw.v
# 39              draw.v
# 40              draw.v
# 41              draw.v
# 42              draw.v
# 43              draw.v
# 44              draw.v
# 45              draw.v
# 46              draw.v
# 47              draw.v
# 48              draw.v
# ...                ...
# 10739           yank.v
# 10740           yank.v
# 10741           yank.v
# 10742           yank.v
# 10743           yank.v
# 10744           yank.v
# 10745           yank.v
# 10746           yank.v
# 10747           yank.v
# 10748           yank.v
# 10749           yank.v
# 10750           yank.v
# 10751           yank.v
# 10752           yank.v
# 10753           yank.v
# 10754           yank.v
# 10755           yank.v
# 10756           yank.v
# 10757           yank.v
# 10758           yank.v
# 10759           yank.v
# 10760           yank.v
# 10761           yank.v
# 10762           yank.v
# 10763           yank.v
# 10764           yank.v
# 10765           yank.v
# 10766           yank.v
# 10767           yank.v
# 10768           yank.v
# 10769           yank.v
# 10770           yank.v
# 10771           yank.v
# 10772           yank.v
# 10773           yank.v
# 10774           yank.v
# 10775           yank.v
# 10776           yank.v
# 10777           yank.v
# 10778           yank.v
# 10779           yank.v
# 10780           yank.v
# 10781           yank.v
# 10782           yank.v
# 10783           yank.v
# 10784           yank.v
# 10785           yank.v
# 10786           yank.v
# 10787           yank.v
#
# [10788 rows x 17 columns]

# %%
by_sid_start = cm_plus_df.groupby(['sentence.ID', 'label.start'], as_index=True)

# %%
gs = [g for _, g in by_sid_start]
gs[1]
# Out:
#       annotationSet.ID annotationSet.status  label.end  label.feID  \
# 1116            642838               MANUAL       11.0         NaN
#
#      label.itype label.name  label.start  layer.name  layer.rank  sentence.ID  \
# 1116         NaN     Target          2.0  catapult.v           1       580494
#
#       sentence.aPos  sentence.corpID  sentence.docID  sentence.paragNo  \
# 1116       92227906              NaN             NaN               NaN
#
#       sentence.sentNo                                      text.contents  \
# 1116                0  I catapulted the tiny beasts across the creek ...
#
#      annotationSet.LU
# 1116       catapult.v

# %%
gs[1].pivot(columns='label.name', values='layer.name')
# Out:
# label.name      Target
# 1116        catapult.v

# %%
gs[0].pivot(columns='label.name', values='layer.name')
# Out:
# label.name Agent   Ext    NP
# 1102          FE  None  None
# 1106        None    GF  None
# 1110        None  None    PT

# %%
qgrid.show_grid(cm_plus_df, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 100})

# %% [markdown]
# ## Now, let's try to do the same without Pandas

# %%
import gzip

from framenet.util           import take, iget, groupby
from framenet.data           import annotation as ann
from pickle                  import dump, load
from pprint                  import pformat


@curry
def crit(aset, d):
    return d['annotationSet.ID'] in aset

# %%
LU_RECS = 'lu_recs'
lu_recs = ann.get_object(LU_RECS, unstack_all(lu_sents()))
len(lu_recs)
# Out:
# Reading pickle for lu_recs
# 7658278

# %% [markdown]
# ## Cause_motion

# %%
CM_RECS  = 'cm_recs'
cm_asets = ann.annoset_for('Cause_motion')
cm_crit  = crit(cm_asets)
cm_recs  = ann.get_object(CM_RECS, filter(crit, lu_recs))
assert len(cm_recs) == 10788
# Out:
# Reading pickle for cm_recs

# %%
pd.options.display.max_rows=500

# cols1 = ['sentence.ID', 'label.start', 
#          'label.itype', 'label.name', 'label.feID', 'layer.name']

# cols2 = ['sentence.ID', 'label.start', 
#          'layer.name', 'label.name', 'label.feID']

# cols3 = ['sentence.ID', 'label.start', 'label.name', 
#          'label.name:Ext', 'label.name:Dep', 'label.name:Obj']

# cols4 = ['sentence.ID', 'label.start', 
#          'label.name:Ext', 'label.name:Dep', 'label.name:Obj']

cols5 = ['label.start', 'layer.name', 'label.name', 'label.itype']

# %%
layers            = ['GF', 'PT', 'FE', 'Target', 'Other']
# cm_recs_in_layers = filter(lambda d: d.get('layer.name', None) in layers, cm_recs)
select_cols1      = iget(*cols5, default=9999)
# group_key_cols    = iget(*cols1[:2], default=9999) 
sentence_id       = iget('sentence.ID') 
label_start       = iget('label.start', default=9999)

def lmap(f, it):
    return [f(i) for i in it]

def lmap_plus(f, it):
    xs = list(map(f, it))
    try:
        return [(n, dict(map(iget(1, 2), g))) for n, g in groupby(iget(0), xs)]
#         return [(n, list(g)) for n, g in groupby(iget(0), xs)]
    except TypeError:
        print('Exception:')
        pprint(xs)
        raise

grouped_by_sentence = groupby(sentence_id, cm_recs)
grouped_by_sentence_and_start = (
    (k, groupby(label_start, g)) 
    for k, g in grouped_by_sentence
)

# %%
# Let's see what's in there
grouped_and_groups = [(n, lmap_plus(select_cols1, g)) for n, g in grouped_by_sentence]
# grouped_and_groups = [(n, list(g)) for n, g in grouped_by_sentence]
print(len(grouped_and_groups))
# Out:
# 821

# %%
from multipledispatch import dispatch
from collections      import Sequence, namedtuple
from framenet.util    import (compose, groupwise, unique, juxt, aget, 
                              reduceby, iget, remove)
from framenet.data.annotation import Pattern, Graph
from pprint           import pprint

gf_tgt = compose(iget('GF', 'Target', default=None), 
                 iget(1))

def gf_or_tgt(group):
    "Turn a group into a pattern."
    f, s = gf_tgt(group) 
    return f or s

# Test
g1 = [(0,  {'FE': 'Agent', 'GF': 'Ext', 'PT': 'NP'}),
      (2,  {'Target': 'Target'}),
      (13, {'FE': 'Theme', 'GF': 'Obj', 'PT': 'NP'}),
      (29, {'FE': 'Path',  'GF': 'Dep', 'PT': 'PP'}),
      (50, {'FE': 'Goal',  'GF': 'Dep', 'PT': 'PP'})]    


pattern = list(map(gf_or_tgt, g1))
pprint(pattern)
    
vertices = Ext, Target, Obj, Dep = ['Ext', 'Target', 'Obj', 'Dep']
edges    = ((Ext, [Target]),
            (Target, [Obj]), 
            (Obj, [Dep]),
            (Dep, [Dep, None]),
            (None, [None]))

matcher = Pattern(Graph(vertices=vertices, edges=edges))

@curry
def match(matcher, group):
    return matcher.match(list(map(gf_or_tgt, group)))

assert match(matcher, g1)
# Out:
# ['Ext', 'Target', 'Obj', 'Dep', 'Dep']

# %%
groups       = [g for _, g in grouped_and_groups]
#################################################

# pprint(groups[:10])
groups_count = len(groups)
fe           = compose(iget('FE',       default=None), iget(1))
fe_gf        = compose(iget('FE', 'GF', default=None), iget(1))
fes          = [[fe(r) for r in g] for g in groups if match(matcher, g)]
fes_count    = len(fes)

# print(fes[:2])
print('Matching Ext T Obj Dep+ pattern:', len(fes), len(fes) / groups_count)

len([fe for fe in fes if fe[0] == 'Agent']) / fes_count
# Out:
# Matching Ext T Obj Dep+ pattern: 439 0.5347137637028014
# 0.979498861047836

# %%
nonmatching = [tuple(fe(r) for r in g) for g in groups if match(matcher, g)]

from collections import Counter

nm_conts = Counter(nonmatching)
nm_conts.most_common()
# Out:
# [(('Agent', None, 'Theme', 'Goal', None), 187),
#  (('Agent', None, 'Theme', 'Path', None), 102),
#  (('Agent', None, 'Theme', 'Source', None), 42),
#  (('Agent', None, 'Theme', 'Result', None), 15),
#  (('Agent', None, 'Theme', 'Manner', 'Goal', None), 11),
#  (('Agent', None, 'Theme', 'Path', 'Goal', None), 11),
#  (('Agent', None, 'Theme', 'Path', 'Path', None), 6),
#  (('Agent', None, 'Theme', 'Manner', 'Path', None), 5),
#  (('Agent', None, 'Theme', 'Area', None), 5),
#  (('Agent', None, 'Theme', 'Source', 'Goal', None), 5),
#  (('Cause', None, 'Theme', 'Goal', None), 4),
#  (('Agent', None, 'Theme', 'Path', 'Distance', None), 3),
#  (('Agent', None, 'Theme', 'Path', 'Manner', None), 3),
#  (('Agent', None, 'Theme', 'Initial_state', None), 3),
#  (('Agent', None, 'Goal', 'Theme', None), 2),
#  (('Agent', None, 'Theme', 'Goal', 'Manner', None), 2),
#  (('Agent', None, 'Theme', 'Manner', 'Goal'), 2),
#  (('Agent', None, 'Theme', 'Source', 'Path', None), 2),
#  (('Agent', None, 'Theme', 'Depictive', 'Goal', None), 2),
#  (('Agent', None, 'Theme', 'Goal', 'Instrument', None), 2),
#  (('Agent', None, 'Theme', 'Goal', 'Handle', None), 1),
#  (('Agent', None, 'Theme', 'Source', 'Handle', None), 1),
#  (('Cause', None, 'Theme', 'Area', None), 1),
#  (('Agent', None, 'Theme', 'Source', 'Time', None), 1),
#  (('Agent', None, 'Theme', 'Distance', 'Goal'), 1),
#  (('Agent', None, 'Theme', 'Manner', 'Area', None), 1),
#  (('Agent', None, 'Theme', 'Goal', 'Source', None), 1),
#  (('Agent', None, 'Theme', 'Result', 'Path', 'Handle', None), 1),
#  (('Agent', None, 'Theme', 'Area', 'Time', None), 1),
#  (('Theme', None, 'Path', 'Agent', None), 1),
#  (('Agent', None, 'Theme', 'Distance', 'Goal', None), 1),
#  (('Agent', None, 'Theme', 'Path', 'Depictive', None), 1),
#  (('Agent', None, 'Theme', 'Manner', 'Source', None), 1),
#  (('Agent', None, 'Theme', 'Distance', 'Path'), 1),
#  (('Source', None, 'Theme', 'Goal', None), 1),
#  (('Agent', None, 'Theme', 'Source', 'Instrument', None), 1),
#  (('Agent', None, 'Theme', 'Path', 'Path', 'Time', None), 1),
#  (('Agent', None, 'Theme', 'Path', 'Result', None), 1),
#  (('Agent', None, 'Theme', 'Path', 'Means', None), 1),
#  (('Agent', None, 'Theme', 'Result', 'Goal', None), 1),
#  (('Goal', None, 'Theme', 'Time', 'Agent'), 1),
#  (('Agent', None, 'Theme', 'Area', 'Instrument', None), 1),
#  (('Cause', None, 'Theme', 'Manner', 'Source', None), 1),
#  (('Agent', None, 'Theme', 'Path', 'Source', None), 1),
#  (('Agent', None, 'Theme', 'Source', 'Source', 'Goal', None), 1)]

# %%
Node   = namedtuple('Node', 'id FE GF')
Link   = namedtuple('Link', 'source target')

layers = [remove(lambda x: x == (None, None), [fe_gf(r) for r in g]) 
          for g in groups if match(g)]
nodes  = lambda group: [Node('%d:%s' % (i, fe), str(fe), str(gf)) 
                        for i, (fe, gf) in enumerate(group)]
links  = lambda node:  [Link(*pair) for pair in groupwise(2, node)] 
nss    = map(nodes, layers)

def to_csv(link_and_count):
    link, count = link_and_count
    return (link.source.id, link.source.FE, link.source.GF,
            link.target.id, link.target.FE, link.target.GF, 
            count)

def cols(link):
    return ['%s_%s' % (st, k) 
            for st, n in zip(('source', 'target'), link)
            for k in n._asdict().keys()]

assert cols(Link(Node('id', 'fe', 'gf'), Node('id2', 'fe2', 'gf2'))) == [
    'source_id', 'source_FE', 'source_GF',
    'target_id', 'target_FE', 'target_GF'
]

# list(take(10, flatmap(links, map(nodes, layers)))
layers[:10]
# Out:
# [[('Agent', 'Ext'), ('Theme', 'Obj'), ('Path', 'Dep'), ('Goal', 'Dep')],
#  [('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', 'Dep')],
#  [('Agent', 'Ext'), ('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', 'Dep')],
#  [('Agent', 'Ext'), ('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', 'Dep')],
#  [('Theme', 'Ext'), ('Source', 'Dep'), ('Agent', None)],
#  [('Theme', 'Ext'), ('Goal', 'Dep'), ('Agent', None)],
#  [('Theme', 'Ext'), ('Goal', 'Dep'), ('Agent', None)],
#  [('Theme', 'Ext'), ('Goal', 'Dep'), ('Goal', 'Dep'), ('Agent', None)],
#  [('Theme', 'Ext'), ('Source', 'Dep'), ('Goal', 'Dep'), ('Agent', None)],
#  [('Theme', 'Ext'), ('Source', 'Dep'), ('Agent', None)]]

# %%
from framenet.data.annotation import Pattern, Graph

def normalize(group, normalizer):
    "Normalize group by applying `normalizer` to each key."
    
def as_layers(groups):
    vertices     = Ext, T, Dep = ['Ext', 'Target', 'Dep']
    ext_dep      = Pattern(Graph(vertices, ((Ext, [T]), 
                                            (T, [Dep]), 
                                            (Dep, [Dep, None]), 
                                            (None, [None]))))
    match2       = ext_dep.match
    non_m_layers = [remove(lambda x: x == (None, None), [fe_gf(r) for r in g])
                    for g in groups 
                    if not match2([gf_or_tgt(r) for r in g]) and not match(g)]
    return non_m_layers

# %%
print(len(as_layers(groups)))
ls2 = as_layers(groups)
ls2[:10]
# Out:
# 201
# [[('Agent', 'Ext'), ('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', 'Dep')],
#  [('Agent', 'Ext'), ('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', 'Dep')],
#  [('Theme', 'Obj'), ('Goal', 'Dep'), ('Agent', None)],
#  [('Goal', 'Obj'), ('Theme', 'Dep'), ('Agent', None)],
#  [('Goal', 'Obj'), ('Theme', 'Dep'), ('Agent', None)],
#  [('Theme', 'Obj'), ('Goal', 'Dep'), ('Agent', None)],
#  [('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', None)],
#  [('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', None)],
#  [('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', None)],
#  [('Agent', 'Ext'), ('Theme', 'Obj'), ('Manner', 'Dep'), ('Goal', None)]]

# %%
nonm1 = Counter(map(tuple, ls2))
nonm1.most_common()
# Out:
# [((('Agent', 'Ext'), ('Goal', 'Dep'), ('Theme', 'Obj')), 29),
#  ((('Theme', 'Obj'), ('Goal', 'Dep'), ('Agent', None)), 14),
#  ((('Agent', 'Ext'), ('Source', 'Dep'), ('Theme', 'Obj')), 13),
#  ((('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', None)), 10),
#  ((('Goal', 'Dep'), ('Theme', 'Obj'), ('Agent', None)), 8),
#  ((('Agent', 'Ext'), ('Path', 'Dep'), ('Theme', 'Obj')), 8),
#  ((('Theme', 'Obj'), ('Path', 'Dep'), ('Agent', None)), 7),
#  ((('Theme', 'Obj'), ('Theme', 'Obj'), ('Agent', 'Ext'), ('Goal', 'Dep')), 6),
#  ((('Agent', 'Ext'), ('Agent', 'Ext'), ('Theme', 'Obj'), ('Path', 'Dep')), 5),
#  ((('Theme', 'Obj'), ('Source', 'Dep'), ('Agent', None)), 5),
#  ((('Theme', 'Obj'), ('Agent', 'Ext'), ('Goal', 'Dep')), 4),
#  ((('Goal', 'Dep'), ('Theme', None)), 4),
#  ((('Theme', 'Ext'), ('Theme', 'Ext'), ('Path', 'Dep'), ('Agent', None)), 3),
#  ((('Agent', 'Ext'), ('Agent', 'Ext'), ('Theme', 'Obj'), ('Goal', 'Dep')), 3),
#  ((('Goal', 'Obj'), ('Theme', 'Dep'), ('Agent', None)), 3),
#  ((('Agent', 'Ext'), ('Theme', 'Gen'), ('Goal', 'Obj')), 3),
#  ((('Theme', 'Obj'), ('Goal', 'Dep'), ('Agent', 'Ext')), 2),
#  ((('Theme', 'Obj'), ('Agent', 'Ext'), ('Path', 'Dep')), 2),
#  ((('Theme', 'Ext'), ('Theme', 'Ext'), ('Goal', 'Dep'), ('Agent', None)), 2),
#  ((('Agent', 'Ext'), ('Theme', 'Obj'), ('Manner', 'Dep'), ('Goal', None)), 2),
#  ((('Agent', 'Ext'), ('Manner', 'Dep'), ('Theme', 'Obj'), ('Path', 'Dep')), 2),
#  ((('Theme', 'Obj'), ('Source', 'Dep'), ('Goal', 'Dep'), ('Agent', None)), 2),
#  ((('Agent', 'Ext'), ('Result', 'Dep'), ('Theme', 'Obj')), 2),
#  ((('Agent', 'Ext'), ('Agent', 'Ext'), ('Theme', 'Obj'), ('Source', 'Dep')),
#   1),
#  ((('Theme', 9999),), 1),
#  ((('Theme', 'Ext'), ('Time', 'Dep'), ('Goal', 'Dep')), 1),
#  ((('Theme', 'Ext'),
#    ('Theme', 'Ext'),
#    ('Path', 'Dep'),
#    ('Instrument', 'Dep'),
#    ('Agent', None)),
#   1),
#  ((('Path', 'Dep'), ('Theme', 'Dep'), ('Agent', None)), 1),
#  ((('Cause', 'Ext'),
#    ('Cause', 'Ext'),
#    ('Theme', 'Obj'),
#    ('Manner', 'Dep'),
#    ('Goal', None)),
#   1),
#  ((('Goal', 'Dep'), ('Theme', 'Ext'), ('Agent', None)), 1),
#  ((('Theme', 'Ext'), ('Goal', None)), 1),
#  ((('Agent', 'Ext'),
#    ('Agent', 'Ext'),
#    ('Theme', 'Obj'),
#    ('Distance', 'Dep'),
#    ('Path', None)),
#   1),
#  ((('Theme', 'Ext'), ('Theme', 'Ext'), ('Source', 'Dep'), ('Agent', None)), 1),
#  ((('Agent', 'Ext'),
#    ('Path', 'Dep'),
#    ('Theme', 'Obj'),
#    ('Distance', 'Dep'),
#    ('Path', 'Dep')),
#   1),
#  ((('Agent', 'Ext'), ('Theme', 'Obj'), ('Path', None)), 1),
#  ((('Agent', 'Ext'), ('Time', 'Dep'), ('Theme', 'Obj'), ('Goal', 'Dep')), 1),
#  ((('Theme', 'Ext'), ('Area', None)), 1),
#  ((('Path', 9999),), 1),
#  ((('Theme', 'Obj'), ('Theme', 'Obj'), ('Agent', 'Ext'), ('Area', 'Dep')), 1),
#  ((('Theme', 'Obj'), ('Path', 'Dep'), ('Agent', 'Ext')), 1),
#  ((('Agent', 'Ext'), ('Means', 'Dep'), ('Theme', 'Obj'), ('Path', 'Dep')), 1),
#  ((('Agent', 'Ext'), ('Theme', 'Obj'), ('Distance', 'Dep'), ('Path', None)),
#   1),
#  ((('Agent', 'Ext'), ('Source', 'Dep'), ('Theme', 'Obj'), ('Manner', 'Dep')),
#   1),
#  ((('Agent', 'Ext'), ('Theme', 'Gen'), ('Result', 'Dep'), ('Handle', 'Dep')),
#   1),
#  ((('Agent', 'Ext'), ('Theme', 'Obj'), ('Result', None)), 1),
#  ((('Theme', 'Obj'), ('Path', 'Dep'), ('Path', 'Dep'), ('Agent', None)), 1),
#  ((('Agent', 'Ext'), ('Time', 'Dep'), ('Theme', 'Obj'), ('Source', 'Dep')), 1),
#  ((('Theme', 'Ext'), ('Path', 'Obj'), ('Agent', None)), 1),
#  ((('Theme', 'Obj'),
#    ('Theme', 'Obj'),
#    ('Agent', 'Ext'),
#    ('Manner', 'Dep'),
#    ('Goal', 'Dep')),
#   1),
#  ((('Theme', 'Ext'), ('Theme', 'Ext'), ('Area', 'Dep'), ('Agent', None)), 1),
#  ((('Source', 'Dep'), ('Theme', 'Obj'), ('Means', 'Dep'), ('Agent', None)), 1),
#  ((('Theme', 'Obj'), ('Agent', None)), 1),
#  ((('Cause', 'Ext'),
#    ('Cause', 'Ext'),
#    ('Degree', 'Dep'),
#    ('Theme', 'Obj'),
#    ('Goal', 'Dep')),
#   1),
#  ((('Agent', 'Ext'), ('Theme', 'Obj'), ('Distance', 'Dep'), ('Goal', None)),
#   1),
#  ((('Theme', 'Ext'),
#    ('Depictive', 'Dep'),
#    ('Path', 'Dep'),
#    ('Goal', 'Dep'),
#    ('Agent', None)),
#   1),
#  ((('Theme', 'Dep'), ('Goal', 'Dep'), ('Agent', None)), 1),
#  ((('Theme', 'Ext'), ('Time', 'Dep'), ('Goal', 'Dep'), ('Agent', None)), 1),
#  ((('Theme', 'Ext'),
#    ('Goal', 'Dep'),
#    ('Explanation', 'Dep'),
#    ('Theme', 'Ext'),
#    ('Goal', 'Dep'),
#    ('Agent', None)),
#   1),
#  ((('Agent', 'Ext'), ('Degree', 'Dep'), ('Theme', 'Obj'), ('Source', 'Dep')),
#   1),
#  ((('Theme', 'Obj'), ('Goal', None)), 1),
#  ((('Theme', 'Obj'), ('Theme', 'Obj'), ('Agent', 'Ext'), ('Source', 'Dep')),
#   1),
#  ((('Theme', 'Ext'), ('Manner', 'Dep'), ('Goal', 'Dep'), ('Agent', None)), 1),
#  ((('Theme', 'Ext'), ('Theme', 'Ext'), ('Area', None)), 1),
#  ((('Theme', 'Dep'), ('Agent', 'Ext'), ('Goal', 'Obj')), 1),
#  ((('Goal', 'Dep'), ('Theme', 'Obj'), ('Manner', 'Dep'), ('Agent', None)), 1),
#  ((('Theme', 'Obj'), ('Cause', 'Dep'), ('Agent', None)), 1),
#  ((('Theme', 'Obj'), ('Path', 'Dep'), ('Distance', 'Dep'), ('Agent', None)),
#   1),
#  ((('Theme', 'Obj'), ('Distance', 'Dep'), ('Path', None)), 1),
#  ((('Agent', 'Ext'), ('Theme', 'Gen'), ('Goal', 'Dep'), ('Handle', 'Dep')), 1),
#  ((('Theme', 'Obj'), ('Source', 'Dep'), ('Path', 'Dep'), ('Agent', None)), 1),
#  ((('Source', 'Dep'), ('Theme', 'Obj'), ('Agent', 'Ext')), 1),
#  ((('Theme', 'Obj'), ('Agent', 'Ext'), ('Distance', 'Dep'), ('Path', 'Dep')),
#   1),
#  ((('Theme', 'Obj'), ('Goal', 'Dep'), ('Manner', 'Dep'), ('Agent', None)), 1),
#  ((('Agent', 'Ext'), ('Manner', 'Dep'), ('Theme', 'Obj'), ('Goal', None)), 1),
#  ((('Goal', 'Ext'), ('Theme', 'Obj'), ('Time', 'Dep'), ('Agent', None)), 1),
#  ((('Cause', 'Ext'),
#    ('Cause', 'Ext'),
#    ('Area', 'Dep'),
#    ('Theme', 'Obj'),
#    ('Manner', 'Dep')),
#   1),
#  ((('Theme', 'Obj'), ('Result', 'Dep'), ('Manner', 'Dep'), ('Agent', None)),
#   1),
#  ((('Agent', 'Ext'),
#    ('Agent', 'Ext'),
#    ('Theme', 'Obj'),
#    ('Source', 'Dep'),
#    ('Goal', 'Dep')),
#   1),
#  ((('Theme', 'Obj'), ('Result', 'Dep'), ('Agent', 'Ext')), 1),
#  ((('Time', 'Dep'), ('Theme', 'Ext'), ('Source', 'Dep'), ('Agent', None)), 1),
#  ((('Theme', 'Ext'), ('Source', 'Dep'), ('Goal', 'Dep'), ('Depictive', 'Obj')),
#   1),
#  ((('Theme', 'Ext'), ('Goal', 'Obj'), ('Agent', None)), 1),
#  ((('Cause', 'Ext'), ('Cause', 'Ext'), ('Theme', 'Obj'), ('Source', 'Dep')),
#   1),
#  ((('Time', 'Dep'),
#    ('Cause', 'Ext'),
#    ('Theme', 'Obj'),
#    ('Cause', 'Ext'),
#    ('Theme', 'Obj'),
#    ('Goal', None)),
#   1),
#  ((('Agent', 'Ext'), ('Source', 'Dep'), ('Theme', 'Obj'), ('Place', 'Dep')),
#   1)]

# %%
def write_csv(fname, layers, base='.'):
    path = join(base, '%s.csv' % fname)
    with open(path, 'w+') as sout:
        ident           = lambda x: x
        count           = lambda ys, _: ys + 1
        link_and_counts = reduceby(ident, 0, count, flatmap(links, map(nodes, layers)))
        for i, lc in enumerate(link_and_counts):
            if i == 0:
                print(','.join( cols(lc[0]) + ['count']), file=sout)
            print(','.join(str(lc) for lc in to_csv(lc)), file=sout)
        print('Written %d records.' % i)

# %%
write_csv('ExtTDep+None', as_layers(groups))
# Out:
# Written 68 records.

# %%
json = {
    'nodes': list(map(dict, unique(flatmap(nodes, layers)))),
    'links': list(flatmap(links, map(nodes, layers)))
}
len(json['links'])

# %%
import json
with open('sankey.json', 'w+b') as sout:
    json.dump(json, sout)

# %% [markdown]
# ## To do:
#
# * Remove non-core stuff!
# * include
#     - CNI
#     - Target
# * and modify the pattern matcher to select on those
# * also: add `Other` (as `layer.name`)
# * add `sentence.ID`
# * pattern counts, with freq of freq.
#     - and histograms
# * other frames: `Placing`, `Cause_fluidic_motion`
