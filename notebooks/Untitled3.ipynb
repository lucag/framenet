# %%
# %%html
#
# <script type="text/javascript">
#
# $(function () {
#   $('[data-toggle="popover"]').popover()
# })
#
# </script>
#
# <button type="button" class="btn btn-default"
#         container="body" data-toggle="popover"
#         data-placement="auto" data-trigger="click focus"
#         data-html="true"
#         data-content="<b>Vivamus</b> <i>sagittis</i> <ul><li>lacus vel</li> <li>augue laoreet</li> <li>rutrum faucibus</li<">
#   ...
# </button>
# Out:
# <script type="text/javascript">
#
# $(function () {
#   $('[data-toggle="popover"]').popover()
# })
#
# </script>
#
# <button type="button" class="btn btn-default"
#         container="body" data-toggle="popover"
#         data-placement="auto" data-trigger="click focus"
#         data-html="true"
#         data-content="<b>Vivamus</b> <i>sagittis</i> <ul><li>lacus vel</li> <li>augue laoreet</li> <li>rutrum faucibus</li<">
#   ...
# </button>

# %%
from framenet.data.annotation import Groups, Patterns
from framenet.data.pattern import *

Ext, Dep, Obj, x = map(Lit, 'Ext Dep Obj _'.split())

cm = Groups('Cause_motion')
cm_ps = Patterns(cm)
cm_ps.display(pattern_matcher=Ext & x & Obj & Many1(Dep))
# Out:
# <style>
#   .popover{
#     width: 960px;
#     max-width: none;
#   }
# </style>
#
# <script type="text/javascript">
#   $(function () {
#     $('[data-toggle="popover"]').popover()
#   })
# </script><table><tr><th></th><th>freq.</th><th>Patterns</th><th></th></tr><tr><td style="text-align: right">1</td>
# <td style="text-align: right">178</td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Theme (NP) → <b>Dep</b>: Goal (PP)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click focus"
#         data-html="true"
# ...
