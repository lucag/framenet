# %% [markdown]
# ## Ways to construct ECG schemas and constructions from FN data

# %%
from framenet.builder import build

# %% [markdown]
# ### Schemas
#
# Converting FN frames to ECG schemas:
#
# - General info:
#   - 'Forbidden' terms (FN terms that clash with ECG.  e.g. 'construction', 'map', 'form') get appended with "_fn"_
#   - Selected semantic types are converted to Frames. Currently, these are:
#       - 'Physical_object': "Entity", 'Artifact': "Artifact", 'Living_thing': "Biological_entity"
# - **Relations** -- Frame relations are converted to schema relations:
#   - parents (inherits from) are listed as subcases ('subcase of')
#   - cause (is causative of) and Uses are listed as evoked schemas ('evokes')
#   - [**For 'is causative of', do we also want to evoke a Causation schema and, e.g. identify the 'is causative frame' with
#        the Causation.affectedProcess role? And maybe try to figure out which role shoud be bound to affectedEntity?**]
# - **Roles**:
#    - FEs are converted to ECG roles, and are listed in the 'roles' section
#    - If an FE has one of the selected semantic types, the relevant schema is added as a type constraint to that role
#    - [**add description of how inherited roles are handled -- might consider changing from current method.
#         Note that in FN, a subframe does not necessarily inherit all of the superframes roles (i.e., they are not necessarily
#         listed as FEs in the subframe. And even when they are, they can either be core or non-core).**]
#    - [**should core, non-core, and peripheral roles be marked or somehow handled differently?**]
# - **Bindings**
#    - FE relations are listed as bindings in the 'constraints' section [**need to add a description of how this is done**]

# %%
help(ecg_demo1)
# Out:
# Help on function ecg_demo1 in module ecg_demo:
#
# ecg_demo1(fn)
#     Returns list of ECG schemas from FrameNet frames.

# %%
all_schemas = ecg_demo1(fn)

# %%
print(all_schemas)
# Out:
# schema Abandonment
#     subcase of Intentionally_affect
#     roles
#        Agent
#        Theme
#        Place
#        Time
#        Manner
#        Duration
#        Explanation
#        Depictive
#        Degree
#        Means
#        Purpose
#        Event_description
#        Event
#        Instrument
#        Patient
#
#
# schema Abounding_with
#     subcase of Locative_relation
#     evokes Abundance as abundance
#     roles
#        Theme: Entity
#        Location
#        Degree
#        Depictive
#        Time
#        Ground
#        Figure
#        Distance
#        Direction
#        Figures
#        Deixis
#        Accessibility
#        Directness
#        Temporal_profile
#        Region_quantification
#        Profiled_region
#
#
# schema Absorb_heat
#     subcase of Becoming
#     roles
#        Entity
#        Container
#        Heat_source
#        Place
#        Medium
#        Manner
#        Time
#        Explanation
#        Temperature
#        Duration
#        Circumstances
#        Purpose
#        Depictive
#        Result
#        Duration_of_final_state
#        Final_state
#        Final_category
#        Transitional_period
#        Initial_state
#        Initial_category
#        Group
#
#
# schema Abundance
#     subcase of Gradable_attributes
#     roles
#        Collection
#        Quantity
#        Degree
#        Time
#        Circumstances
#        Measure
#        Place
#        Entity
#        Attribute
#        Value
#
#
# schema Abusing
#     subcase of Committing_crime
#     evokes Cause_harm as cause_harm
#     roles
#        Abuser
#        Victim
#        Type_fn
#        Degree
#        Place
#        Time
#        Manner
#        Means
#        Instrument
#        Purpose
#        Explanation
#        Duration
#        Frequency
#        Depictive
#        Circumstances
#        Period_of_iterations
#        Perpetrator
#        Crime
#
#
# schema Access_scenario
#     roles
#        Theme
#        Useful_location
#        Barrier
#
#
# schema Accompaniment
#     subcase of Relation
#     roles
#        Participant
#        Co-participant
#        Participants
#        Entity_1
#        Entity_2
#        Entities
#        Relation_type
#
#
# schema Accomplishment
#     evokes Intentionally_act as intentionally_act
#     roles
#        Means
#        Agent
#        Instrument
#        Place
#        Time
#        Manner
#        Explanation
#        Degree
#        Goal
#        Outcome
#        Circumstances
#        Duration
#        Domain
#        Particular_iteration
#
#
# schema Accoutrements
#     subcase of Artifact
#     roles
#        Wearer
#        Style
#        Material
#        Accoutrement: Artifact
#        Descriptor
#        Use
#        Part
#        Body_location
#        Creator
#        Time_of_creation
#        Name
#        Artifact
#        Type_fn
#
#
# schema Accuracy
#     subcase of Inclination
#     evokes Success_or_failure as success_or_failure
#     evokes Measurable_attributes as measurable_attributes
#     roles
#        Agent
#        Target
#        Outcome
#        Means
#        Degree
#        Time
#        Place
#        Instrument
#        Target_value
#        Deviation
#        Domain
#        Circumstances
#        Frequency
#        Entity
#        Behavior
#        Basis
#        Containing_event
#
#
# schema Achieving_first
#     subcase of Intentionally_create
#     evokes First_experience as first_experience
#     roles
#        Cognizer
#        New_idea
#        Time
#        Place
#        Means
#        Purpose
#        Explanation
#        Field
#        Instrument
#        Manner
#        Basis
#        Location_of_appearance
#        Creator
#        Components
#        Depictive
#        Created_entity: Artifact
#        Role
#        Co-participant
#
#
# schema Active_substance
#     subcase of Substance
#     roles
#        Effect
#        Substance
#        Descriptor
#        Type_fn
#        Name
#        Constituents_fn
#        Origin
#        Inherent_purpose
#
#
# schema Activity
#     subcase of Process
#     roles
#        Activity
#        Duration
#        Place
#        Time
#        Agent
#        Manner
#        Explanation
#        Process
#        Result
#
#
# schema Activity_abandoned_state
#     subcase of Process_uncompleted_state
#     evokes Process_stopped_state as process_stopped_state
#     roles
#        Agent
#        Time
#        Duration
#        Activity
#        Place
#        Process
#
#
# schema Activity_done_state
#     subcase of Process_completed_state
#     roles
#        Agent
#        Activity
#        Time
#        Place
#        Process
#
#
# schema Activity_finish
#     subcase of Intentionally_act, Process_end
#     roles
#        Depictive
#        Manner
#        Result
#        Co-timed_event
#        Place
#        Time
#        Agent
#        Activity
#        Means
#        Purpose
#        Degree
#        Explanation
#        Circumstances
#        Containing_event
#        Act
#        Domain
#        Frequency
#        Period_of_iterations
#        Particular_iteration
#        Event_description
#        Process
#        Final_subevent
#        Duration
#
#
# schema Activity_ongoing
#     subcase of Process_continue
#     roles
#        Duration
#        Activity
#        Place
#        Purpose
#        Time
#        Depictive
#        Manner
#        Means
#        Co-timed_event
#        Agent
#        Explanation
#        Event_description
#        Circumstances
#        Event
#        Next_subevent
#        Concessive
#
#
# schema Activity_pause
#     subcase of Process_pause
#     evokes Eventive_affecting as eventive_affecting
#     roles
#        Activity
#        Agent
#        Manner
#        Means
#        Place
#        Time
#        Purpose
#        Depictive
#        Completeness
#        Duration
#        Legal_basis
#        Explanation
#        Event_description
#        Process
#        Degree
#        Result
#        Final_subevent
#        Iterations
#
#
# schema Activity_paused_state
#     subcase of Process_stopped_state
#     roles
#        Agent
#        Time
#        Activity
#        Duration
#        Process
#
#
# schema Activity_prepare
#     evokes Eventive_affecting as eventive_affecting
#     roles
#        Agent
#        Activity
#        Place
#        Time
#        Manner
#        Means
#        Purpose
#        Duration
#        Depictive
#        Degree
#        Beneficiary
#        Iterations
#        Event_description
#
#
# schema Activity_ready_state
#     subcase of Process_initial_state
#     roles
#        Protagonist
#        Activity
#        Salient_entity
#        Time
#        Result
#        Duration
#        Degree
#        Process
#
#
# schema Activity_resume
#     subcase of Process_resume
#     roles
#        Duration
#        Activity
#        Place
#        Explanation
#        Time
#        Manner
#        Agent
#        Circumstances
#        Depictive
#        Result
#        Event_description
#        Process
#        Frequency
#
#
# schema Activity_start
#     subcase of Process_start
#     evokes Eventive_affecting as eventive_affecting
#     roles
#        Place
#        Purpose
#        Time
#        Depictive
#        Manner
#        Means
#        Activity
#        Agent
#        Co-timed_event
#        Circumstances
#        Containing_event
#        Event_description
#        Explanation
#        Particular_iteration
#        New_situation
#        Viewpoint
#        Concessive
#        Event
#        Initial_subevent
#        Result
#        Duration
#        Frequency
#
#
# schema Activity_stop
#     subcase of Process_stop
#     evokes Eventive_affecting as eventive_affecting
#     roles
#        Purpose
#        Place
#        Time
#        Depictive
#        Manner
#        Result
#        Agent
#        Activity
#        Duration
#        Means
#        Co-timed_event
#        Degree
#        Frequency
#        Containing_event
#        Circumstances
#        Re-encoding
#        Explanation
#        Event_description
#        Particular_iteration
#        Process
#        Final_subevent
#
#
# schema Actually_occurring_entity
#     subcase of Entity
#     roles
#        Instance
#        Type_fn
#        Constituent_parts
#        Formational_cause
#        Name
#        Entity
#
#
# schema Addiction
#     subcase of Gradable_attributes
#     roles
#        Addict
#        Addictant
#        Degree
#        Compeller
#        Entity
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#
#
# schema Adding_up
#     evokes Amounting_to as amounting_to
#     roles
#        Cognizer
#        Numbers
#        Result
#        Time
#        Place
#        Purpose
#        Means
#        Manner
#
#
# schema Adducing
#     evokes Statement as statement
#     roles
#        Speaker
#        Addressee
#        Manner
#        Means
#        Medium
#        Depictive
#        Time
#        Place
#        Specified_entity
#        Role
#        Purpose
#        Explanation
#        Containing_event
#        Event_description
#        Frequency
#        Circumstances
#
#
# schema Adjacency
#     subcase of Locative_relation
#     roles
#        Ground
#        Figure
#        Distance
#        Direction
#        Time
#        Figures
#        Deixis
#        Accessibility
#        Directness
#        Temporal_profile
#        Region_quantification
#        Profiled_region
#
#
# schema Adjusting
#     subcase of Intentionally_affect
#     evokes Cause_change as cause_change
#     roles
#        Agent
#        Part
#        Feature_fn
#        Imposed_purpose
#        Means
#        Place
#        Time
#        Final_value
#        Instrument
#        Purpose
#        Manner
#        Degree
#        Circumstances
#        Event
#        Patient
#        Explanation
#        Event_description
#
#
# schema Adopt_selection
#     evokes Choosing as choosing
#     roles
#        Agent
#        Attribute
#        Value
#        Time
#        Manner
#        Event_description
#        Depictive
#        Purpose
#        Role
#        Place
#        Frequency
#        Containing_event
#        Circumstances
#        Re-encoding
#        Particular_iteration
#        Means
#        Instrument
#        Duration
#        Explanation
#        Viewpoint
#
#
# schema Aesthetics
#     subcase of Desirability
#     roles
#        Entity
#        Attribute
#        Degree
#        Time
#        Circumstances
#        Viewpoint
#        Place
#        Evaluee
#        Parameter
#        Comparison_set
#        Affected_party
#        Depictive
#
#
# schema Age
#     subcase of Measurable_attributes
#     roles
#        Entity
#        Attribute
#        Age
#        Degree
#        Time
#        Circumstances
#        Expressor
#        Descriptor
#        Duration
#        Value
#
#
# schema Aggregate
#     roles
#        Individuals
#        Aggregate
#        Aggregate_property
#        Name
#        Container_possessor
#        Domain
#
#
# schema Aging
#     subcase of Eventive_affecting
#     evokes Age as age
#     roles
#        Entity
#        Time
#        Circumstances
#        Manner
#        Place
#        Result
#        Event
#        Explanation
#        Frequency
#
#
# schema Agree_or_refuse_to_act
#     subcase of Respond_to_proposal
#     roles
#        Speaker
#        Interlocutor
#        Medium
#        Proposed_action
#        Manner
#        Depictive
#        Means
#        Internal_cause
#        Place
#        Time
#        Purpose
#        Particular_iteration
#        Role
#        Co-timed_event
#        Frequency
#        Explanation
#        Event_description
#        Proposal
#        Group
#        Iterations
#
#
# schema Agriculture
#     subcase of Attempt_obtain_food_scenario
#     roles
#        Agriculturist
#        Food
#        Instrument
#        Duration
#        Manner
#        Means
#        Outcome
#        Place
#        Time
#        Purpose
#        Frequency
#        Degree
#        Ground
#        Particular_iteration
#        Type_fn
#        Event_description
#        Circumstances
#        Seeker
#
#
# schema Aiming
#     subcase of Manipulation
#     roles
#        Agent
#        Targeted
#        Outcome
#        Means
#        Time
#        Depictive
#        Place
#        Manner
#        Duration
#        Purpose
#        Particular_iteration
#        Circumstances
#        Instrument
#        Target_location
#        Location_of_protagonist
#        Activity
#        Containing_event
#        Explanation
#        Entity
#        Locus
#        Bodypart_of_agent
#        Result
#
#
# schema Alignment_image_schema
#     subcase of Image_schema
#     roles
#        Alignment_match
#        Ground
#        Alignment_mismatch
#        Profiled_region
#
#
# schema Alliance
#     evokes Organization as organization
#     evokes Competition as competition
#     roles
#        Alliance
#        Members
#        Purpose
#        Period_of_existence
#        Member_1
#        Member_2
#        Descriptor
#
#
# schema Alternatives
#     roles
#        Situation_fn
#        Agent
#        Number_of_possibilities
#        Salient_entity
#        Purpose
#
#
# schema Alternativity
#     roles
#        Profiled_alternative
#        Contrasting_alternative
#
#
# schema Amalgamation
#     subcase of Reciprocality
#     roles
#        Parts
#        Whole
#        Part_1
#        Part_2
#        Degree
#        Manner
#        Result
#        Time
#        Place
#        Depictive
#        Descriptor
#        Protagonist_1
#        Protagonist_2
#        Protagonists
#
#
# schema Amassing
#     subcase of Getting
#     roles
#        Recipient
#        Mass_theme
#        Source
#        Place
#        Purpose
#        Explanation
#        Time
#        Means
#        Manner
#        Result
#        Duration
#        Circumstances
#        Role
#        Theme: Entity
#        Concessive
#        Beneficiary
#
#
# schema Ambient_temperature
#     subcase of Temperature
#     roles
#        Place
#        Attribute
#        Temperature
#        Degree
#        Time
#        Circumstances
#        Weather
#        Entity
#        Subregion
#
#
# schema Ammunition
#     subcase of Artifact
#     roles
#        Ammunition
#        Use
#        Creator
#        Time_of_creation
#        Name
#        Type_fn
#        Material
#        Artifact
#
#
# schema Amounting_to
#     roles
#        Value
#        Attribute
#        Time_span
#        Frequency
#        Numbers
#
#
# schema Animals
#     subcase of Biological_entity
#     roles
#        Animal: Biological_entity
#        Descriptor
#        Origin
#        Characteristic
#        Organism
#
#
# schema Annoyance
#     subcase of Emotions_by_stimulus
#     roles
#        Experiencer
#        Topic
#        Stimulus
#        Degree
#        Empathy_target
#        Expressor
#        Explanation
#        Circumstances
#        State
#        Parameter
#        Manner
#        Time
#        Event
#
#
# schema Appeal
#     evokes Criminal_process as criminal_process
#     roles
#        Convict
#        Representative
#        Decision
#        Grounds
#        Court
#        Time
#        Re-encoding
#        Explanation
#
#
# schema Appellations
#     subcase of Being_named
#     evokes Rank as rank
#     roles
#        Name
#        Title
#        Context
#        Type_fn
#        Entity
#        Language
#        Descriptor
#        Etymological_root
#
#
# schema Apply_heat
#     subcase of Intentionally_affect, Activity
#     evokes Absorb_heat as absorb_heat
#     roles
#        Cook
#        Heating_instrument
#        Place
#        Food
#        Time
#        Means
#        Purpose
#        Duration
#        Medium
#        Co-participant
#        Temperature_setting
#        Degree
#        Manner
#        Container
#        Beneficiary
#        Event
#        Agent
#        Instrument
#        Patient
#        Explanation
#        Event_description
#        Activity
#
#
# schema Appointing
#     subcase of Intentionally_affect
#     roles
#        Selector
#        Official
#        Role
#        Degree
#        Depictive
#        Manner
#        Means
#        Result
#        Circumstances
#        Function
#        Time
#        Place
#        Body
#        Event
#        Agent
#        Instrument
#        Purpose
#        Patient
#        Explanation
#        Event_description
#
#
# schema Architectural_part
#     subcase of Shaped_part
#     roles
#        Part
#        Whole
#        Descriptor
#        Orientation
#        Material
#        Creator
#        Part_prop
#
#
# schema Arithmetic
#     subcase of Reciprocality
#     roles
#        Term1
#        Term2
#        Terms
#        Protagonist_1
#        Protagonist_2
#        Protagonists
#
#
# schema Arithmetic_commutative
#     subcase of Arithmetic
#     roles
#        Terms
#        Term1
#        Term2
#
#
# schema Arithmetic_non-commutative
#     subcase of Arithmetic
#     roles
#        Term_1
#        Term_2
#        Term1
#        Term2
#        Terms
#
#
# schema Armor
#     evokes Protecting as protecting
#     roles
#        Armor
#        Danger
#        Asset
#        Descriptor
#        Degree
#        Material
#        Subregion
#        Type_fn
#
#
# schema Arraignment
#     subcase of Process
#     roles
#        Defendant
#        Place
#        Time
#        Judge
#        Charges
#        Duration
#        Manner
#        Explanation
#        Process
#        Result
#
#
# schema Arranging
#     subcase of Intentionally_affect
#     evokes Placing as placing
#     roles
#        Agent
#        Theme: Entity
#        Time
#        Configuration
#        Manner
#        Location
#        Circumstances
#        Purpose
#        Instrument
#        Means
#        Degree
#        Event
#        Place
#        Patient
#        Explanation
#        Event_description
#
#
# schema Arrest
#     subcase of Intentionally_affect
#     evokes Inhibit_movement as inhibit_movement
#     roles
#        Charges
#        Place
#        Time
#        Authorities
#        Suspect
#        Type_fn
#        Offense
#        Manner
#        Means
#        Purpose
#        Source_of_legal_authority
#        Co-participant
#        Event
#        Agent
#        Instrument
#        Patient
#        Explanation
#        Degree
#        Event_description
#
#
# schema Arriving
#     subcase of Eventive_affecting
#     roles
#        Theme: Entity
#        Source
#        Path
#        Goal
#        Manner
#        Means
#        Mode_of_transportation
#        Cotheme
#        Time
#        New_situation
#        Depictive
#        Period_of_iterations
#        Circumstances
#        Purpose
#        Degree
#        Event_description
#        Re-encoding
#        Frequency
#        Place
#        Event
#        Explanation
#        Entity
#
#
# schema Arson
#     subcase of Offenses
#     evokes Intentionally_affect as intentionally_affect
#     evokes Setting_fire as setting_fire
#     roles
#        Degree
#        Depictive
#        Offense
#        Manner
#        Means
#        Purpose
#        Duration
#        Place
#        Time
#        Perpetrator
#        Victim
#        Frequency
#        Explanation
#        Specification
#        Punishment
#
#
# schema Artifact
#     subcase of Entity
#     evokes Using as using
#     roles
#        Artifact
#        Use
#        Creator
#        Time_of_creation
#        Name
#        Type_fn
#        Material
#        Constituent_parts
#        Formational_cause
#        Entity
#
#
# schema Artifact_subpart
#     roles
#        Component
#        Artifact
#        Function
#        Material
#        Creator
#        Time_of_creation
#
#
# schema Artificiality
#     subcase of Gradable_attributes
#     roles
#        Entity
#        Reference_category
#        Degree
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#
#
# schema Artistic_style
#     evokes Aesthetics as aesthetics
#     roles
#        Artist
#        Artwork
#        Form_fn
#        Time
#        Descriptor
#
#
# schema Assemble
#     subcase of Come_together, Intentionally_act
#     roles
#        Individuals
#        Group
#        Party_1
#        Party_2
#        Manner
#        Place
#        Means
#        Time
#        Purpose
#        Configuration
#        Iterations
#        Frequency
#        Topic
#        Explanation
#        Particular_iteration
#        Act
#        Agent
#        Domain
#        Period_of_iterations
#        Result
#        Event_description
#
#
# schema Assessing
#     subcase of Cogitation
#     roles
#        Assessor
#        Phenomenon
#        Value
#        Feature_fn
#        Evidence
#        Manner
#        Method
#        Means
#        Time
#        Standard
#        Purpose
#        Place
#        Medium
#        Co-participant
#        Frequency
#        Beneficiary
#        Depictive
#        Degree
#        Circumstances
#        Result
#        Duration
#        Explanation
#        Cognizer
#        Topic
#
#
# schema Assigned_location
#     subcase of Locale
#     evokes Being_obligated as being_obligated
#     roles
#        Station
#        Constituent_parts
#        Relative_location
#        Formational_cause
#        Container_possessor
#        Descriptor
#        Related_event
#        Task
#        Responsible_party
#        Locale
#        Name
#        Inherent_purpose
#
#
# schema Assistance
#     subcase of Intentionally_act
#     evokes Intentionally_act as intentionally_act
#     roles
#        Benefited_party
#        Helper
#        Goal
#        Focal_entity
#        Time
#        Place
#        Manner
#        Means
#        Instrument
#        Domain
#        Degree
#        Duration
#        Purpose
#        Frequency
#        Explanation
#        Act
#        Agent
#        Period_of_iterations
#        Result
#        Particular_iteration
#        Event_description
#
#
# schema Asymmetric_reciprocality
#     roles
#        Protagonist_1
#        Protagonist_2
#
#
# schema Atonement
#     subcase of Intentionally_act
#     evokes Forgiveness as forgiveness
#     roles
#        Agent
#        Wrong
#        Amends
#        Degree
#        Purpose
#        Manner
#        Time
#        Place
#        Act
#        Means
#        Domain
#        Frequency
#        Period_of_iterations
#        Result
#        Particular_iteration
#        Explanation
#        Event_description
#
#
# schema Attaching
#     subcase of Intentionally_affect
#     evokes Becoming_attached as becoming_attached
#     roles
#        Agent
#        Item
#        Result
#        Goal
#        Connector
#        Items
#        Handle
#        Means
#        Manner
#        Place
#        Purpose
#        Time
#        Instrument
#        Degree
#        Frequency
#        Period_of_iterations
#        Duration
#        Event
#        Patient
#        Explanation
#        Event_description
#
#
# schema Attack
#     subcase of Intentionally_affect
#     roles
#        Victim
#        Weapon
#        Assailant
#        Manner
#        Means
#        Place
#        Purpose
#        Explanation
#        Time
#        Source
#        Depictive
#        Re-encoding
#        Result
#        Containing_event
#        Particular_iteration
#        Circumstances
#        Iterations
#        Event_description
#        Path
#        Frequency
#        Duration
#        Direction
#        Event
#        Agent
#        Instrument
#        Patient
#        Degree
#
#
# schema Attempt
#     roles
#        Agent
#        Goal
#        Outcome
#        Means
#        Effort
#        Time
#        Depictive
#        Place
#        Manner
#        Duration
#        Purpose
#        Particular_iteration
#        Circumstances
#        Domain
#        Condition
#        Frequency
#        Explanation
#
#
# schema Attempting_scenario
#     subcase of Intentionally_act
#     roles
#        Agent
#        Goal
#        Outcome
#        Means
#        Time
#        Place
#        Duration
#        Manner
#        Purpose
#        Act
#        Domain
#        Frequency
#        Period_of_iterations
#        Result
#        Particular_iteration
#        Explanation
#        Event_description
#
#
# schema Attempt_distant_interaction_scenario
#     subcase of Attempting_scenario
#     evokes Manipulation as manipulation
#     roles
#        Agent
#        Target
#        Outcome
#        Means
#        Degree
#        Time
#        Depictive
#        Place
#        Manner
#        Duration
#        Purpose
#        Particular_iteration
#        Circumstances
#        Instrument
#        Target_location
#        Goal
#
#
# schema Attempt_means
#     subcase of Attempt
#     roles
#        Agent
#        Goal
#        Outcome
#        Means
#        Degree
#        Time
#        Depictive
#        Place
#        Manner
#        Duration
#        Purpose
#        Particular_iteration
#        Circumstances
#        Domain
#        Frequency
#        Effort
#        Condition
#        Explanation
#
#
# schema Attempt_obtain_food_scenario
#     subcase of Attempting_scenario
#     roles
#        Seeker
#        Food
#        Instrument
#        Duration
#        Manner
#        Means
#        Outcome
#        Place
#        Time
#        Purpose
#        Frequency
#        Degree
#        Ground
#        Particular_iteration
#        Agent
#        Goal
#
#
# schema Attempt_obtain_mineral_scenario
#     subcase of Attempting_scenario
#     roles
#        Agent
#        Outcome
#        Means
#        Time
#        Place
#        Duration
#        Mineral
#        Goal
#        Manner
#        Purpose
#
#
# schema Attempt_suasion
#     subcase of Attempt
#     evokes Communication as communication
#     evokes Subjective_influence as subjective_influence
#     roles
#        Content
#        Addressee
#        Speaker
#        Topic
#        Medium
#        Manner
#        Depictive
#        Means
#        Degree
#        Time
#        Explanation
#        Period_of_iterations
#        Circumstances
#        Group
#        Frequency
#        Re-encoding
#        Place
#        Purpose
#        Salient_entity
#        Role
#        Agent
#        Goal
#        Outcome
#        Effort
#        Duration
#        Particular_iteration
#        Domain
#        Condition
#
#
# schema Attending
#     subcase of Intentionally_act
#     roles
#        Agent
#        Event
#        Manner
#        Means
#        Place
#        Time
#        Circumstances
#        Purpose
#        Frequency
#        Duration
#        Iterations
#        Event_description
#        Act
#        Domain
#        Period_of_iterations
#        Result
#        Particular_iteration
#        Explanation
#
#
# schema Attention
#     subcase of State
#     roles
#        Perceiver
#        Ground
#        Figure
#        Degree
#        Circumstances
#        Manner
#        Expressor
#        Entity
#        State
#
#
# schema Attention_getting
#     evokes Referring_by_name as referring_by_name
#     roles
#        Address_term
#        Interjection
#
#
# schema Attitude_description
#     subcase of Social_behavior_evaluation
#     evokes Emotions as emotions
#     roles
#        Cognizer
#        Attitude
#        State_of_affairs
#        Degree
#        Time
#        Behavior
#        Individual
#        Judge
#
#
# schema Attributed_information
#     evokes Statement as statement
#     roles
#        Proposition
#        Speaker
#        Text
#
#
# schema Attributes
#     roles
#        Entity
#        Attribute
#        Value
#
#
# schema Authority
#     subcase of Influencing_potential
#     roles
#        Agent
#        Theme
#        Domain
#        Source
#        Descriptor
#        Force
#        Entity
#        State_of_affairs
#
#
# schema Avoiding
#     subcase of Intentionally_act
#     roles
#        Agent
#        Place
#        Time
#        Purpose
#        Undesirable_situation
#        Means
#        Manner
#        Circumstances
#        Degree
#        Explanation
#        Act
#        Domain
#        Frequency
#        Period_of_iterations
#        Result
#        Particular_iteration
#        Event_description
#
#
# schema Awareness
#     subcase of Mental_activity
#     evokes Information as information
#     roles
#        Cognizer
#        Content
#        Evidence
#        Topic
#        Degree
#        Manner
#        Expressor
#        Role
#        Paradigm
#        Time
#        Explanation
#        Sentient_entity
#
#
# schema Awareness_situation
#     roles
#        Cognizer
#        Content
#        Expressor
#        Topic
#        Degree
#        Evidence
#        Manner
#        Role
#        Time
#
#
# schema Awareness_status
#     evokes Awareness_situation as awareness_situation
#     roles
#        Cognizer
#        Content
#        Degree
#        Evidence
#        Role
#        Time
#
#
# schema Bail_decision
#     subcase of Intentionally_act
#     evokes Communication as communication
#     roles
#        Accused
#        Judge
#        Status
#        Time
#        Place
#        Manner
#        Means
#        Purpose
#        Act
#        Agent
#        Domain
#        Frequency
#        Period_of_iterations
#        Result
#        Particular_iteration
#        Explanation
#        Event_description
#
#
# schema Bearing_arms
#     subcase of State
#     evokes Weapon as weapon
#     roles
#        Degree
#        Weapon: Artifact
#        Protagonist
#        Place
#        Time
#        Entity
#        State
#
#
# schema Beat_opponent
#     evokes Win_prize as win_prize
#     roles
#        Winner
#        Score
#        Margin
#        Rank
#        Prize
#        Means
#        Manner
#        Time
#        Place
#        Venue
#        Particular_iteration
#        Explanation
#        Period_of_iterations
#        Loser
#        Circumstances
#        Re-encoding
#        Result
#        Iterations
#        Viewpoint
#        Event_description
#        Degree
#        Depictive
#        Competition
#        Frequency
#
#
# schema Become_silent
#     roles
#        Speaker
#        Topic
#        Place
#        Time
#        Expressor
#        Manner
#        Explanation
#
#
# schema Become_triggered
#     roles
#        System
#        Manner
#        Place
#        Time
#        Frequency
#
#
# schema Becoming
#     subcase of Event
#     roles
#        Place
#        Explanation
#        Time
#        Duration_of_final_state
#        Manner
#        Entity
#        Final_state
#        Final_category
#        Transitional_period
#        Explanation
#        Initial_state
#        Circumstances
#        Initial_category
#        Explanation
#        Group
#        Event
#        Duration
#        Frequency
#        Timespan
#
#
# schema Becoming_attached
#     subcase of Becoming
#     roles
#        Connector
#        Handle
#        Item
#        Items
#        Goal
#        Result
#        Manner
#        Place
#        Time
#        Explanation
#        Duration_of_final_state
#        Entity
#        Final_state
#        Final_category
#        Transitional_period
#        Initial_state
#        Circumstances
#        Initial_category
#        Group
#
#
# schema Becoming_aware
#     subcase of Perception
#     roles
#        Cognizer
#        Phenomenon
#        Ground
#        State
#        Evidence
#        Degree
#        Manner
#        Means
#        Topic
#        Time
#        Purpose
#        Instrument
#        Frequency
#        Circumstances
#        Explanation
#        Particular_iteration
#        Period_of_iterations
#        Perceiver
#        Sought_phenomenon
#
#
# schema Becoming_a_member
#     subcase of Intentionally_act
#     roles
#        New_member
#        Place
#        Purpose
#        Time
#        Means
#        Manner
#        Frequency
#        Group
#        Explanation
#        Role
#        Depictive
#        Reciprocation
#        Circumstances
#        Re-encoding
#        Act
#        Agent
#        Domain
#        Period_of_iterations
#        Result
#        Particular_iteration
#        Event_description
#
#
# schema Becoming_detached
#     subcase of Becoming
#     roles
#        Item
#        Source
#        Items
#        Manner
#        Place
#        Time
#        Degree
#        Event_description
#        Explanation
#        Duration_of_final_state
#        Entity
#        Final_state
#        Final_category
#        Transitional_period
#        Initial_state
#        Circumstances
#        Initial_category
#        Group
#
#
# schema Becoming_dry
#     subcase of Becoming
#     roles
#        Entity
#        Degree
#        Manner
#        Place
#        Time
#        Circumstances
#        Concessive
#        Particular_iteration
#        Explanation
#        Duration_of_final_state
#        Final_state
#        Final_category
#        Transitional_period
#        Initial_state
#        Initial_category
#        Group
#
#
# schema Becoming_separated
#     roles
#        Whole
#        Parts
#        Part_1
#        Part_2
#        Criterion
#        Depictive
#        Manner
#        Degree
#        Means
#        Result
#        Time
#        Place
#
#
# schema Becoming_visible
#     subcase of Becoming
#     roles
#        Entity
#        Perceiver
#        Manner
#        Place
#        Time
#        Explanation
#        Duration_of_final_state
#        Final_state
#        Final_category
#        Transitional_period
#        Initial_state
#        Circumstances
#        Initial_category
#        Group
#
#
# schema Behind_the_scenes
#     evokes Performing_arts as performing_arts
#     roles
#        Artist
#        Production
#        Type_fn
#        Distributor
#        Studio
#        Medium
#        Time
#        Place
#        Nationality
#        Purpose
#        Performer
#        Score
#        Scene
#        Manner
#
#
# schema Being_active
#     subcase of Gradable_attributes
#     evokes Activity_ongoing as activity_ongoing
#     roles
#        Duration
#        Activity
#        Place
#        Purpose
#        Time
#        Manner
#        Agent
#        Salient_entity
#        Role
#        Degree
#        Event_description
#        Frequency
#        Depictive
#        Circumstances
#        Explanation
#        Iterations
#        Entity
#        Attribute
#        Value
#
#
# schema Being_attached
#     subcase of Reciprocality, State
#     roles
#        Connector
#        Handle
#        Item
#        Items
#        Goal
#        Dependent_state
#        Manner
#        Protagonist_1
#        Protagonist_2
#        Protagonists
#        Entity
#        State
#
#
# schema Being_at_risk
#     subcase of Gradable_attributes
#     roles
#        Asset
#        Degree
#        Harmful_event
#        Dangerous_entity
#        Place
#        Time
#        Explanation
#        Situation_fn
#        Domain
#        Depictive
#        Frequency
#        Duration
#        Entity
#        Attribute
#        Circumstances
#        Value
#
#
# schema Being_awake
#     roles
#        Protagonist
#        Duration
#        Time
#        Place
#        Degree
#        Manner
#
#
# schema Being_born
#     subcase of Coming_to_be
#     roles
#        Child
#        Time
#        Place
#        Relatives
#        Depictive
#        Means
#        Entity
#        Explanation
#        Components
#        Duration_of_final_state
#        Role
#        Period_of_iterations
#        Manner
#
#
# schema Being_detached
#     evokes Being_attached as being_attached
#     roles
#        Item
#        Items
#        Source
#        Manner
#
#
# schema Being_dry
#     subcase of Gradable_attributes
#     roles
#        Item
#        Degree
#        Subregion
#        Entity
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#
#
# schema Being_employed
#     roles
#        Compensation
#        Employee
#        Employer
#        Manner
#        Place_of_employment
#        Position
#        Purpose
#        Task
#        Time
#        Field
#        Duration
#        Rank
#        Type_fn
#        Contract_basis
#        Place
#        Frequency
#        Event_description
#        Circumstances
#        Particular_iteration
#
#
# schema Being_incarcerated
#     subcase of Being_in_captivity
#     roles
#        Prisoner: Entity
#        Prison
#        Authorities
#        Crime
#        Place
#        Time
#        Manner
#        Explanation
#        Duration
#        Theme: Entity
#        Holding_location
#        Agent
#        Reciprocation
#        Cause
#
#
# schema Being_included
#     roles
#        Whole
#        Part
#
#
# schema Being_in_captivity
#     evokes Inhibit_movement as inhibit_movement
#     roles
#        Theme: Entity
#        Holding_location
#        Agent
#        Reciprocation
#        Place
#        Time
#        Manner
#        Explanation
#        Duration
#        Cause
#
#
# schema Being_in_category
#     evokes Categorization as categorization
#     roles
#        Cognizer
#        Item
#        Category
#        Criteria
#        Manner
#        Means
#        Time
#        Circumstances
#
#
# schema Being_in_control
#     subcase of Control
#     roles
#        Controlling_entity
#        Dependent_entity
#        Dependent_situation
#        Dependent_variable
#        Degree
#        Time
#        Place
#        Manner
#        Concessive
#        Controlling_variable
#        Controlling_situation
#
#
# schema Being_in_effect
#     evokes Obligation_scenario as obligation_scenario
#     roles
#        Binding_principle
#        Duration
#        Time
#        Place
#        Circumstances
#        Explanation
#        Obligated_party
#        Degree
#
#
# schema Being_in_operation
#     subcase of State
#     evokes Gizmo as gizmo
#     roles
#        Device
#        Time
#        Place
#        Duration
#        Entity
#        State
#
#
# schema Being_located
#     subcase of State
#     evokes Locative_relation as locative_relation
#     roles
#        Theme: Entity
#        Place
#        Dependent_state
#        Time
#        Location
#        Cotheme
#        Depictive
#        Entity
#        State
#
#
# schema Being_named
#     roles
#        Name
#        Entity
#        Language
#        Type_fn
#        Descriptor
#        Context
#        Etymological_root
#
#
# schema Being_necessary
#     roles
#        Dependent
#        Requirement
#        Degree
#        Time
#        Condition
#        Domain
#        Place
#        Dependent_individual
#        Required_entity
#        Descriptor
#        Explanation
#
#
# schema Being_obligated
#     roles
#        Responsible_party
#        Duty
#        Condition
#        Consequence
#        Time
#        Place
#        Frequency
#
#
# schema Being_obligatory
#     roles
#        Condition
#        Consequence
#        Duty
#        Responsible_party
#        Time
#        Place
#        Purpose
#        Explanation
#
#
# schema Being_operational
#     subcase of Capability
#     evokes Render_nonfunctional as render_nonfunctional
#     evokes Artifact as artifact
#     roles
#        Object
#        Degree
#        Entity
#        Event
#        Circumstances
#        Explanation
#        Relevant_feature
#        Status
#        Role
#        Time
#        Frequency
#
#
# schema Being_pregnant
#     roles
#        Mother
#        Father
#        Parents
#        Offspring
#        Duration
#
#
# schema Being_relevant
#     subcase of Cognitive_connection
#     roles
#        Phenomenon
#        Endeavor
#        Cognizer
#        Degree
#        Specification
#        Concept_1
#        Concept_2
#        Point_of_view
#        Circumstances
#        Concepts
#
#
# schema Being_rotted
#     subcase of Gradable_attributes
#     evokes Being_wet as being_wet
#     roles
#        Patient
#        Degree
#        Entity
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#
#
# schema Being_strong
#     subcase of Gradable_attributes
#     roles
#        Entity
#        Degree
#        Manner
#        Means
#        Place
#        Time
#        Purpose
#        Force
#        Circumstances
#        Depictive
#        Attribute
#        Value
#
#
# schema Being_up_to_it
#     subcase of Capability
#     roles
#        Entity
#        Activity
#        Degree
#        Circumstances
#        Explanation
#        Relevant_feature
#        Event
#        Status
#        Role
#        Time
#        Frequency
#
#
# schema Being_wet
#     subcase of Gradable_attributes
#     roles
#        Item
#        Liquid
#        Degree
#        Explanation
#        Subregion
#        Entity
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#
#
# schema Besieging
#     subcase of Attack
#     roles
#        Assailant
#        Victim
#        Manner
#        Means
#        Place
#        Purpose
#        Source
#        Time
#        Weapon
#        Path
#        Duration
#        Explanation
#        Depictive
#        Re-encoding
#        Result
#        Containing_event
#        Particular_iteration
#        Circumstances
#        Iterations
#        Event_description
#        Frequency
#        Direction
#
#
# schema Beyond_compare
#     evokes Surpassing as surpassing
#     roles
#        Standard
#        Variable
#        Competitors
#        Domain
#
#
# schema Be_in_agreement_on_action
#     evokes Make_agreement_on_action as make_agreement_on_action
#     roles
#        Party_1
#        Party_2
#        Obligation
#        Topic
#        Medium
#        Parties
#        Place
#        Time
#        Manner
#        Circumstances
#        Degree
#        Duration
#        Descriptor
#
#
# schema Be_in_agreement_on_assessment
#     subcase of Similarity
#     evokes Opinion as opinion
#     roles
#        Cognizers
#        Cognizer_1
#        Cognizer_2
#        Question
#        Degree
#        Time
#        Place
#        Manner
#        Explanation
#        Depictive
#        Opinion
#        Topic
#        Circumstances
#        Entities
#        Entity_1
#        Entity_2
#        Dimension
#        Differentiating_fact
#
#
# schema Be_on_alert
#     subcase of Activity_ready_state
#     roles
#        Protagonist
#        Activity
#        Time
#        Result
#        Duration
#        Degree
#        Danger
#        Dangerous_entity
#        Salient_entity
#
#
# schema Be_subset_of
#     subcase of Being_included
#     roles
#        Total
#        Part
#        Frequency
#        Contrast_set
#        Subregion
#        Explanation
#        Manner
#        Time
#        Place
#        Whole
#
#
# schema Be_translation_equivalent
#     evokes Translating as translating
#     roles
#        Source_symbol
#        Source_representation
#        Time
#        Circumstances
#        Target_symbol
#        Target_representation
#        Content
#        Equivalence
#        Medium
#
#
# schema Biological_area
#     subcase of Locale
#     roles
#        Constituent_parts
#        Container_possessor
#        Formational_cause
#        Locale
#        Name
#        Relative_location
#        Descriptor
#        Related_event
#        Inherent_purpose
#
#
# schema Biological_classification
#     subcase of Type
#     evokes Biological_entity as biological_entity
#     roles
#        Rank
#        Member: Biological_entity
#        Subtype
#        Property
#        Category
#        Type_property
#        Item_property
#
#
# schema Biological_entity
#     subcase of Entity
#     roles
#        Organism
#        Descriptor
#        Origin
#        Constituent_parts
#        Formational_cause
#        Name
#        Entity
#        Type_fn
#
#
# schema Biological_mechanisms
#     roles
#        Trigger
#        Systemic_effect
#        Place
#
#
# schema Biological_urge
#     subcase of Gradable_attributes
#     roles
#        Degree
#        Experiencer
#        Time
#        Place
#        Expressor
#        Duration
#        Explanation
#        State
#        Parameter
#        Entity
#        Attribute
#        Circumstances
#        Value
#
#
# schema Birth_scenario
#     subcase of Event
#     roles
#        Offspring
#        Mother
#        Father
#        Parents
#        Time
#        Place
#        Manner
#        Event
#        Explanation
#        Duration
#        Frequency
#        Timespan
#
#
# schema Board_vehicle
#     evokes Ride_vehicle as ride_vehicle
#     roles
#        Traveller
#        Vehicle
#        Source
#        Manner
#        Path
#        Duration_of_final_state
#        Depictive
#        Time
#        Cotheme
#        Purpose
#        Place
#        Circumstances
#
#
# schema Body_decoration
#     subcase of Artifact
#     evokes Observable_body_parts as observable_body_parts
#     roles
#        Body_location
#        Decorated_individual
#        Decoration: Artifact
#        Decoration_descriptor
#        Picture
#        Use
#        Type_fn
#        Artifact
#        Creator
#        Time_of_creation
#        Name
#        Material
#
#
# schema Body_description_holistic
#     subcase of Gradable_attributes
#     roles
#        Degree
#        Individual
#        Figure
#        Entity
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#
#
# schema Body_description_part
#     subcase of Gradable_attributes
#     evokes Observable_body_parts as observable_body_parts
#     roles
#        Individual
#        Figure
#        Degree
#        Entity
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#
#
# schema Body_mark
#     subcase of Physical_entity
#     evokes Observable_body_parts as observable_body_parts
#     roles
#        Attachment
#        Body_mark: Artifact
#        Descriptor
#        Possessor
#        Cause
#        Type_fn
#        Constituents_fn
#        Entity
#        Formational_cause
#        Name
#        Place
#
#
# schema Body_movement
#     evokes Motion as motion
#     evokes Observable_body_parts as observable_body_parts
#     roles
#        Agent
#        Body_part
#        Internal_cause
#        External_cause
#        Addressee
#        Source
#        Path
#        Goal
#        Area
#        Degree
#        Depictive
#        Manner
#        Result
#        Message
#        Time
#        Subregion
#        Purpose
#        Cognate_event
#        Duration
#        Place
#        Re-encoding
#        Coordinated_event
#
#
# schema Bond_maturation
#     evokes Repayment as repayment
#     roles
#        Financial_instrument
#        Time
#        Issuer
#        Holder
#        Value
#        Principle
#        Interest
#
#
# schema Borrowing
#     subcase of Receiving
#     roles
#        Borrower
#        Duration
#        Lender
#        Theme
#        Purpose
#        Time
#        Means_of_transfer
#        Place
#        Manner
#        Recipient
#        Donor
#        Purpose_of_donor
#        Means
#        Mode_of_transfer
#        Depictive
#        Countertransfer
#        Path
#        Purpose_of_theme
#        Role
#
#
# schema Boundary
#     roles
#        Boundary
#        Entity
#        Entities
#        Relative_location
#
#
# schema Bounded_entity
#     subcase of Physical_entity
#     evokes Boundary as boundary
#     evokes Being_located as being_located
#     roles
#        Bounded_area
#        Constituent_parts
#        Relative_location
#        Name
#        Owner
#        Formational_cause
#        Type_fn
#        Constituents_fn
#        Entity
#        Place
#
#
# schema Bounded_region
#     subcase of Image_schema
#     roles
#        Interior
#        Ground
#        Surface
#        Boundary
#        Exterior
#        Profiled_region
#
#
# schema Bragging
#     subcase of Judgment_communication
#     roles
#        Speaker
#        Addressee
#        Topic
#        Manner
#        Means
#        Medium
#        Depictive
#        Time
#        Place
#        Explanation
#        Message
#        Role
#        Expressor
#        Occasion
#        Particular_iteration
#        Internal_cause
#        Degree
#        Communicator
#        Evaluee
#        Reason
#        Result
#        Grounds
#        Extent_of_acclaim
#        Frequency
#
#
# schema Breaking_apart
#     roles
#        Whole
#        Pieces
#        Criterion
#        Manner
#        Time
#        Place
#        Means
#
#
# schema Breaking_off
#     roles
#        Subpart
#        Whole
#        Criterion
#        Time
#        Place
#        Manner
#        Means
#
#
# schema Breaking_out_captive
#     subcase of Intentionally_affect
#     roles
#        Agent
#        Theme: Entity
#        Manner
#        Means
#        Explanation
#        Purpose
#        Place
#        Time
#        Location_of_confinement
#        Concessive
#        Circumstances
#        Event
#        Instrument
#        Patient
#        Degree
#        Event_description
#
#
# schema Breathing
#     evokes Fluidic_motion as fluidic_motion
#     roles
#        Agent
#        Air
#        Goal
#        Manner
#        Means
#        Source
#        Path
#        Degree
#        Depictive
#        Place
#        Duration
#        Distance
#        Instrument
#        Time
#        Internal_cause
#        External_cause
#        Circumstances
#        Purpose
#
#
# schema Bringing
#     evokes Cause_motion as cause_motion
#     evokes Motion as motion
#     roles
#        Agent
#        Goal
#        Source
#        Path
#        Theme: Entity
#        Constant_location
#        Area
#        Depictive
#        Distance
#        Manner
#        Speed
#        Purpose
#        Carrier
#        Means
#        Place
#        Time
#        Explanation
#        Beneficiary
#        Particular_iteration
#        Frequency
#        Degree
#        Co-participant
#        Duration
#        Period_of_iterations
#
#
# schema Building
#     subcase of Intentionally_create
#     roles
#        Agent
#        Instrument
#        Place
#        Purpose
#        Time
#        Means
#        Components
#        Created_entity: Artifact
#        Result
#        Depictive
#        Manner
#        Beneficiary
#        Duration
#        Particular_iteration
#        Descriptor
#        Period_of_iterations
#        Creator
#        Role
#        Co-participant
#
#
# schema Buildings
#     subcase of Artifact
#     evokes Locale_by_use as locale_by_use
#     roles
#        Creator
#        Building: Artifact
#        Function
#        Name
#        Material
#        Time_of_creation
# ...
#     roles
#        Agent
#        Source
#        Path
#        Goal
#        Manner
#        Means
#        Speed
#        Mode_of_transportation
#        Distance
#        Time
#        Place
#        Purpose
#        Theme: Entity
#        Cotheme
#        Frequency
#        Journey
#        Depictive
#        Explanation
#        Duration_of_final_state
#        Iterations
#        Circumstances
#        Re-encoding
#        Containing_event
#        Event_description
#        Event
#        Entity
#      constraints
#        Agent <--> Agent
#        Distance <--> Distance
#        Goal <--> Goal
#        Manner <--> Manner
#        Means <--> Means
#        Mode_of_transportation <--> Mode_of_transportation
#        Path <--> Path
#        Place <--> Place
#        Purpose <--> Purpose
#        Source <--> Source
#        Speed <--> Speed
#        Time <--> Time
#
#
# schema Visitor_scenario
#     roles
#        Agent
#        Entity
#        Purpose
#        Normal_location
#      constraints
#        Agent <--> Agent
#        Entity <--> Entity
#        Normal_location <--> Normal_location
#        Purpose <--> Purpose
#
#
# schema Visit_host
#     subcase of Visitor_scenario
#     roles
#        Visitor
#        Host
#        Purpose
#        Normal_location
#        Host_location
#        Agent
#        Entity
#      constraints
#        Agent <--> Visitor
#        Entity <--> Host
#        Purpose <--> Purpose
#        Normal_location <--> Normal_location
#        Host <--> Host
#        Host_location <--> Host_location
#        Normal_location <--> Normal_location
#        Purpose <--> Purpose
#        Visitor <--> Visitor
#
#
# schema Visit_host_arrival
#     subcase of Visiting_scenario_arrival
#     roles
#        Visitor
#        Normal_location
#        Path
#        Host
#        Manner
#        Means
#        Mode_of_transportation
#        Time
#        Purpose
#        Host_location
#        Place
#        Agent
#        Goal
#        Theme: Entity
#        Source
#        Cotheme
#        New_situation
#        Depictive
#        Period_of_iterations
#        Circumstances
#        Degree
#        Event_description
#        Re-encoding
#        Frequency
#        Event
#        Explanation
#        Entity
#      constraints
#        Manner <--> Manner
#        Means <--> Means
#        Mode_of_transportation <--> Mode_of_transportation
#        Normal_location <--> Normal_location
#        Path <--> Path
#        Purpose <--> Purpose
#        Time <--> Time
#        Goal <--> Host
#        Agent <--> Visitor
#
#
# schema Visit_host_departure
#     subcase of Visiting_scenario_departing
#     roles
#        Visitor
#        Host_location
#        Path
#        Goal
#        Manner
#        Means
#        Speed
#        Mode_of_transportation
#        Distance
#        Time
#        Place
#        Purpose
#        Host
#        Agent
#        Source
#        Theme: Entity
#        Cotheme
#        Frequency
#        Journey
#        Depictive
#        Explanation
#        Duration_of_final_state
#        Iterations
#        Circumstances
#        Re-encoding
#        Containing_event
#        Event_description
#        Event
#        Entity
#      constraints
#        Distance <--> Distance
#        Goal <--> Goal
#        Manner <--> Manner
#        Means <--> Means
#        Mode_of_transportation <--> Mode_of_transportation
#        Path <--> Path
#        Place <--> Place
#        Purpose <--> Purpose
#        Speed <--> Speed
#        Time <--> Time
#        Agent <--> Visitor
#        Source <--> Host
#
#
# schema Visit_host_stay
#     subcase of Visiting_scenario_stay
#     roles
#        Visitor
#        Host
#        Dependent_state
#        Purpose
#        Normal_location
#        Time
#        Duration
#        Manner
#        Place
#        Means
#        Iterations
#        Frequency
#        Host_location
#        Agent
#        Entity: Entity
#      constraints
#        Dependent_state <--> Dependent_state
#        Duration <--> Duration
#        Frequency <--> Frequency
#        Iterations <--> Iterations
#        Manner <--> Manner
#        Means <--> Means
#        Normal_location <--> Normal_location
#        Place <--> Place
#        Purpose <--> Purpose
#        Time <--> Time
#        Agent <--> Visitor
#        Entity <--> Host
#
#
# schema Vocalizations
#     subcase of Sounds
#     roles
#        Sound_source
#        Location_of_sound_source
#        Place
#        Internal_cause
#        Manner
#        Degree
#        Explanation
#        Path
#        Frequency
#        Noisy_event
#        Theme: Entity
#        Ground
#        Themes
#        Component_sound
#      constraints
#        Sound_source <--> Sound_source
#        Location_of_sound_source <--> Location_of_sound_source
#        Place <--> Place
#        Internal_cause <--> Internal_cause
#        Manner <--> Manner
#        Degree <--> Degree
#        Explanation <--> Explanation
#        Path <--> Path
#
#
# schema Volubility
#     subcase of Inclination
#     evokes Communication as communication
#     evokes Social_behavior_evaluation as social_behavior_evaluation
#     roles
#        Speaker
#        Company
#        Text
#        Topic
#        Medium
#        Degree
#        Manner
#        Judge
#        Entity
#        Behavior
#        Basis
#        Containing_event
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#      constraints
#        Degree <--> Degree
#        Entity <--> Speaker
#        communication.Amount_of_information <--> Degree
#        communication.Manner <--> Manner
#        communication.Medium <--> Medium
#        communication.Message <--> Text
#        communication.Topic <--> Topic
#        communication.Communicator <--> Speaker
#        social_behavior_evaluation.Judge <--> Judge
#        social_behavior_evaluation.Individual <--> Speaker
#
#
# schema Wagering
#     evokes Run_risk as run_risk
#     roles
#        Gambler
#        Place
#        Time
#        Asset
#        Frequency
#        Purpose
#        Explanation
#        Iterations
#        Circumstances
#        Beneficiary
#        Outcome
#        Uncertain_situation
#      constraints
#        run_risk.Protagonist <--> Gambler
#        run_risk.Place <--> Place
#        run_risk.Time <--> Time
#        run_risk.Asset <--> Asset
#        run_risk.Frequency <--> Frequency
#        run_risk.Purpose <--> Purpose
#        run_risk.Explanation <--> Explanation
#        run_risk.Iterations <--> Iterations
#        run_risk.Circumstances <--> Circumstances
#        run_risk.Beneficiary <--> Beneficiary
#
#
# schema Waiting
#     evokes Change_event_time as change_event_time
#     evokes Intentionally_act as intentionally_act
#     roles
#        Protagonist
#        Salient_entity
#        Time
#        Place
#        Duration
#        Manner
#        Expected_event
#        End_point
#        Explanation
#        Depictive
#        Purpose
#        Co-participant
#      constraints
#        change_event_time.Manner <--> Manner
#        change_event_time.Place <--> Place
#        change_event_time.Purpose <--> Purpose
#        change_event_time.Time <--> Time
#        change_event_time.Agent <--> Protagonist
#        change_event_time.Explanation <--> Explanation
#        change_event_time.Interval <--> Duration
#        intentionally_act.Manner <--> Manner
#        intentionally_act.Place <--> Place
#        intentionally_act.Agent <--> Protagonist
#
#
# schema Waking_up
#     subcase of Event
#     roles
#        Place
#        Sleeper
#        Time
#        Sleep_state
#        Manner
#        Depictive
#        New_situation
#        Circumstances
#        Particular_iteration
#        Explanation
#        Frequency
#        Event
#        Duration
#        Timespan
#      constraints
#        Manner <--> Manner
#        Place <--> Place
#        Time <--> Time
#
#
# schema Want_suspect
#     evokes Give_impression as give_impression
#     roles
#        Suspect
#        Charges
#        Degree
#      constraints
#        give_impression.Inference <--> Charges
#        give_impression.Phenomenon <--> Suspect
#
#
# schema Warning
#     subcase of Telling
#     roles
#        Speaker
#        Addressee
#        Message
#        Topic
#        Manner
#        Means
#        Medium
#        Time
#        Place
#        Viewpoint
#        Descriptor
#        Iterations
#        Internal_cause
#        Depictive
#        Occasion
#        Particular_iteration
#        Degree
#        Group
#        Event_description
#        Frequency
#        Containing_event
#      constraints
#        Speaker <--> Speaker
#        Addressee <--> Addressee
#        Message <--> Message
#        Topic <--> Topic
#        Manner <--> Manner
#        Means <--> Means
#        Medium <--> Medium
#        Time <--> Time
#        Place <--> Place
#        Viewpoint <--> Viewpoint
#        Descriptor <--> Descriptor
#        Iterations <--> Iterations
#
#
# schema Waver_between_options
#     evokes Choosing as choosing
#     roles
#        Cognizer
#        Explanation
#        Options
#        Place
#        Time
#        Manner
#        Issue
#        Option_1
#        Option_2
#        Duration
#        Frequency
#        Degree
#        Containing_event
#        Circumstances
#      constraints
#        choosing.Cognizer <--> Cognizer
#        choosing.Explanation <--> Explanation
#        choosing.Possibilities <--> Options
#        choosing.Place <--> Place
#        choosing.Time <--> Time
#        choosing.Manner <--> Manner
#        choosing.Topic <--> Issue
#
#
# schema Wealthiness
#     subcase of Gradable_attributes
#     evokes Possession as possession
#     roles
#        Person
#        Institution
#        Degree
#        Type_of_possession
#        Entity
#        Attribute
#        Time
#        Circumstances
#        Value
#        Place
#      constraints
#        Degree <--> Degree
#        Entity <--> Person
#        possession.Owner <--> Person
#        possession.Possession <--> Type_of_possession
#
#
# schema Weapon
#     subcase of Artifact
#     roles
#        Weapon: Artifact
#        Use
#        Type_fn
#        Material
#        Wielder
#        Part
#        Name
#        Time_of_creation
#        Creator
#        Descriptor
#        Artifact
#        Constituent_parts
#        Formational_cause
#        Entity
#      constraints
#        Use <--> Use
#        Artifact <--> Weapon
#        Material <--> Material
#        Type_fn <--> Type_fn
#        Creator <--> Creator
#        Time_of_creation <--> Time_of_creation
#        Name <--> Name
#
#
# schema Wearing
#     evokes Clothing as clothing
#     evokes Observable_body_parts as observable_body_parts
#     evokes Accoutrements as accoutrements
#     roles
#        Wearer
#        Clothing: Artifact
#        Body_part
#        Degree
#        Manner
#        Time
#        Source
#        Intended_wearing_location
#        Purpose
#        Relative_location
#      constraints
#        clothing.Wearer <--> Wearer
#        clothing.Garment <--> Clothing
#        clothing.Body_location <--> Body_part
#        observable_body_parts.Body_part <--> Body_part
#        observable_body_parts.Possessor <--> Wearer
#        accoutrements.Wearer <--> Wearer
#        accoutrements.Accoutrement <--> Clothing
#        accoutrements.Body_location <--> Body_part
#
#
# schema Weather
#     roles
#        Place
#        Time
#        Specification
#
#
# schema Wholes_and_parts
#     subcase of Inclusion_scenario
#     roles
#        Whole
#        Part
#        Manner
#        Time
#        Place
#      constraints
#        Whole <--> Whole
#        Part <--> Part
#        Manner <--> Manner
#        Time <--> Time
#        Place <--> Place
#
#
# schema Willingness
#     evokes Choosing as choosing
#     roles
#        Cognizer
#        Activity
#        Explanation
#        Place
#        Time
#        Purpose
#        Degree
#        Frequency
#      constraints
#        choosing.Cognizer <--> Cognizer
#        choosing.Chosen <--> Activity
#        choosing.Explanation <--> Explanation
#        choosing.Place <--> Place
#        choosing.Time <--> Time
#        choosing.Inherent_purpose <--> Purpose
#
#
# schema Win_prize
#     evokes Finish_competition as finish_competition
#     roles
#        Competitor
#        Score
#        Margin
#        Rank
#        Prize
#        Means
#        Manner
#        Time
#        Place
#        Venue
#        Particular_iteration
#        Competition
#        Explanation
#        Period_of_iterations
#        Opponent
#        Circumstances
#        Re-encoding
#        Result
#        Iterations
#        Viewpoint
#        Event_description
#      constraints
#        finish_competition.Competition <--> Competition
#        finish_competition.Competitor <--> Competitor
#        finish_competition.Manner <--> Manner
#        finish_competition.Margin <--> Margin
#        finish_competition.Means <--> Means
#        finish_competition.Opponent <--> Opponent
#        finish_competition.Particular_iteration <--> Particular_iteration
#        finish_competition.Place <--> Place
#        finish_competition.Prize <--> Prize
#        finish_competition.Rank <--> Rank
#        finish_competition.Score <--> Score
#        finish_competition.Time <--> Time
#        finish_competition.Venue <--> Venue
#        Competition <--> Competition
#        Competitor <--> Competitor
#        Manner <--> Manner
#        Margin <--> Margin
#        Means <--> Means
#        Particular_iteration <--> Particular_iteration
#        Place <--> Place
#        Prize <--> Prize
#        Rank <--> Rank
#        Score <--> Score
#        Time <--> Time
#        Venue <--> Venue
#
#
# schema Withdraw_from_participation
#     evokes Participation as participation
#     roles
#        Participant
#        Activity
#        Explanation
#        Place
#        Time
#        Organization
#        Purpose
#        Means
#        Medium
#        Manner
#      constraints
#        participation.Participant_1 <--> Participant
#        participation.Event <--> Activity
#
#
# schema Within_distance
#     subcase of Locative_relation
#     roles
#        Ground
#        Figure
#        Distance
#        Direction
#        Time
#        Figures
#        Deixis
#        Accessibility
#        Directness
#        Temporal_profile
#        Region_quantification
#        Profiled_region
#        Entity
#        State
#        Trajector
#        Landmark
#      constraints
#        Ground <--> Ground
#        Figure <--> Figure
#        Distance <--> Distance
#
#
# schema Word_relations
#     evokes Linguistic_meaning as linguistic_meaning
#     roles
#        Sign_1
#        Sign_2
#        Signs
#        Circumstances
#      constraints
#        linguistic_meaning.Form_fn <--> Signs
#
#
# schema Work
#     subcase of Attempt
#     roles
#        Agent
#        Goal
#        Outcome
#        Means
#        Degree
#        Time
#        Depictive
#        Place
#        Manner
#        Duration
#        Purpose
#        Particular_iteration
#        Circumstances
#        Domain
#        Salient_entity
#        Frequency
#        Event_description
#        Descriptor
#        Effort
#        Condition
#        Explanation
#      constraints
#        Agent <--> Agent
#        Goal <--> Goal
#        Outcome <--> Outcome
#        Means <--> Means
#        Effort <--> Degree
#        Time <--> Time
#        Depictive <--> Depictive
#        Place <--> Place
#        Manner <--> Manner
#        Duration <--> Duration
#        Purpose <--> Purpose
#        Particular_iteration <--> Particular_iteration
#        Circumstances <--> Circumstances
#        Domain <--> Domain
#
#
# schema Working_a_post
#     subcase of Intentionally_act
#     roles
#        Agent
#        Place
#        Purpose
#        Time
#        Means
#        Manner
#        Frequency
#        Period_of_iterations
#        Result
#        Particular_iteration
#        Explanation
#        Event_description
#        Post
#        Salient_entity
#        Act
#        Domain
#        Event
#        Duration
#        Timespan
#      constraints
#        Agent <--> Agent
#        Place <--> Place
#        Purpose <--> Purpose
#        Time <--> Time
#        Means <--> Means
#        Manner <--> Manner
#        Frequency <--> Frequency
#        Period_of_iterations <--> Period_of_iterations
#        Result <--> Result
#        Particular_iteration <--> Particular_iteration
#        Explanation <--> Explanation
#        Event_description <--> Event_description

# %% [markdown]
# ## Constructions
#
# ### Choose the frame for which you want to make constructions

# %%
all_cxns = ecg_demo2(fn, fnb, frame="Cause_motion")

# %% [markdown]
# **ecg_demo2**
# - Takes in:
#     - FrameNet object (fn) -- keeps track of all the data
#     - FrameNetBuilder object (fnb)  -- creates FrameNet object from XML. Is in Builder.py
#     - frame, e.g. "Motion" (frame)
#
# - Returns: build_cxns_for_frame(frame, fn, fnb, role, pos)
#
#
# **build_cxn_for frame(frame_name, fn, fnb, role_name, pos, filter_value=False)**:
# According to documentataion for this function:
# - Takes in:
#     - frame_name, e.g. "Motion"
#     - FrameNet object (fn)
#     - FrameNetBuilder object (fnb)
#     - role_name: role to modify in types/tokens
#     - pos: lexical unit POS to create tokens for (e.g., "V")
#     - "filter_value" boolean: determines if you want to filter valence patterns
#
# - Returns:
#     - tokens
#     - types
#     - VP valences (non-collapsed) = **valence_patterns**
#     - VP valences (collapsed) = **collapsed_valences**
#     - VP constructions (non-collapsed) = **cxns_all**
#     - vP constructions (collapsed) = **cxns_collapsed**
#
#  **BUT** the actual code indicates that there are also a couple of additional returned items, having to do with prepositions and prepositional phrases (see last 3 dictionary keys):
#
#              returned = dict(tokens=tokens,
#                     types=types,
#                     valence_patterns=valence_patterns,
#                     collapsed_valences=collapsed_valences,
#                     cxns_all=cxns_all,
#                     cxns_collapsed=cxns_collapsed,
#                     pp=pp,
#                     prep_types=prep_types,
#                     prepositions=prepositions)

# %%
help(ecg_demo2)
# Out:
# Help on function ecg_demo2 in module ecg_demo:
#
# ecg_demo2(fn, fnb, frame='Motion', role='Manner', pos='V')
#     Returns dictionary of types/tokens, valence cxns, and prepositions for a frame.

# %% [markdown]
# The ecg_demo2 function produces a dictionary with several different keys:

# %%
all_cxns.keys()
# Out:
# dict_keys(['tokens', 'prep_types', 'collapsed_valences', 'valence_patterns', 'pp', 'types', 'cxns_all', 'prepositions', 'cxns_collapsed'])

# %% [markdown]
# ### Valence patterns
#
# #### Description:
# The **valence_patterns** are the set of group realizations for the current frame.
#
# Each LU is associated with its own set of valence patterns. For a given LU, if two or more annotated sentence share **all** the same elements (e.g. same number and kind of FE/PT/GF constituents') they will be considered instances of the same single valence pattern. But, if the LUs are different, this function will produce separate valence patterns, even if all other aspects of the two valence patterns are the same. **[need to verify this!]**   Consequently, one obvious way to generalize over valence patterns is to collapse patterns in these cases (i.e. generalize over the verbs in given frame).
#
# The valence patterns are based on the FE **group_ realizations** field of the Frame object. This field captures data about which frame elements show up together in which constructional patterns
#
#
# #### Code:
#
# As defined in build_cxns_for_frame: **valence_patterns** = get_valence_patterns(frame)
#
#     def get_valence_patterns(frame):
#         patterns = []
#         for re in frame.group_realizations:
#             patterns += re.valencePatterns
#         return patterns
#
#  This would do the same thing:
#
#     def get_valence_patterns(frame):
#           return [re.valencePatterns for re in frame.group_realizations]

# %%
print("Total number of valence patterns: ", len(all_cxns['valence_patterns']))
print(all_cxns['valence_patterns'])
# Out:
# Total number of valence patterns:  598
# [Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 7
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Distance, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 7
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 7
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 7
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PPing[into], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 7
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PPing[at], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 2
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: catapult.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: , PT: INI, FE: Goal, total: 4
# , Frame: Cause_motion, GF: Dep, PT: Sub, FE: Manner, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 2
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Goal, total: 3
# , Frame: Cause_motion, GF: Dep, PT: NP, FE: Theme, total: 3
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 3
# ]
# LU: chuck.v, Total: 2
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 3
# ]
# LU: chuck.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: , PT: INI, FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Goal, total: 3
# , Frame: Cause_motion, GF: Dep, PT: NP, FE: Theme, total: 3
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[at], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Path, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Path, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 22
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 27
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 3
# ]
# LU: chuck.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[along], FE: Path, total: 9
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 10
# , Frame: Cause_motion, GF: Dep, PT: PP[around], FE: Area, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Handle, total: 5
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Degree, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 4
# , Frame: Cause_motion, GF: , PT: 2nd, FE: Source, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Depictive, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Handle, total: 5
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 2
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 10
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Path, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Dep, PT: PP[along], FE: Path, total: 9
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Dep, PT: PP[up], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: VPto, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Source, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 10
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 2
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 10
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[outside], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[towards], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[up], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[inside], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Time, total: 1
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Handle, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[along], FE: Path, total: 9
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Handle, total: 5
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 4
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 2
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Handle, total: 5
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Source, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 10
# , Frame: Cause_motion, GF: Dep, PT: PP[along], FE: Path, total: 9
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 4
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[along], FE: Path, total: 9
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[past], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[toward], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[along], FE: Path, total: 9
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Result, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 10
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 3
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 10
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 39
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# , Frame: Cause_motion, GF: Dep, PT: PP[during], FE: Time, total: 1
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[around], FE: Area, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Cause, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 14
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 4
# , Frame: Cause_motion, GF: , PT: 2nd, FE: Source, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 38
# ]
# LU: drag.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: , PT: DNI, FE: Area, total: 1
# , Frame: Cause_motion, GF: , PT: INC, FE: Cause, total: 1
# , Frame: Cause_motion, GF: , PT: INI, FE: Goal, total: 1
# , Frame: Cause_motion, GF: , PT: DNI, FE: Initial_state, total: 1
# , Frame: Cause_motion, GF: , PT: INI, FE: Path, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Result, total: 1
# , Frame: Cause_motion, GF: , PT: INI, FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Depictive, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 6
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: , PT: DNI, FE: Goal, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Manner, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Path, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 9
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 6
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 6
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Theme, total: 1
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 9
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 9
# ]
# LU: fling.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: , PT: DNI, FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Goal, total: 2
# , Frame: Cause_motion, GF: Dep, PT: NP, FE: Theme, total: 2
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[about], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[around], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[at], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 4
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 6
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 6
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[like], FE: Manner, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Path, total: 4
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[as], FE: Time, total: 1
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Path, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 9
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Path, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 9
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[at], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Place, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Result, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 9
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 11
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 9
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 51
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 51
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 9
# ]
# LU: fling.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: NP, FE: Distance, total: 2
# , Frame: Cause_motion, GF: , PT: INI, FE: Path, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: NP, FE: Distance, total: 2
# , Frame: Cause_motion, GF: , PT: INI, FE: Path, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 7
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 6
# , Frame: Cause_motion, GF: Dep, PT: PP[up], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[like], FE: Manner, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 7
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: , PT: DNI, FE: Goal, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[with], FE: Manner, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 6
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 7
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 6
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 7
# ]
# LU: hurl.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: , PT: DNI, FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[at], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Path, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Result, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 6
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 5
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 7
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 6
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[after], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[at], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Path, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[towards], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 6
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Path, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 7
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 7
# ]
# LU: hurl.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 30
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[between], FE: Goal, total: 1
# , Frame: Cause_motion, GF: , PT: 2nd, FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Cause, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 7
# ]
# LU: hurl.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: nudge.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: nudge.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[under], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: nudge.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: nudge.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[towards], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: nudge.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 6
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 2
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Path, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 4
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 4
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 4
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 6
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 6
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 4
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 4
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[with], FE: Means, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Path, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 2
# Valences:[Frame: Cause_motion, GF: , PT: INI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: , PT: INI, FE: Path, total: 2
# , Frame: Cause_motion, GF: , PT: INI, FE: Theme, total: 2
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[at], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 12
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Result, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 13
# ]
# LU: pitch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Distance, total: 2
# , Frame: Cause_motion, GF: , PT: INI, FE: Path, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Distance, total: 2
# , Frame: Cause_motion, GF: , PT: INI, FE: Path, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 8
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[like], FE: Manner, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Goal, total: 3
# , Frame: Cause_motion, GF: , PT: DNI, FE: Theme, total: 2
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 2
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 8
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 3
# , Frame: Cause_motion, GF: , PT: DNI, FE: Theme, total: 2
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 3
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 8
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: press.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[across], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[against], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 4
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 8
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 5
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 25
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 8
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 8
# ]
# LU: press.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 17
# , Frame: Cause_motion, GF: Dep, PT: PPing[by], FE: Means, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 32
# ]
# LU: press.v, Total: 1
# ...
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Cause, total: 1
# , Frame: Cause_motion, GF: , PT: DNI, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 2
# ]
# LU: draw.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: pull.v, Total: 3
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Initial_state, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: pull.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[over], FE: Result, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: pull.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Source, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 1
# ]
# LU: drive.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 2
# ]
# LU: move.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 2
# ]
# LU: move.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: VPto, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Time, total: 1
# ]
# LU: move.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: VPto, FE: Cause, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 3
# ]
# LU: force.v, Total: 2
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 3
# ]
# LU: force.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[after], FE: Time, total: 1
# ]
# LU: force.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Cause, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Result, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 2
# ]
# LU: force.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: NP, FE: Time, total: 1
# ]
# LU: attract.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: attract.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: attract.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 2
# , Frame: Cause_motion, GF: , PT: INI, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Time, total: 1
# ]
# LU: attract.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: attract.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Cause, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 1
# ]
# LU: attract.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Agent, total: 1
# , Frame: Cause_motion, GF: , PT: DNI, FE: Area, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Instrument, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 10
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: VPed, FE: Depictive, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[along], FE: Path, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 10
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: NP, FE: Distance, total: 1
# , Frame: Cause_motion, GF: , PT: DNI, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[towards], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 7
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[towards], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: VPing, FE: Instrument, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 7
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 10
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 10
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[like], FE: Manner, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[along], FE: Path, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[with], FE: Manner, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 7
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: VPing, FE: Means, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 7
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 7
# , Frame: Cause_motion, GF: Dep, PT: PP[off], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 8
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 3
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Degree, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[towards], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 3
# , Frame: Cause_motion, GF: , PT: INI, FE: Goal, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[with], FE: Manner, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Cause, total: 3
# , Frame: Cause_motion, GF: Dep, PT: Sfin, FE: Explanation, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 7
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 10
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Cause, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[through], FE: Path, total: 7
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 10
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Cause, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 10
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 11
# ]
# LU: propel.v, Total: 4
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[by], FE: Cause, total: 4
# , Frame: Cause_motion, GF: , PT: INI, FE: Goal, total: 5
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 10
# ]
# LU: propel.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[at], FE: Manner, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Dep, PT: PP[out], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 1
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: DNI, FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[of], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 5
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Time, total: 1
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 4
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[toward], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 8
# ]
# LU: launch.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: DNI, FE: Agent, total: 1
# , Frame: Cause_motion, GF: , PT: DNI, FE: Area, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: VPto, FE: Area, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 1
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Time, total: 2
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 20
# , Frame: Cause_motion, GF: Dep, PT: PP[for], FE: Explanation, total: 1
# , Frame: Cause_motion, GF: Dep, PT: VPto, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 20
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 15
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 20
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 20
# , Frame: Cause_motion, GF: Dep, PT: PP[down], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 2
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 20
# , Frame: Cause_motion, GF: Dep, PT: PP[into], FE: Goal, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 3
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 20
# , Frame: Cause_motion, GF: Dep, PT: PP[onto], FE: Goal, total: 3
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 20
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 15
# , Frame: Cause_motion, GF: , PT: DNI, FE: Theme, total: 1
# ]
# LU: transfer.v, Total: 10
# Valences:[Frame: Cause_motion, GF: , PT: CNI, FE: Agent, total: 20
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 15
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Obj, PT: NP, FE: Depictive, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 15
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 2
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PPing[for], FE: Explanation, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Result, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Time, total: 1
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 15
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 15
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 24
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Time, total: 2
# ]
# LU: transfer.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: DNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: PP[to], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[in], FE: Manner, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: slam.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: slam.v, Total: 1
# Valences:[Frame: Cause_motion, GF: , PT: DNI, FE: Agent, total: 2
# , Frame: Cause_motion, GF: Dep, PT: AVP, FE: Path, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[from], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: slam.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: PP[after], FE: Path, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: slam.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 3
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 5
# ]
# LU: slam.v, Total: 1
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 1
# , Frame: Cause_motion, GF: Dep, PT: PP[on], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 1
# ]
# LU: drop.v]

# %% [markdown]
# ### Collapsed valence patterns
#
# #### Description:
# The collapsed_valences are
#
#
# #### Code:
#   In scripts.py, the function **build_cxns_for_frame** inclues:
#   - collapsed_valences = collapse_valences_to_cxns(frame)
#
# The relevant code for the **collapse_valences_to_cxns** function is in Hypothesized_constructions.py:
#
#
# **Note**: if filter is True, this function collapses the specific PTs for prepositional phrases into a reduced set of PTs that append the relevant FE.  For instance, a case where PT: PP[in] and FE:Goal would be converted to the more general PT: PP-Goal
#
#
#         def collapse_valences_to_cxns(frame, filter=True):
#             all_patterns=[]
#             s = [valence for valence in frame.individual_valences if valence.lexeme.split(".")[1] == "v"]
#
#             #if filter is true, return a reduced list with valence PT changed to more general PT, e.g. "Area-PP" """
#             if filter:
#                 s = filter_by_pp(s)
#
#             # 'sorted'creates a new list that is sorted in descending order (reverse=True)
#             # based on the total number of each valence pattern (key=lambda valence: valence.total)
#             by_total = sorted(s, key=lambda valence: valence.total, reverse=True)
#
#
#             #ValencePattern is an object defined in lexical_units.py
#             # """ Contains a list of valenceUnits (Valence objects), as well as associated
#             #  annotations.This corresponds to a given valence pattern for an FEGroupRealization."""
#
#             #I think this next section identifies valence patterns (units??) that include an "NI"
#             #   phrase type and adds that valenceUnit to the 'initial_pattern' ValencePattern object
#             #  Or, maybe it actually has the opposite function? [What does 'continue' achieve here?]
#             for i in by_total:
#                 initial_pattern = ValencePattern(frame.name, 0, None)
#                 if i.pt in ['INI', 'DNI', 'CNI']:
#                     continue
#                 initial_pattern.add_valenceUnit(i)
#
#                 # collapse_with_seed is in hypothesize_constructions.py
#                 # I think it's purpose is to: (1) filter certain valence patterns out of
#                 # 'by_total', e.g. select only core FEs, and (2) compare the initial_pattern with
#                 # by_total, with the objective of adding certain 'by_total' items to 'initial_pattern'
#                 # BUT, it's unclear to me what sorts of comparisons are actually being made
#
#                 all_patterns.append(collapse_with_seed(initial_pattern, by_total, frame))
#
#             #'filter_collapsed_patterns' removes duplicate patterns from 'all_patterns'
#             return filter_collapsed_patterns(all_patterns)
#
#    **TO DO:  add comments to the above code so it's easier to tell what it's supposed to be doing!!**
#
#    **Also: what do the numbers in the patterns this produces mean??**

# %%
print("Total number of collapsed valence patterns: ", len(all_cxns['collapsed_valences']))
print(all_cxns['collapsed_valences'])
# Out:
# Total number of collapsed valence patterns:  54
# [Total: 1349
# Valences:[Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1281
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 568
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 916
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Theme, total: 185
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1012
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Goal, total: 35
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1378
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Manner, total: 29
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1170
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Path, total: 29
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 660
# Valences:[Frame: Cause_motion, GF: Dep, PT: Area-PP, FE: Area, total: 19
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# ]
# LU: None, Total: 728
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Cause, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1362
# Valences:[Frame: Cause_motion, GF: Dep, PT: Manner-PP, FE: Manner, total: 13
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 374
# Valences:[Frame: Cause_motion, GF: Obj, PT: NP, FE: Goal, total: 10
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1249
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Source, total: 10
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1343
# Valences:[Frame: Cause_motion, GF: Dep, PT: Result-PP, FE: Result, total: 9
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 745
# Valences:[Frame: Cause_motion, GF: Dep, PT: NP, FE: Distance, total: 9
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1334
# Valences:[Frame: Cause_motion, GF: Dep, PT: Cause-PP, FE: Cause, total: 8
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1341
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Result, total: 7
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 737
# Valences:[Frame: Cause_motion, GF: Dep, PT: NP, FE: Theme, total: 6
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1355
# Valences:[Frame: Cause_motion, GF: Dep, PT: Handle-PP, FE: Handle, total: 6
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1355
# Valences:[Frame: Cause_motion, GF: Dep, PT: Instrument-PP, FE: Instrument, total: 6
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 976
# Valences:[Frame: Cause_motion, GF: Dep, PT: AJP, FE: Goal, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: Result-PP, FE: Result, total: 9
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1354
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Time, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1354
# Valences:[Frame: Cause_motion, GF: Dep, PT: Time-PP, FE: Time, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1354
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Distance, total: 5
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1281
# Valences:[Frame: Cause_motion, GF: Dep, PT: Sfin, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 568
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1346
# Valences:[Frame: Cause_motion, GF: Dep, PT: AJP, FE: Depictive, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: Result-PP, FE: Result, total: 9
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 980
# Valences:[Frame: Cause_motion, GF: Dep, PT: VPto, FE: Goal, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1242
# Valences:[Frame: Cause_motion, GF: , PT: 2nd, FE: Source, total: 3
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1351
# Valences:[Frame: Cause_motion, GF: Dep, PT: Distance-PP, FE: Distance, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1351
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Degree, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1351
# Valences:[Frame: Cause_motion, GF: Dep, PT: Place-PP, FE: Place, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 530
# Valences:[Frame: Cause_motion, GF: Obj, PT: NP, FE: Path, total: 2
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 643
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Area, total: 2
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# ]
# LU: None, Total: 978
# Valences:[Frame: Cause_motion, GF: Dep, PT: PPing[into], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 978
# Valences:[Frame: Cause_motion, GF: Dep, PT: PPing[at], FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: Sub, FE: Manner, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1327
# Valences:[Frame: Cause_motion, GF: , PT: INC, FE: Cause, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: Depictive-PP, FE: Depictive, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1277
# Valences:[Frame: Cause_motion, GF: Dep, PT: AVP, FE: Theme, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 568
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: Means-PP, FE: Means, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: PPing[by], FE: Means, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 978
# Valences:[Frame: Cause_motion, GF: Dep, PT: VPing, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1277
# Valences:[Frame: Cause_motion, GF: Dep, PT: VPing, FE: Theme, total: 1
# , Frame: Cause_motion, GF: Ext, PT: NP, FE: Agent, total: 568
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1327
# Valences:[Frame: Cause_motion, GF: Dep, PT: PPing[by], FE: Agent, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1240
# Valences:[Frame: Cause_motion, GF: Dep, PT: PPing[from], FE: Source, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1327
# Valences:[Frame: Cause_motion, GF: Dep, PT: VPto, FE: Cause, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 365
# Valences:[Frame: Cause_motion, GF: Ext, PT: NP, FE: Goal, total: 1
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 737
# Valences:[Frame: Cause_motion, GF: Dep, PT: NP, FE: Time, total: 1
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: VPed, FE: Depictive, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: Sfin, FE: Explanation, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: VPing, FE: Instrument, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: VPing, FE: Means, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 642
# Valences:[Frame: Cause_motion, GF: Dep, PT: VPto, FE: Area, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# ]
# LU: None, Total: 737
# Valences:[Frame: Cause_motion, GF: Obj, PT: NP, FE: Depictive, total: 1
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Gen, PT: Poss, FE: Theme, total: 5
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: Explanation-PP, FE: Explanation, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None, Total: 1350
# Valences:[Frame: Cause_motion, GF: Dep, PT: PPing[for], FE: Explanation, total: 1
# , Frame: Cause_motion, GF: Obj, PT: NP, FE: Theme, total: 618
# , Frame: Cause_motion, GF: Dep, PT: Goal-PP, FE: Goal, total: 372
# , Frame: Cause_motion, GF: Dep, PT: Path-PP, FE: Path, total: 208
# , Frame: Cause_motion, GF: Dep, PT: Source-PP, FE: Source, total: 110
# , Frame: Cause_motion, GF: Dep, PT: Agent-PP, FE: Agent, total: 23
# , Frame: Cause_motion, GF: Dep, PT: AJP, FE: Result, total: 15
# , Frame: Cause_motion, GF: Dep, PT: Initial_state-PP, FE: Initial_state, total: 3
# ]
# LU: None]

# %% [markdown]
# ### Preposition Constructions -- not confined to local frame
#
# - A separate construction is defined for each prepostion that is an LU in any FrameNet frame.
# - Constructional meaning is identified with the frame evoked by that LU.
# - These constructions are available for all frames -- they are not unique to (and may not even occur in) the current frame
# - **NOTE**: I need to look into how the subcase relations are currently determined

# %%
print(all_cxns['prepositions'])
# Out:
# construction along-Preposition-Locative_relation
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "along"
#      meaning: Locative_relation
#
# construction along-Preposition-Non-gradable_proximity
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "along"
#      meaning: Non-gradable_proximity
#
# construction along-Preposition-Locative_relation
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "along"
#      meaning: Locative_relation
#
# construction along-Preposition-Non-gradable_proximity
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "along"
#      meaning: Non-gradable_proximity
#
# construction onto-Preposition-None
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "onto"
#
#
# construction in-Preposition-Expected_location_of_person
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Expected_location_of_person
#
# construction in-Preposition-Fields
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Fields
#
# construction in-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Interior_profile_relation
#
# construction in-Preposition-Medium
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Medium
#
# construction in-Preposition-Taking_time
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Taking_time
#
# construction in-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Temporal_collocation
#
# construction in-Preposition-Wearing
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Wearing
#
# construction in-Preposition-Expected_location_of_person
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Expected_location_of_person
#
# construction in-Preposition-Fields
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Fields
#
# construction in-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Interior_profile_relation
#
# construction in-Preposition-Medium
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Medium
#
# construction in-Preposition-Taking_time
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Taking_time
#
# construction in-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Temporal_collocation
#
# construction in-Preposition-Wearing
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Wearing
#
# construction upon-Preposition-Spatial_contact
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "upon"
#      meaning: Spatial_contact
#
# construction upon-Preposition-Spatial_contact
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "upon"
#      meaning: Spatial_contact
#
# construction round-Preposition-None
#     subcase of Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "round"
#
#
# construction below-Preposition-Directional_locative_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "below"
#      meaning: Directional_locative_relation
#
# construction below-Preposition-Directional_locative_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "below"
#      meaning: Directional_locative_relation
#
# construction against-Preposition-Spatial_contact
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "against"
#      meaning: Spatial_contact
#
# construction against-Preposition-Taking_sides
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "against"
#      meaning: Taking_sides
#
# construction against-Preposition-Spatial_contact
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "against"
#      meaning: Spatial_contact
#
# construction against-Preposition-Taking_sides
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "against"
#      meaning: Taking_sides
#
# construction above-Preposition-Directional_locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "above"
#      meaning: Directional_locative_relation
#
# construction above-Preposition-Directional_locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "above"
#      meaning: Directional_locative_relation
#
# construction with-Preposition-Accompaniment
#     subcase of Manner-Preposition, Means-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "with"
#      meaning: Accompaniment
#
# construction with-Preposition-Have_associated
#     subcase of Manner-Preposition, Means-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "with"
#      meaning: Have_associated
#
# construction with-Preposition-Accompaniment
#     subcase of Manner-Preposition, Means-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "with"
#      meaning: Accompaniment
#
# construction with-Preposition-Have_associated
#     subcase of Manner-Preposition, Means-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "with"
#      meaning: Have_associated
#
# construction from-Preposition-Evidence
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Evidence
#
# construction from-Preposition-Origin
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Origin
#
# construction from-Preposition-Time_vector
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Time_vector
#
# construction from-Preposition-Evidence
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Evidence
#
# construction from-Preposition-Origin
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Origin
#
# construction from-Preposition-Time_vector
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Time_vector
#
# construction within-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Interior_profile_relation
#
# construction within-Preposition-Temporal_collocation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Temporal_collocation
#
# construction within-Preposition-Within_distance
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Within_distance
#
# construction within-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Interior_profile_relation
#
# construction within-Preposition-Temporal_collocation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Temporal_collocation
#
# construction within-Preposition-Within_distance
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Within_distance
#
# construction past-Preposition-Locative_relation
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "past"
#      meaning: Locative_relation
#
# construction past-Preposition-Locative_relation
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "past"
#      meaning: Locative_relation
#
# construction by-Preposition-Means
#     subcase of Agent-Preposition, Cause-Preposition, Handle-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "by"
#      meaning: Means
#
# construction by-Preposition-Non-gradable_proximity
#     subcase of Agent-Preposition, Cause-Preposition, Handle-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "by"
#      meaning: Non-gradable_proximity
#
# construction by-Preposition-Means
#     subcase of Agent-Preposition, Cause-Preposition, Handle-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "by"
#      meaning: Means
#
# construction by-Preposition-Non-gradable_proximity
#     subcase of Agent-Preposition, Cause-Preposition, Handle-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "by"
#      meaning: Non-gradable_proximity
#
# construction off-Preposition-Accuracy
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Accuracy
#
# construction off-Preposition-Being_in_operation
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Being_in_operation
#
# construction off-Preposition-Locative_relation
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Locative_relation
#
# construction off-Preposition-Spatial_contact
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Spatial_contact
#
# construction off-Preposition-Accuracy
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Accuracy
#
# construction off-Preposition-Being_in_operation
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Being_in_operation
#
# construction off-Preposition-Locative_relation
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Locative_relation
#
# construction off-Preposition-Spatial_contact
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Spatial_contact
#
# construction over-Preposition-Distributed_position
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Distributed_position
#
# construction over-Preposition-Locative_relation
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Locative_relation
#
# construction over-Preposition-Non-gradable_proximity
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Non-gradable_proximity
#
# construction over-Preposition-Proportional_quantity
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Proportional_quantity
#
# construction over-Preposition-Distributed_position
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Distributed_position
#
# construction over-Preposition-Locative_relation
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Locative_relation
#
# construction over-Preposition-Non-gradable_proximity
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Non-gradable_proximity
#
# construction over-Preposition-Proportional_quantity
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Proportional_quantity
#
# construction at-Preposition-Being_employed
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Being_employed
#
# construction at-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Locative_relation
#
# construction at-Preposition-Spatial_co-location
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Spatial_co-location
#
# construction at-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Temporal_collocation
#
# construction at-Preposition-Being_employed
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Being_employed
#
# construction at-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Locative_relation
#
# construction at-Preposition-Spatial_co-location
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Spatial_co-location
#
# construction at-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Temporal_collocation
#
# construction behind-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "behind"
#      meaning: Non-gradable_proximity
#
# construction behind-Preposition-Responsibility
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "behind"
#      meaning: Responsibility
#
# construction behind-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "behind"
#      meaning: Non-gradable_proximity
#
# construction behind-Preposition-Responsibility
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "behind"
#      meaning: Responsibility
#
# construction of-Preposition-Age
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Age
#
# construction of-Preposition-Origin
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Origin
#
# construction of-Preposition-Partitive
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Partitive
#
# construction of-Preposition-Age
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Age
#
# construction of-Preposition-Origin
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Origin
#
# construction of-Preposition-Partitive
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Partitive
#
# construction under-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "under"
#      meaning: Non-gradable_proximity
#
# construction under-Preposition-Proportional_quantity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "under"
#      meaning: Proportional_quantity
#
# construction under-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "under"
#      meaning: Non-gradable_proximity
#
# construction under-Preposition-Proportional_quantity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "under"
#      meaning: Proportional_quantity
#
# construction up-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "up"
#      meaning: Locative_relation
#
# construction up-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "up"
#      meaning: Locative_relation
#
# construction around-Preposition-Distributed_position
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Distributed_position
#
# construction around-Preposition-Locative_relation
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Locative_relation
#
# construction around-Preposition-Proportional_quantity
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Proportional_quantity
#
# construction around-Preposition-Surrounding
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Surrounding
#
# construction around-Preposition-Temporal_collocation
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Temporal_collocation
#
# construction around-Preposition-Distributed_position
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Distributed_position
#
# construction around-Preposition-Locative_relation
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Locative_relation
#
# construction around-Preposition-Proportional_quantity
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Proportional_quantity
#
# construction around-Preposition-Surrounding
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Surrounding
#
# construction around-Preposition-Temporal_collocation
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Temporal_collocation
#
# construction outside-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "outside"
#      meaning: Interior_profile_relation
#
# construction outside-Preposition-Locative_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "outside"
#      meaning: Locative_relation
#
# construction outside-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "outside"
#      meaning: Interior_profile_relation
#
# construction outside-Preposition-Locative_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "outside"
#      meaning: Locative_relation
#
# construction across-Preposition-Distributed_position
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "across"
#      meaning: Distributed_position
#
# construction across-Preposition-Distributed_position
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "across"
#      meaning: Distributed_position
#
# construction on-Preposition-Accuracy
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Accuracy
#
# construction on-Preposition-Being_in_operation
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Being_in_operation
#
# construction on-Preposition-Means
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Means
#
# construction on-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Non-gradable_proximity
#
# construction on-Preposition-Spatial_contact
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Spatial_contact
#
# construction on-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Temporal_collocation
#
# construction on-Preposition-Topic
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Topic
#
# construction on-Preposition-Accuracy
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Accuracy
#
# construction on-Preposition-Being_in_operation
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Being_in_operation
#
# construction on-Preposition-Means
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Means
#
# construction on-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Non-gradable_proximity
#
# construction on-Preposition-Spatial_contact
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Spatial_contact
#
# construction on-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Temporal_collocation
#
# construction on-Preposition-Topic
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Topic
#
# construction after-Preposition-Relative_time
#     subcase of Path-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "after"
#      meaning: Relative_time
#
# construction after-Preposition-Time_vector
#     subcase of Path-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "after"
#      meaning: Time_vector
#
# construction after-Preposition-Relative_time
#     subcase of Path-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "after"
#      meaning: Relative_time
#
# construction after-Preposition-Time_vector
#     subcase of Path-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "after"
#      meaning: Time_vector
#
# construction between-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "between"
#      meaning: Interior_profile_relation
#
# construction between-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "between"
#      meaning: Interior_profile_relation
#
# construction amongst-Preposition-None
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "amongst"
#
#
# construction down-Preposition-Change_position_on_a_scale
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "down"
#      meaning: Change_position_on_a_scale
#
# construction down-Preposition-Locative_relation
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "down"
#      meaning: Locative_relation
#
# construction down-Preposition-Change_position_on_a_scale
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "down"
#      meaning: Change_position_on_a_scale
#
# construction down-Preposition-Locative_relation
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "down"
#      meaning: Locative_relation
#
# construction out-Preposition-Expected_location_of_person
#     subcase of Source-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "out"
#      meaning: Expected_location_of_person
#
# construction out-Preposition-Locative_relation
#     subcase of Source-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "out"
#      meaning: Locative_relation
#
# construction out-Preposition-Expected_location_of_person
#     subcase of Source-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "out"
#      meaning: Expected_location_of_person
#
# construction out-Preposition-Locative_relation
#     subcase of Source-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "out"
#      meaning: Locative_relation
#
# construction into-Preposition-Goal
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "into"
#      meaning: Goal
#
# construction into-Preposition-Goal
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "into"
#      meaning: Goal
#
# construction through-Preposition-Time_vector
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "through"
#      meaning: Time_vector
#
# construction through-Preposition-Time_vector
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "through"
#      meaning: Time_vector
#
# construction before-Preposition-Time_vector
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "before"
#      meaning: Time_vector
#
# construction before-Preposition-Time_vector
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "before"
#      meaning: Time_vector
#
# construction like-Preposition-Similarity
#     subcase of Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "like"
#      meaning: Similarity
#
# construction like-Preposition-Similarity
#     subcase of Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "like"
#      meaning: Similarity
#
# construction beneath-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "beneath"
#      meaning: Non-gradable_proximity
#
# construction beneath-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "beneath"
#      meaning: Non-gradable_proximity
#
# construction underneath-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "underneath"
#      meaning: Non-gradable_proximity
#
# construction underneath-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "underneath"
#      meaning: Non-gradable_proximity
#
# construction among-Preposition-Be_subset_of
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "among"
#      meaning: Be_subset_of
#
# construction among-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "among"
#      meaning: Interior_profile_relation
#
# construction among-Preposition-Be_subset_of
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "among"
#      meaning: Be_subset_of
#
# construction among-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "among"
#      meaning: Interior_profile_relation
#
# construction as-Preposition-Performers_and_roles
#     subcase of Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "as"
#      meaning: Performers_and_roles
#
# construction as-Preposition-Performers_and_roles
#     subcase of Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "as"
#      meaning: Performers_and_roles
#
# construction for-Preposition-Duration_relation
#     subcase of Distance-Preposition, Explanation-Preposition
#     form
#       constraints
#         self.f.orth <-- "for"
#      meaning: Duration_relation
#
# construction for-Preposition-Taking_sides
#     subcase of Distance-Preposition, Explanation-Preposition
#     form
#       constraints
#         self.f.orth <-- "for"
#      meaning: Taking_sides
#
# construction for-Preposition-Duration_relation
#     subcase of Distance-Preposition, Explanation-Preposition
#     form
#       constraints
#         self.f.orth <-- "for"
#      meaning: Duration_relation
#
# construction for-Preposition-Taking_sides
#     subcase of Distance-Preposition, Explanation-Preposition
#     form
#       constraints
#         self.f.orth <-- "for"
#      meaning: Taking_sides
#
# construction inside-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "inside"
#      meaning: Interior_profile_relation
#
# construction inside-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "inside"
#      meaning: Interior_profile_relation
#
# construction to-Preposition-Goal
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "to"
#      meaning: Goal
#
# construction to-Preposition-Locative_relation
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "to"
#      meaning: Locative_relation
#
# construction to-Preposition-Goal
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "to"
#      meaning: Goal
#
# construction to-Preposition-Locative_relation
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "to"
#      meaning: Locative_relation
#
# construction towards-Preposition-None
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "towards"
#
#
# construction during-Preposition-Temporal_collocation
#     subcase of Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "during"
#      meaning: Temporal_collocation
#
# construction during-Preposition-Temporal_collocation
#     subcase of Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "during"
#      meaning: Temporal_collocation
#
# construction away-Preposition-None
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "away"
#
#
# construction beyond-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "beyond"
#      meaning: Locative_relation
#
# construction beyond-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "beyond"
#      meaning: Locative_relation
#
# construction about-Preposition-Proportional_quantity
#     subcase of Goal-Preposition, Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "about"
#      meaning: Proportional_quantity
#
# construction about-Preposition-Topic
#     subcase of Goal-Preposition, Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "about"
#      meaning: Topic
#
# construction about-Preposition-Proportional_quantity
#     subcase of Goal-Preposition, Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "about"
#      meaning: Proportional_quantity
#
# construction about-Preposition-Topic
#     subcase of Goal-Preposition, Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "about"
#      meaning: Topic
#
# construction toward-Preposition-None
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "toward"

# %% [markdown]
# ### Prepositions that occur in annotation for the current frame(??)
#
# **NOTE**: I need to determine how these are defined

# %%
print(all_cxns['prep_types'])
# Out:
# general construction Distance-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Cause-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Handle-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Time-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Depictive-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Place-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Time-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Cause-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Means-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Distance-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Instrument-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Instrument-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Area-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Place-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Instrument-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Handle-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Cause-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Initial_state-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Time-Preposition
# 	 subcase of Preposition
#
#
# general construction Cause-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Time-Preposition
# 	 subcase of Preposition
#
#
# general construction Agent-Preposition
# 	 subcase of Preposition
#
#
# general construction Cause-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Instrument-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Explanation-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Result-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Time-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition
#
#
# general construction Manner-Preposition
# 	 subcase of Preposition
#
#
# general construction Path-Preposition
# 	 subcase of Preposition
#
#
# general construction Source-Preposition
# 	 subcase of Preposition
#
#
# general construction Goal-Preposition
# 	 subcase of Preposition

# %%
print(all_cxns['prepositions'])
# Out:
# construction along-Preposition-Locative_relation
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "along"
#      meaning: Locative_relation
#
# construction along-Preposition-Non-gradable_proximity
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "along"
#      meaning: Non-gradable_proximity
#
# construction along-Preposition-Locative_relation
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "along"
#      meaning: Locative_relation
#
# construction along-Preposition-Non-gradable_proximity
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "along"
#      meaning: Non-gradable_proximity
#
# construction onto-Preposition-None
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "onto"
#
#
# construction in-Preposition-Expected_location_of_person
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Expected_location_of_person
#
# construction in-Preposition-Fields
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Fields
#
# construction in-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Interior_profile_relation
#
# construction in-Preposition-Medium
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Medium
#
# construction in-Preposition-Taking_time
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Taking_time
#
# construction in-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Temporal_collocation
#
# construction in-Preposition-Wearing
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Wearing
#
# construction in-Preposition-Expected_location_of_person
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Expected_location_of_person
#
# construction in-Preposition-Fields
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Fields
#
# construction in-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Interior_profile_relation
#
# construction in-Preposition-Medium
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Medium
#
# construction in-Preposition-Taking_time
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Taking_time
#
# construction in-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Temporal_collocation
#
# construction in-Preposition-Wearing
#     subcase of Goal-Preposition, Depictive-Preposition, Manner-Preposition, Path-Preposition, Place-Preposition, Area-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "in"
#      meaning: Wearing
#
# construction upon-Preposition-Spatial_contact
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "upon"
#      meaning: Spatial_contact
#
# construction upon-Preposition-Spatial_contact
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "upon"
#      meaning: Spatial_contact
#
# construction round-Preposition-None
#     subcase of Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "round"
#
#
# construction below-Preposition-Directional_locative_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "below"
#      meaning: Directional_locative_relation
#
# construction below-Preposition-Directional_locative_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "below"
#      meaning: Directional_locative_relation
#
# construction against-Preposition-Spatial_contact
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "against"
#      meaning: Spatial_contact
#
# construction against-Preposition-Taking_sides
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "against"
#      meaning: Taking_sides
#
# construction against-Preposition-Spatial_contact
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "against"
#      meaning: Spatial_contact
#
# construction against-Preposition-Taking_sides
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "against"
#      meaning: Taking_sides
#
# construction above-Preposition-Directional_locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "above"
#      meaning: Directional_locative_relation
#
# construction above-Preposition-Directional_locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "above"
#      meaning: Directional_locative_relation
#
# construction with-Preposition-Accompaniment
#     subcase of Manner-Preposition, Means-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "with"
#      meaning: Accompaniment
#
# construction with-Preposition-Have_associated
#     subcase of Manner-Preposition, Means-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "with"
#      meaning: Have_associated
#
# construction with-Preposition-Accompaniment
#     subcase of Manner-Preposition, Means-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "with"
#      meaning: Accompaniment
#
# construction with-Preposition-Have_associated
#     subcase of Manner-Preposition, Means-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "with"
#      meaning: Have_associated
#
# construction from-Preposition-Evidence
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Evidence
#
# construction from-Preposition-Origin
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Origin
#
# construction from-Preposition-Time_vector
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Time_vector
#
# construction from-Preposition-Evidence
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Evidence
#
# construction from-Preposition-Origin
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Origin
#
# construction from-Preposition-Time_vector
#     subcase of Source-Preposition, Path-Preposition, Result-Preposition, Initial_state-Preposition
#     form
#       constraints
#         self.f.orth <-- "from"
#      meaning: Time_vector
#
# construction within-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Interior_profile_relation
#
# construction within-Preposition-Temporal_collocation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Temporal_collocation
#
# construction within-Preposition-Within_distance
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Within_distance
#
# construction within-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Interior_profile_relation
#
# construction within-Preposition-Temporal_collocation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Temporal_collocation
#
# construction within-Preposition-Within_distance
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "within"
#      meaning: Within_distance
#
# construction past-Preposition-Locative_relation
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "past"
#      meaning: Locative_relation
#
# construction past-Preposition-Locative_relation
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "past"
#      meaning: Locative_relation
#
# construction by-Preposition-Means
#     subcase of Agent-Preposition, Cause-Preposition, Handle-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "by"
#      meaning: Means
#
# construction by-Preposition-Non-gradable_proximity
#     subcase of Agent-Preposition, Cause-Preposition, Handle-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "by"
#      meaning: Non-gradable_proximity
#
# construction by-Preposition-Means
#     subcase of Agent-Preposition, Cause-Preposition, Handle-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "by"
#      meaning: Means
#
# construction by-Preposition-Non-gradable_proximity
#     subcase of Agent-Preposition, Cause-Preposition, Handle-Preposition, Instrument-Preposition
#     form
#       constraints
#         self.f.orth <-- "by"
#      meaning: Non-gradable_proximity
#
# construction off-Preposition-Accuracy
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Accuracy
#
# construction off-Preposition-Being_in_operation
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Being_in_operation
#
# construction off-Preposition-Locative_relation
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Locative_relation
#
# construction off-Preposition-Spatial_contact
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Spatial_contact
#
# construction off-Preposition-Accuracy
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Accuracy
#
# construction off-Preposition-Being_in_operation
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Being_in_operation
#
# construction off-Preposition-Locative_relation
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Locative_relation
#
# construction off-Preposition-Spatial_contact
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "off"
#      meaning: Spatial_contact
#
# construction over-Preposition-Distributed_position
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Distributed_position
#
# construction over-Preposition-Locative_relation
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Locative_relation
#
# construction over-Preposition-Non-gradable_proximity
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Non-gradable_proximity
#
# construction over-Preposition-Proportional_quantity
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Proportional_quantity
#
# construction over-Preposition-Distributed_position
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Distributed_position
#
# construction over-Preposition-Locative_relation
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Locative_relation
#
# construction over-Preposition-Non-gradable_proximity
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Non-gradable_proximity
#
# construction over-Preposition-Proportional_quantity
#     subcase of Distance-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "over"
#      meaning: Proportional_quantity
#
# construction at-Preposition-Being_employed
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Being_employed
#
# construction at-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Locative_relation
#
# construction at-Preposition-Spatial_co-location
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Spatial_co-location
#
# construction at-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Temporal_collocation
#
# construction at-Preposition-Being_employed
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Being_employed
#
# construction at-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Locative_relation
#
# construction at-Preposition-Spatial_co-location
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Spatial_co-location
#
# construction at-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Path-Preposition, Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "at"
#      meaning: Temporal_collocation
#
# construction behind-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "behind"
#      meaning: Non-gradable_proximity
#
# construction behind-Preposition-Responsibility
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "behind"
#      meaning: Responsibility
#
# construction behind-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "behind"
#      meaning: Non-gradable_proximity
#
# construction behind-Preposition-Responsibility
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "behind"
#      meaning: Responsibility
#
# construction of-Preposition-Age
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Age
#
# construction of-Preposition-Origin
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Origin
#
# construction of-Preposition-Partitive
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Partitive
#
# construction of-Preposition-Age
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Age
#
# construction of-Preposition-Origin
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Origin
#
# construction of-Preposition-Partitive
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "of"
#      meaning: Partitive
#
# construction under-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "under"
#      meaning: Non-gradable_proximity
#
# construction under-Preposition-Proportional_quantity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "under"
#      meaning: Proportional_quantity
#
# construction under-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "under"
#      meaning: Non-gradable_proximity
#
# construction under-Preposition-Proportional_quantity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "under"
#      meaning: Proportional_quantity
#
# construction up-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "up"
#      meaning: Locative_relation
#
# construction up-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "up"
#      meaning: Locative_relation
#
# construction around-Preposition-Distributed_position
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Distributed_position
#
# construction around-Preposition-Locative_relation
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Locative_relation
#
# construction around-Preposition-Proportional_quantity
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Proportional_quantity
#
# construction around-Preposition-Surrounding
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Surrounding
#
# construction around-Preposition-Temporal_collocation
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Temporal_collocation
#
# construction around-Preposition-Distributed_position
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Distributed_position
#
# construction around-Preposition-Locative_relation
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Locative_relation
#
# construction around-Preposition-Proportional_quantity
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Proportional_quantity
#
# construction around-Preposition-Surrounding
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Surrounding
#
# construction around-Preposition-Temporal_collocation
#     subcase of Area-Preposition, Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "around"
#      meaning: Temporal_collocation
#
# construction outside-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "outside"
#      meaning: Interior_profile_relation
#
# construction outside-Preposition-Locative_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "outside"
#      meaning: Locative_relation
#
# construction outside-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "outside"
#      meaning: Interior_profile_relation
#
# construction outside-Preposition-Locative_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "outside"
#      meaning: Locative_relation
#
# construction across-Preposition-Distributed_position
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "across"
#      meaning: Distributed_position
#
# construction across-Preposition-Distributed_position
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "across"
#      meaning: Distributed_position
#
# construction on-Preposition-Accuracy
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Accuracy
#
# construction on-Preposition-Being_in_operation
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Being_in_operation
#
# construction on-Preposition-Means
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Means
#
# construction on-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Non-gradable_proximity
#
# construction on-Preposition-Spatial_contact
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Spatial_contact
#
# construction on-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Temporal_collocation
#
# construction on-Preposition-Topic
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Topic
#
# construction on-Preposition-Accuracy
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Accuracy
#
# construction on-Preposition-Being_in_operation
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Being_in_operation
#
# construction on-Preposition-Means
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Means
#
# construction on-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Non-gradable_proximity
#
# construction on-Preposition-Spatial_contact
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Spatial_contact
#
# construction on-Preposition-Temporal_collocation
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Temporal_collocation
#
# construction on-Preposition-Topic
#     subcase of Goal-Preposition, Result-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "on"
#      meaning: Topic
#
# construction after-Preposition-Relative_time
#     subcase of Path-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "after"
#      meaning: Relative_time
#
# construction after-Preposition-Time_vector
#     subcase of Path-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "after"
#      meaning: Time_vector
#
# construction after-Preposition-Relative_time
#     subcase of Path-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "after"
#      meaning: Relative_time
#
# construction after-Preposition-Time_vector
#     subcase of Path-Preposition, Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "after"
#      meaning: Time_vector
#
# construction between-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "between"
#      meaning: Interior_profile_relation
#
# construction between-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "between"
#      meaning: Interior_profile_relation
#
# construction amongst-Preposition-None
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "amongst"
#
#
# construction down-Preposition-Change_position_on_a_scale
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "down"
#      meaning: Change_position_on_a_scale
#
# construction down-Preposition-Locative_relation
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "down"
#      meaning: Locative_relation
#
# construction down-Preposition-Change_position_on_a_scale
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "down"
#      meaning: Change_position_on_a_scale
#
# construction down-Preposition-Locative_relation
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "down"
#      meaning: Locative_relation
#
# construction out-Preposition-Expected_location_of_person
#     subcase of Source-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "out"
#      meaning: Expected_location_of_person
#
# construction out-Preposition-Locative_relation
#     subcase of Source-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "out"
#      meaning: Locative_relation
#
# construction out-Preposition-Expected_location_of_person
#     subcase of Source-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "out"
#      meaning: Expected_location_of_person
#
# construction out-Preposition-Locative_relation
#     subcase of Source-Preposition, Path-Preposition, Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "out"
#      meaning: Locative_relation
#
# construction into-Preposition-Goal
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "into"
#      meaning: Goal
#
# construction into-Preposition-Goal
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "into"
#      meaning: Goal
#
# construction through-Preposition-Time_vector
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "through"
#      meaning: Time_vector
#
# construction through-Preposition-Time_vector
#     subcase of Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "through"
#      meaning: Time_vector
#
# construction before-Preposition-Time_vector
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "before"
#      meaning: Time_vector
#
# construction before-Preposition-Time_vector
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "before"
#      meaning: Time_vector
#
# construction like-Preposition-Similarity
#     subcase of Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "like"
#      meaning: Similarity
#
# construction like-Preposition-Similarity
#     subcase of Manner-Preposition
#     form
#       constraints
#         self.f.orth <-- "like"
#      meaning: Similarity
#
# construction beneath-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "beneath"
#      meaning: Non-gradable_proximity
#
# construction beneath-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "beneath"
#      meaning: Non-gradable_proximity
#
# construction underneath-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "underneath"
#      meaning: Non-gradable_proximity
#
# construction underneath-Preposition-Non-gradable_proximity
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "underneath"
#      meaning: Non-gradable_proximity
#
# construction among-Preposition-Be_subset_of
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "among"
#      meaning: Be_subset_of
#
# construction among-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "among"
#      meaning: Interior_profile_relation
#
# construction among-Preposition-Be_subset_of
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "among"
#      meaning: Be_subset_of
#
# construction among-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "among"
#      meaning: Interior_profile_relation
#
# construction as-Preposition-Performers_and_roles
#     subcase of Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "as"
#      meaning: Performers_and_roles
#
# construction as-Preposition-Performers_and_roles
#     subcase of Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "as"
#      meaning: Performers_and_roles
#
# construction for-Preposition-Duration_relation
#     subcase of Distance-Preposition, Explanation-Preposition
#     form
#       constraints
#         self.f.orth <-- "for"
#      meaning: Duration_relation
#
# construction for-Preposition-Taking_sides
#     subcase of Distance-Preposition, Explanation-Preposition
#     form
#       constraints
#         self.f.orth <-- "for"
#      meaning: Taking_sides
#
# construction for-Preposition-Duration_relation
#     subcase of Distance-Preposition, Explanation-Preposition
#     form
#       constraints
#         self.f.orth <-- "for"
#      meaning: Duration_relation
#
# construction for-Preposition-Taking_sides
#     subcase of Distance-Preposition, Explanation-Preposition
#     form
#       constraints
#         self.f.orth <-- "for"
#      meaning: Taking_sides
#
# construction inside-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "inside"
#      meaning: Interior_profile_relation
#
# construction inside-Preposition-Interior_profile_relation
#     subcase of Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "inside"
#      meaning: Interior_profile_relation
#
# construction to-Preposition-Goal
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "to"
#      meaning: Goal
#
# construction to-Preposition-Locative_relation
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "to"
#      meaning: Locative_relation
#
# construction to-Preposition-Goal
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "to"
#      meaning: Goal
#
# construction to-Preposition-Locative_relation
#     subcase of Goal-Preposition, Result-Preposition
#     form
#       constraints
#         self.f.orth <-- "to"
#      meaning: Locative_relation
#
# construction towards-Preposition-None
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "towards"
#
#
# construction during-Preposition-Temporal_collocation
#     subcase of Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "during"
#      meaning: Temporal_collocation
#
# construction during-Preposition-Temporal_collocation
#     subcase of Time-Preposition
#     form
#       constraints
#         self.f.orth <-- "during"
#      meaning: Temporal_collocation
#
# construction away-Preposition-None
#     subcase of Source-Preposition
#     form
#       constraints
#         self.f.orth <-- "away"
#
#
# construction beyond-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "beyond"
#      meaning: Locative_relation
#
# construction beyond-Preposition-Locative_relation
#     subcase of Goal-Preposition, Path-Preposition
#     form
#       constraints
#         self.f.orth <-- "beyond"
#      meaning: Locative_relation
#
# construction about-Preposition-Proportional_quantity
#     subcase of Goal-Preposition, Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "about"
#      meaning: Proportional_quantity
#
# construction about-Preposition-Topic
#     subcase of Goal-Preposition, Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "about"
#      meaning: Topic
#
# construction about-Preposition-Proportional_quantity
#     subcase of Goal-Preposition, Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "about"
#      meaning: Proportional_quantity
#
# construction about-Preposition-Topic
#     subcase of Goal-Preposition, Area-Preposition
#     form
#       constraints
#         self.f.orth <-- "about"
#      meaning: Topic
#
# construction toward-Preposition-None
#     subcase of Path-Preposition, Goal-Preposition
#     form
#       constraints
#         self.f.orth <-- "toward"

# %% [markdown]
# ### Prepositional Phrase constructions
#
# - These seem to be based on the 'prep_type' constructions that are shown immediately above

# %%
print(all_cxns['pp'])
# Out:
# construction Distance-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Distance-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Cause-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Cause-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Handle-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Handle-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Time-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Time-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Depictive-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Depictive-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Place-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Place-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Time-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Time-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Cause-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Cause-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Means-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Means-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Distance-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Distance-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Instrument-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Instrument-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Instrument-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Instrument-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Area-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Area-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Place-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Place-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Instrument-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Instrument-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Handle-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Handle-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Cause-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Cause-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Initial_state-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Initial_state-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Time-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Time-Preposition
#
# construction Cause-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Cause-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Time-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Time-Preposition
#
# construction Agent-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Agent-Preposition
#
# construction Cause-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Cause-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Instrument-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Instrument-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Explanation-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Explanation-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Result-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Result-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Time-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Time-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition
#
# construction Manner-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Manner-Preposition
#
# construction Path-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Path-Preposition
#
# construction Source-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Source-Preposition
#
# construction Goal-PP
#   subcase of PP
#   constructional
#     constituents
#       prep: Goal-Preposition

# %%
all_cxns.keys()
# Out:
# dict_keys(['tokens', 'prep_types', 'collapsed_valences', 'valence_patterns', 'pp', 'types', 'cxns_all', 'prepositions', 'cxns_collapsed'])

# %% [markdown]
# ### Types
#
# I assume that this is supposed to create a type construction that can then be referred to in the tokens listed in **'tokens'**
#
# **But, this does not seem to be working correctly right now**
#
# In build_cxns_for_frame:
# - types = utils.generate_types(frame, fn, role_name, pos_to_type[pos])
# - pos_to_type = dict(V="LexicalVerbType", N="NounType")

# %%
print(all_cxns['types'])
# Out:
# {'PP[along]': ['Path'], 'PP[onto]': ['Goal'], 'PP[in]': ['Goal', 'Depictive', 'Manner', 'Path', 'Place', 'Area', 'Time'], 'PP[upon]': ['Goal'], 'PP[round]': ['Area'], 'PP[below]': ['Goal'], 'PP[against]': ['Goal'], 'PP[above]': ['Goal', 'Path'], 'PP[with]': ['Manner', 'Means', 'Instrument'], 'PP[from]': ['Source', 'Path', 'Result', 'Initial_state'], 'PP[within]': ['Goal'], 'PP[past]': ['Path'], 'PP[by]': ['Agent', 'Cause', 'Handle', 'Instrument'], 'PP[off]': ['Source'], 'PP[over]': ['Distance', 'Path', 'Goal', 'Result'], 'PP[at]': ['Goal', 'Path', 'Manner'], 'PP[behind]': ['Goal'], 'PP[of]': ['Source'], 'PP[under]': ['Goal'], 'PP[up]': ['Goal', 'Path'], 'PP[around]': ['Area', 'Goal', 'Path'], 'PP[outside]': ['Goal'], 'PP[across]': ['Path', 'Goal'], 'PP[on]': ['Goal', 'Result', 'Time'], 'PP[after]': ['Path', 'Time'], 'PP[between]': ['Goal', 'Path'], 'PP[amongst]': ['Goal'], 'PP[down]': ['Path', 'Goal'], 'PP[out]': ['Source', 'Path', 'Goal', 'Result'], 'PP[into]': ['Goal', 'Result'], 'PP[through]': ['Path'], 'PP[before]': ['Goal'], 'PP[like]': ['Manner'], 'PP[beneath]': ['Goal'], 'PP[underneath]': ['Goal'], 'PP[among]': ['Goal'], 'PP[as]': ['Time'], 'PP[for]': ['Distance', 'Explanation'], 'PP[inside]': ['Goal'], 'PP[to]': ['Goal', 'Result'], 'PP[towards]': ['Goal', 'Path'], 'PP[during]': ['Time'], 'PP[away]': ['Source'], 'PP[beyond]': ['Goal', 'Path'], 'PP[about]': ['Goal', 'Area'], 'PP[toward]': ['Path', 'Goal']}

# %% [markdown]
# ### Tokens
#
# A token is created for each LU in the frame that has the specified POS
# - The pos can be specified as the **pos** argument in the ecg_demo2 function.
# - If not specified, this function will use the default, which is currently set as "V"
#
# The name of the 'Type' cxn for these tokens is the current **frame** name, with 'Type' appended (e.g. MotionType).
#
# The  token string (e.g. "move") is used as the value assigned to the specified schema role (e.g. Manner).
# - This role can be specified as the **role_name** argument in the ecg_demo2 function.
# - If not specified, this function will use the default, which is currently set as "Manner"
#
# In build_cxns_for_frame:
# tokens = utils.generate_tokens(frame, fn, role_name, pos)

# %%
print(all_cxns['tokens'])
# Out:
# cast :: Cause_motionType :: self.m.Manner <-- "cast"
# catapult :: Cause_motionType :: self.m.Manner <-- "catapult"
# chuck :: Cause_motionType :: self.m.Manner <-- "chuck"
# drag :: Cause_motionType :: self.m.Manner <-- "drag"
# fling :: Cause_motionType :: self.m.Manner <-- "fling"
# hurl :: Cause_motionType :: self.m.Manner <-- "hurl"
# nudge :: Cause_motionType :: self.m.Manner <-- "nudge"
# pitch :: Cause_motionType :: self.m.Manner <-- "pitch"
# press :: Cause_motionType :: self.m.Manner <-- "press"
# push :: Cause_motionType :: self.m.Manner <-- "push"
# shove :: Cause_motionType :: self.m.Manner <-- "shove"
# throw :: Cause_motionType :: self.m.Manner <-- "throw"
# thrust :: Cause_motionType :: self.m.Manner <-- "thrust"
# toss :: Cause_motionType :: self.m.Manner <-- "toss"
# tug :: Cause_motionType :: self.m.Manner <-- "tug"
# yank :: Cause_motionType :: self.m.Manner <-- "yank"
# scoot :: Cause_motionType :: self.m.Manner <-- "scoot"
# draw :: Cause_motionType :: self.m.Manner <-- "draw"
# run :: Cause_motionType :: self.m.Manner <-- "run"
# slide :: Cause_motionType :: self.m.Manner <-- "slide"
# pull :: Cause_motionType :: self.m.Manner <-- "pull"
# drive :: Cause_motionType :: self.m.Manner <-- "drive"
# move :: Cause_motionType :: self.m.Manner <-- "move"
# force :: Cause_motionType :: self.m.Manner <-- "force"
# haul :: Cause_motionType :: self.m.Manner <-- "haul"
# attract :: Cause_motionType :: self.m.Manner <-- "attract"
# knock :: Cause_motionType :: self.m.Manner <-- "knock"
# punt :: Cause_motionType :: self.m.Manner <-- "punt"
# roll :: Cause_motionType :: self.m.Manner <-- "roll"
# jerk :: Cause_motionType :: self.m.Manner <-- "jerk"
# propel :: Cause_motionType :: self.m.Manner <-- "propel"
# launch :: Cause_motionType :: self.m.Manner <-- "launch"
# stick :: Cause_motionType :: self.m.Manner <-- "stick"
# transfer :: Cause_motionType :: self.m.Manner <-- "transfer"
# hit :: Cause_motionType :: self.m.Manner <-- "hit"
# slam :: Cause_motionType :: self.m.Manner <-- "slam"
# drop :: Cause_motionType :: self.m.Manner <-- "drop"
# rake :: Cause_motionType :: self.m.Manner <-- "rake"
# spatter :: Cause_fluidic_motionType :: self.m.Manner <-- "spatter"
# splatter :: Cause_fluidic_motionType :: self.m.Manner <-- "splatter"
# splash :: Cause_fluidic_motionType :: self.m.Manner <-- "splash"
# spray :: Cause_fluidic_motionType :: self.m.Manner <-- "spray"
# squirt :: Cause_fluidic_motionType :: self.m.Manner <-- "squirt"
# pump :: Cause_fluidic_motionType :: self.m.Manner <-- "pump"
# drip :: Cause_fluidic_motionType :: self.m.Manner <-- "drip"
# sprinkle :: Cause_fluidic_motionType :: self.m.Manner <-- "sprinkle"
# dribble :: Cause_fluidic_motionType :: self.m.Manner <-- "dribble"
# spew :: Cause_fluidic_motionType :: self.m.Manner <-- "spew"
# spill :: Cause_fluidic_motionType :: self.m.Manner <-- "spill"
# shoot :: Shoot_projectilesType :: self.m.Manner <-- "shoot"
# fire :: Shoot_projectilesType :: self.m.Manner <-- "fire"
# fire off :: Shoot_projectilesType :: self.m.Manner <-- "fire off"
# launch :: Shoot_projectilesType :: self.m.Manner <-- "launch"
# pass :: PassingType :: self.m.Manner <-- "pass"

# %%
all_cxns.keys()
# Out:
# dict_keys(['tokens', 'prep_types', 'collapsed_valences', 'valence_patterns', 'pp', 'types', 'cxns_all', 'prepositions', 'cxns_collapsed'])

# %% [markdown]
# ### Create constructions
# The following command creates constructions for each group frame realization pattern (I think), including the relevant sentence example(s)

# %%
(all_cxns['cxns_all'])
print("Total number of constructions: ", len(all_cxns['cxns_all']))
# Out:
# Total number of constructions:  335183

# %%
print(all_cxns['cxns_all'])
# Out:
# /* [Although official records of dioxins date from the middle of last century , it was an explosion at an Italian chemical plant in Seveso in 1976 that catapulted them into the public arena .
# ] */
# construction Cause_motion_pattern_1
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-into: PP-into [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-into.m
#          self.m.Theme <--> np.m
#
#
# /* [Warning that there was no single mechanism which would catapult Britain to economic strength , Mr Kinnock said : ` Research and development , transport and communications , science , education and training ; they are the priorities .
# ] */
# construction Cause_motion_pattern_2
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-to: PP-to [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-to.m
#          self.m.Theme <--> np.m
#
#
# /* [This roller coaster catapults you over 75ft into the air , then plummets you back to earth at 60mph .
# ] */
# construction Cause_motion_pattern_3
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-over: PP-over [1.0, 0.9]
#         pp-into: PP-into [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Distance <--> pp-over.m
#          self.m.Goal <--> pp-into.m
#          self.m.Theme <--> np.m
#
#
# /* [He swerved and avoided the worst of the impact , but was catapulted on to the bonnet of the car and then on to the pavement .
# ] */
# construction Cause_motion_pattern_4
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-on: PP-on [1.0, 0.9]
#         pp-on: PP-on [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-on.m
#          self.m.Goal <--> pp-on.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [I catapulted the tiny beasts across the creek and into the mud on the far side so that I could have funerals .
# ] */
# construction Cause_motion_pattern_5
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-into: PP-into [1.0, 0.9]
#         pp-across: PP-across [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-into.m
#          self.m.Path <--> pp-across.m
#          self.m.Theme <--> np.m
#
#
# /* [She saw the driver of the car being catapulted out onto his back .
# ] */
# construction Cause_motion_pattern_6
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-onto: PP-onto [1.0, 0.9]
#         pp-out: PP-out [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-onto.m
#          self.m.Source <--> pp-out.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [As discussed above there are assumed to be a number of willing Doom Divers ready and waiting to step forward and be catapulted into the air .
# ] */
# construction Cause_motion_pattern_7
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-into: PP-into [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-into.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Hillary was catapulted to stardom and his life has never been the same since .
# ] */
# construction Cause_motion_pattern_8
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-to: PP-to [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-to.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Once our parents are dead , we are catapulted into becoming the older generation ourselves .
# ] */
# construction Cause_motion_pattern_9
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pping-into: PPing-into [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pping-into.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Anything too technical might catapult him into orbit again .
# , On one occasion William catapulted a lump of metal into a classroom full of pupils and a girl was quite badly injured .
# , Divorce or the death of a husband is enough to catapult a middle-class white woman and her children into poverty .
# ] */
# construction Cause_motion_pattern_10
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-into: PP-into [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-into.m
#          self.m.Theme <--> np.m
#
#
# /* [It catapults grains of sand at passing ants in an attempt to knock them down into the pit and eat them .
# ] */
# construction Cause_motion_pattern_11
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pping-at: PPing-at [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pping-at.m
#          self.m.Theme <--> np.m
#
#
# /* [The three adults seemed to be catapulted from their seats as they ran out into the back yard .
# ] */
# construction Cause_motion_pattern_12
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-from: PP-from [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Source <--> pp-from.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Some were catapulted out of smashed windows , while others were trapped and had to be cut free .
# , The van spun off the road into a school fence and trainee decorator Wayne , of Marrick Road , Park End , was catapulted out of the rear doors .
# ] */
# construction Cause_motion_pattern_13
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-out: PP-out [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Source <--> pp-out.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [They 'd chuck their pitch-forks , just as if they was javelins .
# ] */
# construction Cause_motion_pattern_14
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         ini: INI [1.0, 0.9]
#         sub: Sub [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> ini.m
#          self.m.Manner <--> sub.m
#          self.m.Theme <--> np.m
#
#
# /* [Cameras won , and in chucking my fishing bag ashore , the 4lb breaking-strain cast snapped and the trout was gone .
# ] */
# construction Cause_motion_pattern_15
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> avp.m
#          self.m.Theme <--> np.m
#
#
# /* [` Chuck me a can ! "
# , ` Chuck us a hammer , Cyril , " he shouted down bossily , ` the brickwork 's not too bad .
# ] */
# construction Cause_motion_pattern_16
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         np: NP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> np.m
#          self.m.Theme <--> np.m
#
#
# /* [It 's carbon , it 's not being used as a fuel it 's just being chucked in , to do something with the with the iron ore and why does it put limestone in it ?
# ] */
# construction Cause_motion_pattern_17
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-in: PP-in [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-in.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Odd-Knut makes coffee using the method we have become familiar with -- chuck the coffee in a pot , add snow to taste , boil on the stove , when empty add coffee and/or snow as necessary .
# , There 's a lot to be said for making the trench in autumn , chucking in household waste all winter and replacing the soil in spring .
# ] */
# construction Cause_motion_pattern_18
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-in: PP-in [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-in.m
#          self.m.Theme <--> np.m
#
#
# /* [There is a hollow boom of surf as if some massive object has just been chucked into the sea .
# ] */
# construction Cause_motion_pattern_19
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-into: PP-into [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-into.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [When you chuck the arrow , gravity takes effect and it arches realistically in flight .
# , On duty she strode about looking as if she could not wait to get off duty and chuck a discus .
# , I go to funerals and chuck earth .
# ] */
# construction Cause_motion_pattern_20
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         ini: INI [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> ini.m
#          self.m.Theme <--> np.m
#
#
# /* [There 's a load of pigeons round his feet , all fighting over the bits of bread he chucks them .
# ] */
# construction Cause_motion_pattern_21
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> np.m
#          self.m.Theme <--> np.m
#
#
# /* [Dolly chucked the pack at him .
# ] */
# construction Cause_motion_pattern_22
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-at: PP-at [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-at.m
#          self.m.Theme <--> np.m
#
#
# /* [` Wilhelm wo n't speak to me since I chucked his Filofax in the jacuzzi .
# , You can chuck me in the river , if you like , for all the good I am to meself .
# ] */
# construction Cause_motion_pattern_23
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-in: PP-in [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-in.m
#          self.m.Theme <--> np.m
#
#
# /* [We chucked their livers into a large barrel fastened to the mast ; these were sold for cod-liver oil and the money they fetched was the perquisite of the crew .
# , He chucks it into the sea .
# ] */
# construction Cause_motion_pattern_24
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-into: PP-into [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-into.m
#          self.m.Theme <--> np.m
#
#
# /* [The modern manager establishes his machismo , not by creating a business that can employ thousands , but by buying a business and then chucking all his supposedly supernumerary workers on the dole .
# , If you just chuck it on the floor , then someone s got to come round alter you and pick it up .
# ] */
# construction Cause_motion_pattern_25
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-on: PP-on [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-on.m
#          self.m.Theme <--> np.m
#
#
# /* [She chucks a bath towel to me .
# , In Ancient Rome they 'd have chucked him to the lions .
# , Marie yelled after me to wait but I did n't want to talk to her about it so I chucked my sandwich-box over to her and told her she could eat them for me .
# ] */
# construction Cause_motion_pattern_26
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-to: PP-to [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-to.m
#          self.m.Theme <--> np.m
#
#
# /* [I ca n't afford to keep chucking two quid down the drain .
# ] */
# construction Cause_motion_pattern_27
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-down: PP-down [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Path <--> pp-down.m
#          self.m.Theme <--> np.m
#
#
# /* [You can start by chucking all that hard luck stuff out of the window . "
# , She said she might as well chuck herself out of the window .
# , And then I chucked it out the window .
# ] */
# construction Cause_motion_pattern_28
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-out: PP-out [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-out.m
#          self.m.Theme <--> np.m
#
#
# /* [As he filled her glass again he knocked over the salt cellar and quickly chucked the spilt salt over his left shoulder .
# , You tell me how any of us could have chucked him over the balustrade even if the whole lot of us got together to do it .
# ] */
# construction Cause_motion_pattern_29
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-over: PP-over [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-over.m
#          self.m.Theme <--> np.m
#
#
# /* [Someone had chucked a brick through the gas-mantle on the corner by the Cathedral railings and it had n't been replaced .
# ] */
# construction Cause_motion_pattern_30
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-through: PP-through [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-through.m
#          self.m.Theme <--> np.m
#
#
# /* [Take him away and chuck him off the derrick . "
# ] */
# construction Cause_motion_pattern_31
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-off: PP-off [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Source <--> pp-off.m
#          self.m.Theme <--> np.m
#
#
# /* [I was impressed by the streamlined efficiency of the Surgicentre ( if a little dismayed by the check 'em in , chop it off , chuck 'em out attitude ) .
# ] */
# construction Cause_motion_pattern_32
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-out: PP-out [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Source <--> pp-out.m
#          self.m.Theme <--> np.m
#
#
# /* [I spect someone chucked it off the bridge .
# ] */
# construction Cause_motion_pattern_33
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-off: PP-off [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Source <--> pp-off.m
#          self.m.Theme <--> np.m
#
#
# /* [` He looks like a character who has been chucked out of a Stephen Conroy painting for making too much noise " was one of the more polite comments by the critics .
# ] */
# construction Cause_motion_pattern_34
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-out: PP-out [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Source <--> pp-out.m
#          ed.profiledParticipant <--> self.m.Theme
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Paul follows John , who seems to be dragging his legs along the floor .
# ] */
# construction Cause_motion_pattern_35
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-along: PP-along [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-along.m
#          self.m.Theme <--> np.m
#
#
# /* [He was dragged around by wire flex wrapped round his neck , beaten and threatened with being strangled and having his ears cut off .
# ] */
# construction Cause_motion_pattern_36
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-around: PP-around [1.0, 0.9]
#         pp-by: PP-by [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Area <--> pp-around.m
#          self.m.Handle <--> pp-by.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [There was a little struggle and Osman half dragged himself free .
# ] */
# construction Cause_motion_pattern_37
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [1.0, 0.9]
#         ajp: AJP [1.0, 0.9]
#         2nd: 2nd [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Degree <--> avp.m
#          self.m.Result <--> ajp.m
#          self.m.Source <--> 2nd.m
#          self.m.Theme <--> np.m
#
#
# /* [He also threatened to drag him down the street handcuffed to the bumper of his car .
# ] */
# construction Cause_motion_pattern_38
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         ajp: AJP [1.0, 0.9]
#         pp-down: PP-down [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Depictive <--> ajp.m
#          self.m.Path <--> pp-down.m
#          self.m.Theme <--> np.m
#
#
# /* [` At the last moment she tried to back out but I dragged her back by the elbow .
# ] */
# construction Cause_motion_pattern_39
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [1.0, 0.9]
#         pp-by: PP-by [1.0, 0.9]
#         poss: Poss [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> avp.m
#          self.m.Handle <--> pp-by.m
#          self.m.Theme <--> poss.m
#
#
# /* [Doug is dragged backwards into the chair .
# ] */
# construction Cause_motion_pattern_40
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-into: PP-into [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-into.m
#          self.m.Path <--> avp.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [The men took it in turns to drag Stephen along the tunnel back to the foot of the ladder .
# ] */
# construction Cause_motion_pattern_41
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-to: PP-to [1.0, 0.9]
#         pp-along: PP-along [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-to.m
#          self.m.Path <--> pp-along.m
#          self.m.Theme <--> np.m
#
#
# /* [Have men with oxen drag the barrels up the mountain to a lake with a narrow outlet .
# ] */
# construction Cause_motion_pattern_42
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-to: PP-to [1.0, 0.9]
#         pp-up: PP-up [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-to.m
#          self.m.Path <--> pp-up.m
#          self.m.Theme <--> np.m
#
#
# /* [In one shop I virtually had to drag a sales assistant away from his pressing chat with a colleague to help me .
# ] */
# construction Cause_motion_pattern_43
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vpto: VPto [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#         pp-from: PP-from [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> vpto.m
#          self.m.Source <--> avp.m
#          self.m.Source <--> pp-from.m
#          self.m.Theme <--> np.m
#
#
# /* [I was flung into a police van , and Russell was also dragged in .
# ] */
# construction Cause_motion_pattern_44
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-in: PP-in [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-in.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [I was dragged back into the boat almost immediately .
# , I was dragged back into the boat almost immediately .
# ] */
# construction Cause_motion_pattern_45
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-into: PP-into [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-into.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [We dragged the man free and Warren drove the car at the dogs to box them in the alleyway so they could not escape .
# , Meg dragged her chair close and put her arms around the older woman .
# ] */
# construction Cause_motion_pattern_46
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         ajp: AJP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> ajp.m
#          self.m.Theme <--> np.m
#
#
# /* [When he came round , they dragged him outside and flung him in his night-clothes , into a car and handcuffed him .
# ] */
# construction Cause_motion_pattern_47
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> avp.m
#          self.m.Theme <--> np.m
#
#
# /* [Dragging her into his arms , he pressed his mouth against her neck .
# , You ca n't run with a baby , and I 'm not going to drag my kids into the sort of life I 've been living .
# ] */
# construction Cause_motion_pattern_48
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-into: PP-into [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-into.m
#          self.m.Theme <--> np.m
#
#
# /* [Then I got up and took the two rugs by their corners and dragged them outside the door .
# ] */
# construction Cause_motion_pattern_49
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-outside: PP-outside [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-outside.m
#          self.m.Theme <--> np.m
#
#
# /* [Dexter dragged over a chair and sat down at the desk .
# ] */
# construction Cause_motion_pattern_50
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-over: PP-over [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-over.m
#          self.m.Theme <--> np.m
#
#
# /* [Lucenzo swept over to her , caught her arm and dragged her to the entrance of the ballroom .
# , He was looking pleased with himself as he dragged the table to the side of the room to make space to work in .
# ] */
# construction Cause_motion_pattern_51
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-to: PP-to [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-to.m
#          self.m.Theme <--> np.m
#
#
# /* [Cornelius dragged the portmanteau towards the inn door .
# ] */
# construction Cause_motion_pattern_52
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-towards: PP-towards [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-towards.m
#          self.m.Theme <--> np.m
#
#
# /* [` She bit me last night , " he said , dragging up his trouser-leg and showing her the line of tiny red marks .
# ] */
# construction Cause_motion_pattern_53
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-up: PP-up [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-up.m
#          self.m.Theme <--> np.m
#
#
# /* [If an insect walks by , she grabs it and instantly drags it inside the tunnel .
# ] */
# construction Cause_motion_pattern_54
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-inside: PP-inside [1.0, 0.9]
#         np: NP [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-inside.m
#          self.m.Theme <--> np.m
#          self.m.Time <--> avp.m
#
#
# /* [Round and round they staggered like the end of some ghastly marathon , Luke dragging Maldita upright and along by her headcollar , supporting her with his body , Perdita propping up her other side .
# ] */
# construction Cause_motion_pattern_55
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-by: PP-by [1.0, 0.9]
#         pp-along: PP-along [1.0, 0.9]
#         ajp: AJP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Handle <--> pp-by.m
#          self.m.Path <--> pp-along.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> np.m
#
#
# /* [George dragged her upright by her hair .
# ] */
# construction Cause_motion_pattern_56
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-by: PP-by [1.0, 0.9]
#         ajp: AJP [1.0, 0.9]
#         poss: Poss [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Handle <--> pp-by.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#
#
# /* [Eventually he pulled her off and dragged her away by the scruff of her neck .
# ] */
# construction Cause_motion_pattern_57
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-by: PP-by [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Handle <--> pp-by.m
#          self.m.Source <--> avp.m
#          self.m.Theme <--> np.m
#
#
# /* [A man who nearly died when he was dragged along under a car for a quarter of a mile says he hopes to be leaving hospital soon .
# ] */
# construction Cause_motion_pattern_58
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-along: PP-along [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Path <--> pp-along.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Cornelius dragged his suitcase across the deserted concourse of the grand Victorian station .
# , ` I saw state policemen drag strikers across the road and make them kneel in the ditch there while they held shotguns in their backs .
# , Working dogs -- even those dragging sledges across the snow for days on end -- should not look like hat stands .
# ] */
# construction Cause_motion_pattern_59
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-across: PP-across [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-across.m
#          self.m.Theme <--> np.m
#
#
# /* [One mother , near the Blue Hall estate to the north of Stockton , was dragging her three young kids along a trackside shortcut .
# , Clothes were strewn on the sofa and chairs and Faustina was dragging a silver lame belt along the carpet .
# , With a final burst of furious rain , the sky cleared and I dragged my bag along the road in blinding sunshine .
# , It was an awful noise like little kids you heard in the street when they fell down and their Mums dragged them along the pavement .
# ] */
# construction Cause_motion_pattern_60
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-along: PP-along [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-along.m
#          self.m.Theme <--> np.m
#
#
# /* [And why is Ellie dragging her suitcase out the front door ?
# ] */
# construction Cause_motion_pattern_61
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-out: PP-out [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-out.m
#          self.m.Theme <--> np.m
#
#
# /* [As I left the pen I saw Mr Stokill dragging a large object over the cobbles .
# ] */
# construction Cause_motion_pattern_62
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-over: PP-over [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-over.m
#          self.m.Theme <--> np.m
#
#
# /* [Willie sat dejectedly at the table and watched Tom drag his small mattress past the window .
# ] */
# construction Cause_motion_pattern_63
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-past: PP-past [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-past.m
#          self.m.Theme <--> np.m
#
#
# /* [She dragged a hand through her hair , only too aware of how she must look .
# ] */
# construction Cause_motion_pattern_64
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-through: PP-through [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-through.m
#          self.m.Theme <--> np.m
#
#
# /* [She grabbed Anna 's arm , her fingers sinking into the flesh , and began to drag her toward the car .
# ] */
# construction Cause_motion_pattern_65
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-toward: PP-toward [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-toward.m
#          self.m.Theme <--> np.m
#
#
# /* [Children , boys and girls , were loading small carts to be dragged along by old horses .
# ] */
# construction Cause_motion_pattern_66
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-by: PP-by [1.0, 0.9]
#         pp-along: PP-along [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> pp-by.m
#          self.m.Path <--> pp-along.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Ember dragged her to her feet and she limped stiff-legged through the hatch and on to the landing-ramp .
# ] */
# construction Cause_motion_pattern_67
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-to: PP-to [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Result <--> pp-to.m
#          self.m.Theme <--> np.m
#
#
# /* [He felt himself dragged from the bed , his legs and arms quivering with restlessness .
# ] */
# construction Cause_motion_pattern_68
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-from: PP-from [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Source <--> pp-from.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [This morning he was suddenly dragged out , paraded through the streets , displayed to the public , and then beheaded on Tower Hill .
# , We were dragged out .
# , The bodies of the shot terrorists are dragged out .
# ] */
# construction Cause_motion_pattern_69
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-out: PP-out [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Source <--> pp-out.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [They probably figure the public would n't like them very much if they dragged a sick girl from her bed .
# ] */
# construction Cause_motion_pattern_70
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-from: PP-from [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Source <--> pp-from.m
#          self.m.Theme <--> np.m
#
#
# /* [Lily turned to the mirror and dragged off her hat .
# ] */
# construction Cause_motion_pattern_71
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-off: PP-off [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Source <--> pp-off.m
#          self.m.Theme <--> np.m
#
#
# /* [Mrs. Morgan testified that she had been dragged by her husband from the bedroom which she shared with her small son .
# ] */
# construction Cause_motion_pattern_72
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-by: PP-by [1.0, 0.9]
#         pp-from: PP-from [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> pp-by.m
#          self.m.Source <--> pp-from.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [In fact , her mate Klono had been killed and dragged off by a leopard one night when her son Krono was about a year old .
# ] */
# construction Cause_motion_pattern_73
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-by: PP-by [1.0, 0.9]
#         pp-off: PP-off [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> pp-by.m
#          self.m.Source <--> pp-off.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [The next article that Zach dragged out was a stiff black circular object .
# ] */
# construction Cause_motion_pattern_74
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-out: PP-out [1.0, 0.9]
#         np: NP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Source <--> pp-out.m
#          self.m.Theme <--> np.m
#          self.m.Theme <--> np.m
#
#
# /* [The duty manager had to drag her off the dance-floor during the cabaret show .
# ] */
# construction Cause_motion_pattern_75
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-off: PP-off [1.0, 0.9]
#         np: NP [1.0, 0.9]
#         pp-during: PP-during [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Source <--> pp-off.m
#          self.m.Theme <--> np.m
#          self.m.Time <--> pp-during.m
#
#
# /* [The sky was low and constantly shifting as different layers of grey and black cloud were dragged around by gusty winds .
# ] */
# construction Cause_motion_pattern_76
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-around: PP-around [1.0, 0.9]
#         pp-by: PP-by [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Area <--> pp-around.m
#          self.m.Cause <--> pp-by.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [The crab-like hand reached him , closed around his belt , and began to drag him relentlessly clear .
# ] */
# construction Cause_motion_pattern_77
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [1.0, 0.9]
#         ajp: AJP [1.0, 0.9]
#         2nd: 2nd [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Cause
#          self.m.Manner <--> avp.m
#          self.m.Result <--> ajp.m
#          self.m.Source <--> 2nd.m
#          self.m.Theme <--> np.m
#
#
# /* [] */
# construction Cause_motion_pattern_78
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         dni: DNI [1.0, 0.9]
#         inc: INC [1.0, 0.9]
#         ini: INI [1.0, 0.9]
#         dni: DNI [1.0, 0.9]
#         ini: INI [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#         ini: INI [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Area <--> dni.m
#          self.m.Cause <--> inc.m
#          self.m.Goal <--> ini.m
#          self.m.Initial_state <--> dni.m
#          self.m.Path <--> ini.m
#          self.m.Result <--> avp.m
#          self.m.Source <--> ini.m
#          self.m.Theme <--> np.m
#
#
# /* [When he came round , they dragged him outside and flung him in his night-clothes , into a car and handcuffed him .
# ] */
# construction Cause_motion_pattern_79
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-in: PP-in [1.0, 0.9]
#         pp-into: PP-into [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Depictive <--> pp-in.m
#          self.m.Goal <--> pp-into.m
#          self.m.Theme <--> np.m
#
#
# /* [Young Jack flung his darts in such rapid succession that they were nothing more than a triple blur .
# ] */
# construction Cause_motion_pattern_80
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         dni: DNI [1.0, 0.9]
#         pp-in: PP-in [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> dni.m
#          self.m.Manner <--> pp-in.m
#          self.m.Theme <--> np.m
#
#
# /* [I was standing at one of the windows of the outer office , watching the rain fling itself remorselessly against the panes .
# ] */
# construction Cause_motion_pattern_81
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-against: PP-against [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-against.m
#          self.m.Manner <--> avp.m
#          self.m.Theme <--> np.m
#
#
# /* [The Colonel was flung back against the wall where he stood , for a moment , a puzzled expression on his face .
# ] */
# construction Cause_motion_pattern_82
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-against: PP-against [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-against.m
#          self.m.Path <--> avp.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [He kicked it open and flung me down the three steps into the street .
# ] */
# construction Cause_motion_pattern_83
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-into: PP-into [1.0, 0.9]
#         pp-down: PP-down [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-into.m
#          self.m.Path <--> pp-down.m
#          self.m.Theme <--> np.m
#
#
# /* [With that he snatched up the bottle and flung it through the open window into the yard .
# ] */
# construction Cause_motion_pattern_84
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-into: PP-into [1.0, 0.9]
#         pp-through: PP-through [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-into.m
#          self.m.Path <--> pp-through.m
#          self.m.Theme <--> np.m
#
#
# /* [Air the bed by flinging back the covers for around half an hour every morning
# ] */
# construction Cause_motion_pattern_85
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> avp.m
#          self.m.Theme <--> np.m
#
#
# /* [The force of the casual blow was such that Yet was flung back against a bookcase .
# ] */
# construction Cause_motion_pattern_86
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-against: PP-against [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-against.m
#          self.m.Theme <--> avp.m
#
#
# /* [The room was full of the cheerful clutter of a family on holiday -- books , maps and a camera flung on to the table .
# ] */
# construction Cause_motion_pattern_87
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-on: PP-on [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-on.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [She felt as if she 'd just escaped a raging tornado , flung to one side just in time .
# ] */
# construction Cause_motion_pattern_88
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-to: PP-to [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-to.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [I felt like flinging aside the towel .
# ...
# ] */
# construction Cause_motion_pattern_576
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-from: PP-from [1.0, 0.9]
#         np: NP [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Source <--> pp-from.m
#          self.m.Theme <--> np.m
#          self.m.Time <--> avp.m
#
#
# /* [Berry has said she hopes this movie will launch her into the kind of leading roles that are ( as in Dandridge 's day ) unavailable to black women ; Variety seems to think it will , weighing in with a great review : `` an enthralling biopic ...
# ] */
# construction Cause_motion_pattern_577
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-into: PP-into [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Cause
#          self.m.Goal <--> pp-into.m
#          self.m.Theme <--> np.m
#
#
# /* [The fledgling WB network hopes that this prime-time teen soap opera , alongside its cult hit Buffy the Vampire Slayer , will launch it toward Fox -like legitimacy .
# ] */
# construction Cause_motion_pattern_578
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-toward: PP-toward [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Cause
#          self.m.Goal <--> pp-toward.m
#          self.m.Theme <--> np.m
#
#
# /* [well you get it the way you want it and just perfect and sit back for a while i hope y 'all do n't have to get transferred or anything now that you got it the way you want it
# ] */
# construction Cause_motion_pattern_579
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         dni: DNI [1.0, 0.9]
#         dni: DNI [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> dni.m
#          self.m.Area <--> dni.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [And then , well , we found out that my brother had been admitted , until they took out th , that ( fragment 0 , they let him come , but now he did n't come , he went to , to the department of education and asked a transfer , they did n't deny it to him , they transferred him to another place immediately .
# ] */
# construction Cause_motion_pattern_580
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vpto: VPto [1.0, 0.9]
#         np: NP [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Area <--> vpto.m
#          self.m.Theme <--> np.m
#          self.m.Time <--> avp.m
#
#
# /* [Plants were transferred to growth chambers for ozone ( O 3 ) fumigation ( clean air control plants were transferred to an adjacent chamber under identical conditions except for the O 3 treatment ) .
# ] */
# construction Cause_motion_pattern_581
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-for: PP-for [1.0, 0.9]
#         vpto: VPto [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Explanation <--> pp-for.m
#          self.m.Goal <--> vpto.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [and when i was transferred from Atlanta uh to Houston i i bought a condo in southwest Houston
# ] */
# construction Cause_motion_pattern_582
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-to: PP-to [1.0, 0.9]
#         pp-from: PP-from [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-to.m
#          self.m.Source <--> pp-from.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [and uh then we moved here even when we knew we were being transferred here we became Cowboy fans
# ] */
# construction Cause_motion_pattern_583
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> avp.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [uh well no well my husband was transferred down here
# ] */
# construction Cause_motion_pattern_584
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-down: PP-down [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-down.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Oocytes were transferred into tubes containing Hepes - buffered TCM-199 ( Gibco BRL , Grand Island , NY ) supplemented with 0.57 mM cysteine , 10 ng / ml epidermal growth factor ( Sigma ) , 100 IU / ml penicillin , 100 ?g / ml streptomycin , 0.25 ng / ml amphotericin , 0.01 IU / ml porcine FSH ( Sioux Biochemicals , Sioux Center , IA ) , 0.01 IU / ml porcine LH ( Sioux Biochemicals ) and 0.1% ( w:v ) polyvinyl alcohol ( maturation medium ) [ 50 ] , and shipped to the laboratory overnight ( 20 - 24 h ) at 38 .
# , Then VO 2+- nucleotide complexes were added to purified sCD39 at 1:1 molar ratio , mixed , and incubated for 5 minutes on ice before they were transferred into EPR tubes .
# ] */
# construction Cause_motion_pattern_585
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-into: PP-into [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-into.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [5% SDS-PAGE , transferred onto PVDF membranes ( Bio-rad , Richmond , CA ) , then blocked with 5% BSA and 5% non - fat milk .
# , In male and female rats from experiments 1 and 2 , CALB and COX -2 levels in the frontal cortex and hippocampus ( CALB only ) were determined using Western blot analysis , as reported elsewhere [ 49 55 ] . In brief , homogenized samples ( 30 ?g per lane for frontal cortex and hippocampus- by treatment ) were resolved on 14% Tri -Glycine gels and transferred onto Millipore Immobilon-P membranes ( Millipore , Bedford , MA , USA ) by electroblotting .
# , Isolation of total cellular RNA using a urea / LiCl protocol and gel electrophoresis was performed as described previously [ 65 ] . Gels were transferred onto Amersham Hybond N+ nylon membranes in 20 × SSC and prehybridized in 4 × SSC , 1 × Denhardt 's solution , 0.5% SDS for 2 h at 68°C .
# ] */
# construction Cause_motion_pattern_586
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-onto: PP-onto [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-onto.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [4 M formaldehyde RNA gel and transferred to Hybond N +nylon membrane ( Amersham-Pharmacia , UK ) .
# ] */
# construction Cause_motion_pattern_587
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-to: PP-to [1.0, 0.9]
#         dni: DNI [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-to.m
#          self.m.Theme <--> dni.m
#
#
# /* [Later , in 454 b.c. , the treasury was transferred to Athens and its deposits were used to finance the construction of many of the major buildings and temples of the Classical Age .
# , Some of the earliest constructions were the three Binyang Grottoes , dedicated to an emperor and empress of the Northern Wei Dynasty ( 386 – 534 ) , after the capital was transferred to Luoyang .
# , no we 're just this is only the second place we 've lived we 've only been married for five and a half years and uh we have two small children and he had a uh just got transferred here to E Systems
# , um actually married in Pittsburgh and that 's that 's not what they want to hear on this call uh at any rate we came back here with my husband was transferred around uh up to Minnesota and now back to Texas with T i
# , Plants were transferred to growth chambers for ozone ( O 3 ) fumigation ( clean air control plants were transferred to an adjacent chamber under identical conditions except for the O 3 treatment ) .
# , ds cDNA was extracted with an equal volume of phenol:chloroform : isoamyl alcohol ( 25:24:1 ) , transferred to a Phase Lock Gel   tube ( Eppendorf ) and centrifuged at 16,000 g for 5 min .
# , Samples were resolved by SDS-PAGE ( 9% polyacrylamide ) and electrophoretically transferred to nitrocellulose filters ( BioRad ) .
# , The Washington - based Legal Services Corp. wants the buildings transferred to the S.C.
# , After Vortex - mixing , duplicate 1.8 mL aliquots were transferred to polypropylene tubes and centrifuged for 5 min at 25°C and 14,000 g ( Mikroliter centrifuge , Hettich , Tuttlingen , Germany ) .
# , Forty-eight hours after transfection , cells were lysed and membrane and supernatant fractions harvested as described previously [ 8 ] . 10 ?g of membrane proteins and normalized volumes of the supernatants were resolved by SDS-polyacrylamide electrophoresis ( 10% ) , transferred to nitrocellulose , and probed with a monoclonal antibody to the EE epitope [ 34 ] . The antigen - antibody complexes were visualized with ECL chemiluminescence ( Amersham Biosciences , Piscataway , NJ ) .
# ] */
# construction Cause_motion_pattern_588
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cni: CNI [1.0, 0.9]
#         pp-to: PP-to [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> cni.m
#          self.m.Goal <--> pp-to.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [uh our headquarters was transferred from South Carolina to Texas one time
# ] */
# construction Cause_motion_pattern_589
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [1.0, 0.9]
#         pp-to: PP-to [1.0, 0.9]
#         pp-from: PP-from [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Depictive <--> np.m
#          self.m.Goal <--> pp-to.m
#          self.m.Source <--> pp-from.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [Consequently , eggs kept at 0-4°C were transferred to 16°C on day 98 for hatching .
# ] */
# construction Cause_motion_pattern_590
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pping-for: PPing-for [1.0, 0.9]
#         pp-to: PP-to [1.0, 0.9]
#         pp-on: PP-on [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Explanation <--> pping-for.m
#          self.m.Result <--> pp-to.m
#          ed.profiledParticipant <--> self.m.Theme
#          self.m.Time <--> pp-on.m
#
#
# /* [that 's good i know my husband was real uh in the beginning when he uh he was transferred to a a larger plant and he um
# ] */
# construction Cause_motion_pattern_591
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-to: PP-to [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> pp-to.m
#          ed.profiledParticipant <--> self.m.Theme
#
#
# /* [The EDL muscle was then transferred to a dissecting chamber , through which Krebs Henseleit solution ( NaCl , 125 mM ; KCl , 4.7 mM ; NaH 2 PO 4 , 1.78 mM ; MgCl 2 , 1 mM ; CaCl 2 , 1.9 mM ; NaHCO 3 , 24 mM ; Dextrose , 10 mM ) flowed .
# ] */
# construction Cause_motion_pattern_592
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-to: PP-to [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> pp-to.m
#          ed.profiledParticipant <--> self.m.Theme
#          self.m.Time <--> avp.m
#
#
# /* [Now it was Ferreira 's turn to show his frustration , often slamming his racket to the ground in anger as he could only muster 11 points in a set lasting only 20 minutes .
# ] */
# construction Cause_motion_pattern_593
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         dni: DNI [1.0, 0.9]
#         pp-to: PP-to [1.0, 0.9]
#         pp-in: PP-in [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> dni.m
#          self.m.Goal <--> pp-to.m
#          self.m.Manner <--> pp-in.m
#          self.m.Theme <--> np.m
#
#
# /* [I returned it , she slammed it back , I caught it neatly , spun round and delivered a deft backward glance over my left shoulder .
# ] */
# construction Cause_motion_pattern_594
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> avp.m
#          self.m.Theme <--> np.m
#
#
# /* [Atherton batted beautifully for 42 but then left kicking himself for slamming a wide ball from Reiffel straight to cover off the back foot .
# ] */
# construction Cause_motion_pattern_595
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         dni: DNI [1.0, 0.9]
#         avp: AVP [1.0, 0.9]
#         pp-from: PP-from [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> dni.m
#          self.m.Path <--> avp.m
#          self.m.Source <--> pp-from.m
#          self.m.Theme <--> np.m
#
#
# /* [Slamming it after him , a look of disgust on her face , Hilary poured out her tea then carried the cup to the table and sat nursing it in her palms .
# ] */
# construction Cause_motion_pattern_596
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-after: PP-after [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Path <--> pp-after.m
#          self.m.Theme <--> np.m
#
#
# /* [In desperation she slammed the stop-cock open and precious oxygen knifed outwards in an icy cloud that she aimed at the farthest point .
# ] */
# construction Cause_motion_pattern_597
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         ajp: AJP [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> np.m
#
#
# /* [Some helicopters and airplanes , which were to drop water on the fires , continued to be delayed by strong winds .
# ] */
# construction Cause_motion_pattern_598
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pp-on: PP-on [1.0, 0.9]
#         np: NP [1.0, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> pp-on.m
#          self.m.Theme <--> np.m

# %% [markdown]
# This method collapses some of the constructions above into more general constructions.
# Different methods could be written to collapse on the basis of different features/dimensions
#
# **TO DO: what features/dimensions might these be, and how would such methods be written?**

# %%
print("Total number of collapsed constructions: ", len(all_cxns['cxns_collapsed']))
print(all_cxns['cxns_collapsed'])
# Out:
# Total number of collapsed constructions:  41130
# /* [] */
# construction Cause_motion_pattern_1
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.082, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_2
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         goal-pp: Goal-PP [0.29, 0.9]
#         path-pp: Path-PP [0.162, 0.9]
#         source-pp: Source-PP [0.086, 0.9]
#         ajp: AJP [0.012, 0.9]
#         poss: Poss [0.004, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_3
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         goal-pp: Goal-PP [0.406, 0.9]
#         path-pp: Path-PP [0.227, 0.9]
#         source-pp: Source-PP [0.12, 0.9]
#         agent-pp: Agent-PP [0.025, 0.9]
#         ajp: AJP [0.016, 0.9]
#         initial_state-pp: Initial_state-PP [0.003, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Theme
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_4
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.035, 0.9]
#         np: NP [0.611, 0.9]
#         path-pp: Path-PP [0.206, 0.9]
#         source-pp: Source-PP [0.109, 0.9]
#         agent-pp: Agent-PP [0.023, 0.9]
#         ajp: AJP [0.015, 0.9]
#         initial_state-pp: Initial_state-PP [0.003, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_5
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.021, 0.9]
#         np: NP [0.448, 0.9]
#         goal-pp: Goal-PP [0.27, 0.9]
#         path-pp: Path-PP [0.151, 0.9]
#         source-pp: Source-PP [0.08, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Manner <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_6
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.025, 0.9]
#         np: NP [0.528, 0.9]
#         goal-pp: Goal-PP [0.318, 0.9]
#         source-pp: Source-PP [0.094, 0.9]
#         agent-pp: Agent-PP [0.02, 0.9]
#         ajp: AJP [0.013, 0.9]
#         initial_state-pp: Initial_state-PP [0.003, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Path <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_7
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         area-pp: Area-PP [0.029, 0.9]
#         np: NP [0.936, 0.9]
#         agent-pp: Agent-PP [0.035, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Area <--> area-pp.m
#          self.m.Theme <--> np.m
#          self.m.Agent <--> agent-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_8
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         goal-pp: Goal-PP [0.511, 0.9]
#         path-pp: Path-PP [0.286, 0.9]
#         source-pp: Source-PP [0.151, 0.9]
#         ajp: AJP [0.021, 0.9]
#         poss: Poss [0.007, 0.9]
#         initial_state-pp: Initial_state-PP [0.004, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Cause
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_9
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         manner-pp: Manner-PP [0.01, 0.9]
#         np: NP [0.454, 0.9]
#         goal-pp: Goal-PP [0.273, 0.9]
#         path-pp: Path-PP [0.153, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Manner <--> manner-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_10
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [0.027, 0.9]
#         path-pp: Path-PP [0.556, 0.9]
#         source-pp: Source-PP [0.294, 0.9]
#         agent-pp: Agent-PP [0.061, 0.9]
#         ajp: AJP [0.04, 0.9]
#         poss: Poss [0.013, 0.9]
#         initial_state-pp: Initial_state-PP [0.008, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> np.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_11
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.008, 0.9]
#         np: NP [0.495, 0.9]
#         goal-pp: Goal-PP [0.298, 0.9]
#         path-pp: Path-PP [0.167, 0.9]
#         agent-pp: Agent-PP [0.018, 0.9]
#         ajp: AJP [0.012, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Source <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_12
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         result-pp: Result-PP [0.007, 0.9]
#         np: NP [0.46, 0.9]
#         goal-pp: Goal-PP [0.277, 0.9]
#         path-pp: Path-PP [0.155, 0.9]
#         source-pp: Source-PP [0.082, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Result <--> result-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_13
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [0.012, 0.9]
#         goal-pp: Goal-PP [0.499, 0.9]
#         path-pp: Path-PP [0.279, 0.9]
#         source-pp: Source-PP [0.148, 0.9]
#         agent-pp: Agent-PP [0.031, 0.9]
#         ajp: AJP [0.02, 0.9]
#         poss: Poss [0.007, 0.9]
#         initial_state-pp: Initial_state-PP [0.004, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Distance <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_14
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         cause-pp: Cause-PP [0.006, 0.9]
#         np: NP [0.463, 0.9]
#         goal-pp: Goal-PP [0.279, 0.9]
#         path-pp: Path-PP [0.156, 0.9]
#         source-pp: Source-PP [0.082, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Cause <--> cause-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_15
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.005, 0.9]
#         np: NP [0.461, 0.9]
#         goal-pp: Goal-PP [0.277, 0.9]
#         path-pp: Path-PP [0.155, 0.9]
#         source-pp: Source-PP [0.082, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Result <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_16
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [0.008, 0.9]
#         goal-pp: Goal-PP [0.505, 0.9]
#         path-pp: Path-PP [0.282, 0.9]
#         source-pp: Source-PP [0.149, 0.9]
#         agent-pp: Agent-PP [0.031, 0.9]
#         ajp: AJP [0.02, 0.9]
#         initial_state-pp: Initial_state-PP [0.004, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_17
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         handle-pp: Handle-PP [0.004, 0.9]
#         np: NP [0.456, 0.9]
#         goal-pp: Goal-PP [0.275, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Handle <--> handle-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_18
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         instrument-pp: Instrument-PP [0.004, 0.9]
#         np: NP [0.456, 0.9]
#         goal-pp: Goal-PP [0.275, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Instrument <--> instrument-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_19
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         ajp: AJP [0.005, 0.9]
#         np: NP [0.633, 0.9]
#         path-pp: Path-PP [0.213, 0.9]
#         source-pp: Source-PP [0.113, 0.9]
#         agent-pp: Agent-PP [0.024, 0.9]
#         result-pp: Result-PP [0.009, 0.9]
#         initial_state-pp: Initial_state-PP [0.003, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> ajp.m
#          self.m.Theme <--> np.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> result-pp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_20
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.004, 0.9]
#         np: NP [0.456, 0.9]
#         goal-pp: Goal-PP [0.275, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Time <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_21
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         time-pp: Time-PP [0.004, 0.9]
#         np: NP [0.456, 0.9]
#         goal-pp: Goal-PP [0.275, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Time <--> time-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_22
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.004, 0.9]
#         np: NP [0.456, 0.9]
#         goal-pp: Goal-PP [0.275, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Distance <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_23
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         sfin: Sfin [0.004, 0.9]
#         goal-pp: Goal-PP [0.29, 0.9]
#         path-pp: Path-PP [0.162, 0.9]
#         source-pp: Source-PP [0.086, 0.9]
#         ajp: AJP [0.012, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Theme <--> sfin.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_24
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         ajp: AJP [0.002, 0.9]
#         np: NP [0.459, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.155, 0.9]
#         source-pp: Source-PP [0.082, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         result-pp: Result-PP [0.007, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Depictive <--> ajp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> result-pp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_25
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vpto: VPto [0.003, 0.9]
#         np: NP [0.631, 0.9]
#         path-pp: Path-PP [0.212, 0.9]
#         source-pp: Source-PP [0.112, 0.9]
#         agent-pp: Agent-PP [0.023, 0.9]
#         ajp: AJP [0.015, 0.9]
#         initial_state-pp: Initial_state-PP [0.003, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> vpto.m
#          self.m.Theme <--> np.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_26
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         2nd: 2nd [0.002, 0.9]
#         np: NP [0.498, 0.9]
#         goal-pp: Goal-PP [0.3, 0.9]
#         path-pp: Path-PP [0.167, 0.9]
#         agent-pp: Agent-PP [0.019, 0.9]
#         ajp: AJP [0.012, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Source <--> 2nd.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_27
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         distance-pp: Distance-PP [0.001, 0.9]
#         np: NP [0.457, 0.9]
#         goal-pp: Goal-PP [0.275, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Distance <--> distance-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_28
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.001, 0.9]
#         np: NP [0.457, 0.9]
#         goal-pp: Goal-PP [0.275, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Degree <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_29
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         place-pp: Place-PP [0.001, 0.9]
#         np: NP [0.457, 0.9]
#         goal-pp: Goal-PP [0.275, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Place <--> place-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_30
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [0.004, 0.9]
#         goal-pp: Goal-PP [0.702, 0.9]
#         source-pp: Source-PP [0.208, 0.9]
#         agent-pp: Agent-PP [0.043, 0.9]
#         ajp: AJP [0.028, 0.9]
#         poss: Poss [0.009, 0.9]
#         initial_state-pp: Initial_state-PP [0.006, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Path <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_31
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.003, 0.9]
#         np: NP [0.961, 0.9]
#         agent-pp: Agent-PP [0.036, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Area <--> avp.m
#          self.m.Theme <--> np.m
#          self.m.Agent <--> agent-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_32
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pping-into: PPing-into [0.001, 0.9]
#         np: NP [0.632, 0.9]
#         path-pp: Path-PP [0.213, 0.9]
#         source-pp: Source-PP [0.112, 0.9]
#         agent-pp: Agent-PP [0.024, 0.9]
#         ajp: AJP [0.015, 0.9]
#         initial_state-pp: Initial_state-PP [0.003, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> pping-into.m
#          self.m.Theme <--> np.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_33
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pping-at: PPing-at [0.001, 0.9]
#         np: NP [0.632, 0.9]
#         path-pp: Path-PP [0.213, 0.9]
#         source-pp: Source-PP [0.112, 0.9]
#         agent-pp: Agent-PP [0.024, 0.9]
#         ajp: AJP [0.015, 0.9]
#         initial_state-pp: Initial_state-PP [0.003, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> pping-at.m
#          self.m.Theme <--> np.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_34
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         sub: Sub [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Manner <--> sub.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_35
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         inc: INC [0.001, 0.9]
#         np: NP [0.466, 0.9]
#         goal-pp: Goal-PP [0.28, 0.9]
#         path-pp: Path-PP [0.157, 0.9]
#         source-pp: Source-PP [0.083, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Cause <--> inc.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_36
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         depictive-pp: Depictive-PP [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Depictive <--> depictive-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_37
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         avp: AVP [0.001, 0.9]
#         goal-pp: Goal-PP [0.291, 0.9]
#         path-pp: Path-PP [0.163, 0.9]
#         source-pp: Source-PP [0.086, 0.9]
#         ajp: AJP [0.012, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Theme <--> avp.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_38
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         means-pp: Means-PP [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Means <--> means-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_39
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pping-by: PPing-by [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Means <--> pping-by.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_40
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vping: VPing [0.001, 0.9]
#         np: NP [0.632, 0.9]
#         path-pp: Path-PP [0.213, 0.9]
#         source-pp: Source-PP [0.112, 0.9]
#         agent-pp: Agent-PP [0.024, 0.9]
#         ajp: AJP [0.015, 0.9]
#         initial_state-pp: Initial_state-PP [0.003, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Goal <--> vping.m
#          self.m.Theme <--> np.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_41
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vping: VPing [0.001, 0.9]
#         goal-pp: Goal-PP [0.291, 0.9]
#         path-pp: Path-PP [0.163, 0.9]
#         source-pp: Source-PP [0.086, 0.9]
#         ajp: AJP [0.012, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Theme <--> vping.m
#          ed.profiledParticipant <--> self.m.Agent
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_42
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pping-by: PPing-by [0.001, 0.9]
#         np: NP [0.466, 0.9]
#         goal-pp: Goal-PP [0.28, 0.9]
#         path-pp: Path-PP [0.157, 0.9]
#         source-pp: Source-PP [0.083, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Agent <--> pping-by.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_43
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pping-from: PPing-from [0.001, 0.9]
#         np: NP [0.498, 0.9]
#         goal-pp: Goal-PP [0.3, 0.9]
#         path-pp: Path-PP [0.168, 0.9]
#         agent-pp: Agent-PP [0.019, 0.9]
#         ajp: AJP [0.012, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Source <--> pping-from.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_44
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vpto: VPto [0.001, 0.9]
#         np: NP [0.466, 0.9]
#         goal-pp: Goal-PP [0.28, 0.9]
#         path-pp: Path-PP [0.157, 0.9]
#         source-pp: Source-PP [0.083, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Cause <--> vpto.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_45
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         path-pp: Path-PP [0.57, 0.9]
#         source-pp: Source-PP [0.301, 0.9]
#         agent-pp: Agent-PP [0.063, 0.9]
#         ajp: AJP [0.041, 0.9]
#         poss: Poss [0.014, 0.9]
#         initial_state-pp: Initial_state-PP [0.008, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          ed.profiledParticipant <--> self.m.Goal
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_46
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [0.001, 0.9]
#         goal-pp: Goal-PP [0.505, 0.9]
#         path-pp: Path-PP [0.282, 0.9]
#         source-pp: Source-PP [0.149, 0.9]
#         agent-pp: Agent-PP [0.031, 0.9]
#         ajp: AJP [0.02, 0.9]
#         poss: Poss [0.007, 0.9]
#         initial_state-pp: Initial_state-PP [0.004, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Time <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_47
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vped: VPed [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Depictive <--> vped.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_48
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         sfin: Sfin [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Explanation <--> sfin.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_49
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vping: VPing [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Instrument <--> vping.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_50
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vping: VPing [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Means <--> vping.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_51
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         vpto: VPto [0.002, 0.9]
#         np: NP [0.963, 0.9]
#         agent-pp: Agent-PP [0.036, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Area <--> vpto.m
#          self.m.Theme <--> np.m
#          self.m.Agent <--> agent-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_52
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         np: NP [0.001, 0.9]
#         goal-pp: Goal-PP [0.505, 0.9]
#         path-pp: Path-PP [0.282, 0.9]
#         source-pp: Source-PP [0.149, 0.9]
#         agent-pp: Agent-PP [0.031, 0.9]
#         ajp: AJP [0.02, 0.9]
#         poss: Poss [0.007, 0.9]
#         initial_state-pp: Initial_state-PP [0.004, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Depictive <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Theme <--> poss.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_53
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         explanation-pp: Explanation-PP [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Explanation <--> explanation-pp.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
#
#
# /* [] */
# construction Cause_motion_pattern_54
#      subcase of ArgumentStructure
#      constructional
#       constituents
#         v: Verb
#         pping-for: PPing-for [0.001, 0.9]
#         np: NP [0.458, 0.9]
#         goal-pp: Goal-PP [0.276, 0.9]
#         path-pp: Path-PP [0.154, 0.9]
#         source-pp: Source-PP [0.081, 0.9]
#         agent-pp: Agent-PP [0.017, 0.9]
#         ajp: AJP [0.011, 0.9]
#         initial_state-pp: Initial_state-PP [0.002, 0.9]
#       meaning: Cause_motion
#        constraints
#          self.m <--> v.m
#          self.m.Explanation <--> pping-for.m
#          self.m.Theme <--> np.m
#          self.m.Goal <--> goal-pp.m
#          self.m.Path <--> path-pp.m
#          self.m.Source <--> source-pp.m
#          self.m.Agent <--> agent-pp.m
#          self.m.Result <--> ajp.m
#          self.m.Initial_state <--> initial_state-pp.m
