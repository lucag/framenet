# %%
from framenet.data.annotation import Groups, Patterns
from framenet.data.pattern import *

Ext, Obj, t, Dep = map(Lit, 'Ext Obj _ Dep'.split())

p1 = Ext & t & Obj & Many1(Dep)
p2 = Ext & t & Many1(Dep)

# %%
cm = Groups('Cause_motion')
cm_ps = Patterns(cm)

cm_ps.select(p2).diagram(size=(640,320))

# %%
cfm = Groups('Cause_fluidic_motion')
cfm_ps = Patterns(cfm)

cfm_ps.select(p1).diagram(noncore=False, size=(640,320))
# Out:
# Written 13 records.
