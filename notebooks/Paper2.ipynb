# %%
from framenet.data.annotation import get_frame_df, Patterns, to_layers, gf_or_target, Groups
from framenet.data.pattern    import *
import pandas as pd, qgrid

# %% [markdown]
# ## First, we create `Groups`
#
# A `Group` simply groups related information w.r.t. a specific sentence and annotation.

# %%
cfm_groups = Groups('Cause_fluidic_motion')
# Out:
# These lexical units have already been built.

# %% [markdown]
# A `Groups` instance contains a [Pandas](http://pandas.pydata.org/pandas-docs/stable/index.html) `DataFrame` (type, _CamelCase_) in its attribute `data_frame`(Python identifier, *train_case*), which we need for generating the following table.

# %%
qgrid.show_grid(cfm_groups.data_frame, grid_options={'forceFitColumns': True, 'defaultColumnWidth': 50})

# %% [markdown]
# Here is how we check the kind of `LU`s the DataFrame we just created contains:

# %%
cfm_groups.data_frame['annotationSet.LU'].unique()
# Out:
# array(['dribble.v', 'spill.v', 'spatter.v', 'splatter.v', 'splash.v',
#        'spray.v', 'squirt.v', 'pump.v'], dtype=object)

# %% [markdown]
# ## Second: we create a `Patterns` instance.
#
# We start from our `Groups` instance `cfm_groups` we creted in the first step. This is the instance to query patterns in the chosen frame.

# %%
cfm_patterns = Patterns(cfm_groups)

# %% [markdown]
# ## Third: we create the symbols for all our patterns
#
# We need to do this only once per Notebook. We need those becuase we describe the patterns l=we lokk for as Python expressions. The following applies the constructor `Lit` to the strings `'Ext'`, `'Obj'`, `'Dep'`, and `'_'` (our wildcard) and assigns the result to the corresponding Python variables. This way `Ext`, `Obj`, `Dep` and `x` can be combined in the patterns below.

# %%
Ext, Obj, Dep, x = map(Lit, 'Ext Obj Dep _'.split())

# %% [markdown]
# This is *almost* $Pattern_1$ we used in the paper. The **`&`** should be intepreted as "followed by". So `p1` is `Ext` followed by `x` (the wildcard, which matches any *single* element), followd by `Obj`, followed by `Dep`.

# %%
p1 = Ext & x & Obj & Dep

# %% [markdown]
# ### To be really precise
#
# $Pattern_1$ was **`Ext` `_` `Obj` `Dep` `+`**, that is, like the following:

# %%
p1_actually = Ext & x & Obj & Many1(Dep)

# %% [markdown]
# So, `Obj` was followed by one or more `Dep`s.
#
# ### To summarize:
#
# <table>
# <tr><th>The operator</th><th>means</th></tr>
# <tr><td>&amp;</td><td>_followed by_</td></tr>
# <tr><td>`|`</td><td>_one or the other_</td></tr>
# <tr><td>`Many1(...)`</td><td>_one or more of ..._</td></tr>
# <tr><td>`Many(...)`</td><td>_zero or more of ..._</td></tr>
# <tr><td>`Opt(...)`</td><td>_optionally ..._</td></tr>
# </table>

# %% [markdown]
# So, if we wanted to say that `x` should be followed by one or more of `Obj` or `Dep`, we would say:

# %%
weird_p = x & Many1(Obj | Dep)

# %% [markdown]
# Which would match thing like
#
#     v → Obj → Dep → Obj → Obj → Dep → Dep → Dep → Obj ...

# %% [markdown]
# ### $Pattern_2$, which was **`Ext` `_` `Dep` `+`** is like this:

# %%
p2 =  Ext & x & Many1(Dep)

# %% [markdown]
# ## Fourth: now we can actually look at patterns
#
# This is with `p1`. The `display` method understands the following keywords, all optional:
#
# * `pattern_matcher`: defined as the above expressions, or `None` / unspecified
# * `min_count`: the minimum count for sentences matching a pattern; a nonnegative integer number
# * `negative`: a boolean specifying whether a pattern should be inverted (sentences picked when they *do not* match)
# * `collapse_sentences`: a boolean that eliminates the sentences from the table (when se to `True`

# %%
cfm_patterns.display(pattern_matcher = p1, min_count = 0, negative=False, collapse_sentences=True)
# Out:
# <table><tr><th></th><th>freq.</th><th>Pattern</th></tr><tr><td style="text-align: right;">1</td>
# <td style="text-align: right;">42</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Goal (PP)</td></tr>
# <tr><td style="text-align: right;">2</td>
# <td style="text-align: right;">3</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Fluid (PP)</td></tr>
# <tr><td style="text-align: right;">3</td>
# <td style="text-align: right;">2</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Area (PP)</td></tr>
# <tr><td style="text-align: right;">4</td>
# <td style="text-align: right;">2</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Source (PP)</td></tr>
# <tr><td style="text-align: right;">5</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Fluid (PP)</td></tr>
# <tr><td style="text-align: right;">6</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Area (NP) → <b>Dep</b>: Fluid (PP)</td></tr>
# <tr><td style="text-align: right;">7</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Area (PP)</td></tr>
# <tr><td style="text-align: right;">8</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Path (PP)</td></tr>
# <tr><td style="text-align: right;">9</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Path (PP)</td></tr></table>

# %% [markdown]
# ## Fifth: flow diagrams!
#
# The method `select` takes a pattern (as described above), and `diagram` takes an optional keyword argument to select noncore `FE`s. The default value is `True`.

# %%
cfm_patterns.select(p1).diagram(noncore=True)
# Out:
# Written 10 records.

# %% [markdown]
# ## More examples we worked on
#
# ### The `Filling` frame
#
# Comment here.

# %%
filling_groups = Groups('Filling')

filling_pattern = Patterns(filling_groups)

filling_pattern.display(pattern_matcher=p1_actually, collapse_sentences=True)
# Out:
# These lexical units have already been built.
# <table><tr><th></th><th>freq.</th><th>Pattern</th></tr><tr><td style="text-align: right;">1</td>
# <td style="text-align: right;">142</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Theme (PP)</td></tr>
# <tr><td style="text-align: right;">2</td>
# <td style="text-align: right;">18</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP)</td></tr>
# <tr><td style="text-align: right;">3</td>
# <td style="text-align: right;">10</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Result (AJP)</td></tr>
# <tr><td style="text-align: right;">4</td>
# <td style="text-align: right;">6</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Theme (NP) → <b>Dep</b>: Goal (PP)</td></tr>
# <tr><td style="text-align: right;">5</td>
# <td style="text-align: right;">2</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Manner (AVP)</td></tr>
# <tr><td style="text-align: right;">6</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Degree (AVP) → <b>Dep</b>: Result (AJP) → <b>Dep</b>: Degree (Sfin)</td></tr>
# <tr><td style="text-align: right;">7</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Result (NP) → <b>Dep</b>: Theme (PP)</td></tr>
# <tr><td style="text-align: right;">8</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Theme (PPing)</td></tr>
# <tr><td style="text-align: right;">9</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Degree (NP) → <b>Dep</b>: Theme (PP)</td></tr>
# <tr><td style="text-align: right;">10</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Theme (PP) → <b>Dep</b>: Time (PPing)</td></tr>
# <tr><td style="text-align: right;">11</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Result (PP) → <b>Dep</b>: Theme (PP)</td></tr>
# <tr><td style="text-align: right;">12</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Theme (PP) → <b>Dep</b>: Manner (AVP)</td></tr>
# <tr><td style="text-align: right;">13</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Degree (AVP) → <b>Dep</b>: Theme (PP)</td></tr>
# <tr><td style="text-align: right;">14</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Theme (PP) → <b>Dep</b>: Subregion (PP)</td></tr>
# <tr><td style="text-align: right;">15</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Time (PP)</td></tr>
# <tr><td style="text-align: right;">16</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Time (NP)</td></tr>
# <tr><td style="text-align: right;">17</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Result (PP)</td></tr>
# <tr><td style="text-align: right;">18</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Theme (PP) → <b>Dep</b>: Time (PP)</td></tr>
# <tr><td style="text-align: right;">19</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Theme (NP) → <b>Dep</b>: Goal (PP)</td></tr></table>

# %%
filling_pattern.select(p1).diagram(noncore=False)
# Out:
# Written 6 records.

# %%
cfm_patterns.display(pattern_matcher=p1, collapse_sentences=True)
# Out:
# <table><tr><th></th><th>freq.</th><th>Pattern</th></tr><tr><td style="text-align: right;">1</td>
# <td style="text-align: right;">42</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Goal (PP)</td></tr>
# <tr><td style="text-align: right;">2</td>
# <td style="text-align: right;">3</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Fluid (PP)</td></tr>
# <tr><td style="text-align: right;">3</td>
# <td style="text-align: right;">2</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Area (PP)</td></tr>
# <tr><td style="text-align: right;">4</td>
# <td style="text-align: right;">2</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Source (PP)</td></tr>
# <tr><td style="text-align: right;">5</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Fluid (PP)</td></tr>
# <tr><td style="text-align: right;">6</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Area (NP) → <b>Dep</b>: Fluid (PP)</td></tr>
# <tr><td style="text-align: right;">7</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Area (PP)</td></tr>
# <tr><td style="text-align: right;">8</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Path (PP)</td></tr>
# <tr><td style="text-align: right;">9</td>
# <td style="text-align: right;">1</td>
# <td style="vertical-align: top; white-space: nowrap;"><b>Ext</b>: Cause (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Path (PP)</td></tr></table>

# %%
cfm_patterns.select(p1_actually).diagram(noncore=True)
# Out:
# Written 21 records.

# %%
cfm_patterns.select(p1_actually).diagram(noncore=False)
# Out:
# Written 13 records.
