# %% [markdown]
# # Paper Notebook (literally, but also not)
#
# Before anything else, after having checke that the kernel you're running is a Python 3 kernel (it should say Python 3 on the top right, or see Help | About), execute the following cell. It should pull everythig from GitHub and install it.

# %%
# ! git pull
# ! pip3 install -e ..

# %%
from framenet.data.annotation import get_frame_df, Patterns, to_layers, gf_or_target, Groups
from framenet.data.pattern    import *
import pandas as pd, qgrid

# %% [markdown]
# ## First, we create `Groups`
#
# A `Group` simply groups related information w.r.t. a specific sentence and annotation.

# %%
cfm_groups = Groups('Cause_fluidic_motion')

# %% [markdown]
# A `Groups` instance contains a [Pandas](http://pandas.pydata.org/pandas-docs/stable/index.html) `DataFrame` (type, _CamelCase_) in its attribute `data_frame`(Python identifier, *train_case*), which we need for generating the following table.

# %%
# qgrid.show_grid(cfm_groups.data_frame, 
#                 grid_options={'forceFitColumns': True, 'defaultColumnWidth': 50})

# %% [markdown]
# Here is how we check the kind of `LU`s the DataFrame we just created contains:

# %%
cfm_groups.data_frame['annotationSet.LU'].unique()
# Out:
# array(['dribble.v', 'spill.v', 'spatter.v', 'splatter.v', 'splash.v',
#        'spray.v', 'squirt.v', 'pump.v'], dtype=object)

# %% [markdown]
# ## Second: we create a `Patterns` instance.
#
# We start from our `Groups` instance `cfm_groups` we creted in the first step. This is the instance to query patterns in the chosen frame.

# %%
cfm_patterns = Patterns(cfm_groups)

# %% [markdown]
# ## Third: we create the symbols for all our patterns
#
# We need to do this only once per Notebook. We need those becuase we describe the patterns l=we lokk for as Python expressions. The following applies the constructor `Lit` to the strings `'Ext'`, `'Obj'`, `'Dep'`, and `'_'` (our wildcard) and assigns the result to the corresponding Python variables. This way `Ext`, `Obj`, `Dep` and `x` can be combined in the patterns below.

# %%
Ext, Obj, Dep, x, CNI, DNI, INI = map(Lit, 'Ext Obj Dep _ CNI DNI INI'.split())

# %% [markdown]
# This is *almost* $Pattern_1$ we used in the paper. The **`&`** should be intepreted as "followed by". So `p1` is `Ext` followed by `x` (the wildcard, which matches any *single* element), followd by `Obj`, followed by `Dep`.

# %%
p1 = Ext & x & Obj & Dep

# %% [markdown]
# ### To be really precise
#
# $Pattern_1$ was **`Ext` `_` `Obj` `Dep` `+`**, that is, like the following:

# %%
p1_actually = Ext & x & Obj & Many1(Dep)

# %% [markdown]
# So, `Obj` was followed by one or more `Dep`s.
#
# ### To summarize:
#
# <table>
# <tr><th>The operator</th><th>means</th></tr>
# <tr><td>&amp;</td><td>_followed by_</td></tr>
# <tr><td>`|`</td><td>_one or the other_</td></tr>
# <tr><td>`Many1(...)`</td><td>_one or more of ..._</td></tr>
# <tr><td>`Many(...)`</td><td>_zero or more of ..._</td></tr>
# <tr><td>`Opt(...)`</td><td>_optionally ..._</td></tr>
# </table>

# %% [markdown]
# So, if we wanted to say that `x` should be followed by one or more of `Obj` or `Dep`, we would say:

# %%
weird_p = x & Many1(Obj | Dep)

# %% [markdown]
# Which would match thing like
#
#     v → Obj → Dep → Obj → Obj → Dep → Dep → Dep → Obj ...

# %% [markdown]
# ### $Pattern_2$, which was **`Ext` `_` `Dep` `+`** is like this:

# %%
p2 =  Ext & x & Many1(Dep)

# %% [markdown]
# ## Fourth: now we can actually look at patterns
#
# This is with `p1`. The `display` method understands the following keywords, all optional:
#
# * `pattern_matcher`: defined as the above expressions, or `None` / unspecified
# * `min_count`: the minimum count for sentences matching a pattern; a nonnegative integer number
# * `negative`: a boolean specifying whether a pattern should be inverted (sentences picked when they *do not* match)
# * `collapse_sentences`: a boolean that eliminates the sentences from the table (when se to `True`

# %%
cfm_patterns.display(pattern_matcher = p1, min_count = 0, negative=False)
# Out:
# <style>
#   .popover {
#     /*width: 800px;*/
#     max-width: 800px;
#     /*max-height: 600px;*/
#     /*overflow: scroll;*/
#     z-index: 3500;
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
#
#   .popover.in {
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
# </style>
#
# <script type="text/javascript">
#   $(function () {
#     $('[data-toggle="popover"]').popover()
#   })
# </script><div>Total count: 54</div><table><tr><th></th><th>freq.</th><th>Patterns</th><th></th></tr><tr><td style="text-align: right">1</td>
# <td style="text-align: right">42</td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Goal (PP)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;Brandon then told one of the other group : ` Order your food and leave if you do n&#39;t want trouble , or I &#39;ll splatter your face across the road . &#34;&lt;/li&gt;&lt;li&gt;` Bastard ! &#34; cried Bernard , belabouring Jed with his fists , splattering cheap red wine over books and walls .&lt;/li&gt;&lt;li&gt;The priest took the basin of blood and spattered it against the altar .&lt;/li&gt;&lt;li&gt;However , its task is made much more difficult by the fact that derogations granted to the Welsh water authority allow it to pump raw sewage into both those rivers .&lt;/li&gt;&lt;li&gt;The longer we continue to pump lead into the atmosphere , the more it will accumulate .&lt;/li&gt;&lt;li&gt;The Suffolk Water Company is pumping specially dechlorinated water into the habitat of the fen raft spider , Britain &#39;s largest and rarest , to save it from extinction .&lt;/li&gt;&lt;li&gt;However , once the salt fingers are formed , they are pumping salty fluid into the top of the bottom layer and less salty fluid into the bottom of the top layer .&lt;/li&gt;&lt;li&gt;This has been open to doubt since June 8 , 1989 when an extreme left-wing group pumped 20 bullets into Valenzuela &#39;s former chief , ` Wally &#34; Fuentes Morrison .&lt;/li&gt;&lt;li&gt;Carter toppled over and lay pumping his blood onto the canteen floor .&lt;/li&gt;&lt;li&gt;They will pump waste water to an existing sewer at Crosby Road South and then to North West Water &#39;s multimillion pound treatment works at Sandon Dock .&lt;/li&gt;&lt;li&gt;Vital messages from the brain to the body slow down and nerves in the heart , sensing something is wrong , react by instructing the heart to pump extra blood to the brain .&lt;/li&gt;&lt;li&gt;The following week tests were carried out and I went with Dad to watch the Brigade endeavouring to pump water to the roof of Blooms the Drapers on The Canal -- possibly the City &#39;s tallest building .&lt;/li&gt;&lt;li&gt;One possibility being considered is for solar power to be used to pump downstream water back up to the main reservoir , so restoring the head of water needed to generate hydro-electric power .&lt;/li&gt;&lt;li&gt;A valuable way of concealing them is to have bars , stripes or blobs of colour that appear to overflow from one section to the next , as though someone has splashed ink across the animal .&lt;/li&gt;&lt;li&gt;Betty watched him as he splashed a little soda in each , and handed her one .&lt;/li&gt;&lt;li&gt;He splashed whiskey into the glasses .&lt;/li&gt;&lt;li&gt;Edward lifted it and splashed a little water into the teapot , swirling it around .&lt;/li&gt;&lt;li&gt;She splashed water on her face , wishing she had her overnight case up here with her , wondering if it would be possible to make a deal with Ace .&lt;/li&gt;&lt;li&gt;The extreme force of the blows had splashed blood on the walls and ceilings .&lt;/li&gt;&lt;li&gt;The Church of England vicar blessed the Northamp stately home , splashed holy water on the walls and said prayers to ward off the spirit .&lt;/li&gt;&lt;li&gt;Cupping his hands in the large jug , he splashed cold water over his face and chest , rubbing it up and down his arms before towelling himself down .&lt;/li&gt;&lt;li&gt;I splashed water over my face , slicked unruly grey hair into a more reasonable disorder , and headed down to the lobby again .&lt;/li&gt;&lt;li&gt;In fact , she thought as she splashed cold water on to her hot face , she had n&#39;t seen him all morning -- perhaps he &#39;d taken himself off for a walk .&lt;/li&gt;&lt;li&gt;He splashed some down the front of my tunic and was gone .&lt;/li&gt;&lt;li&gt;Eddie splashed more of the liquid against his temples , brushing it back and then rubbing it in with a comb .&lt;/li&gt;&lt;li&gt;I splashed more over my face .&lt;/li&gt;&lt;li&gt;Some female handed them a hypo-bulb and they sprayed it into Jezrael &#39;s face , and there was a physical paralysis leadening her without  ...
#         data-template="
# &lt;div class=&#34;popover&#34; role=&#34;tooltip&#34;&gt;
#     &lt;div class=&#34;arrow&#34;&gt;&lt;/div&gt;
#     &lt;h3 class=&#34;popover-title&#34;&gt;&lt;/h3&gt;
#     &lt;div class=&#34;popover-content&#34;&gt;
# &lt;/div&gt;">
#   ...
# </button>
# </td></tr>
# <tr><td style="text-align: right">2</td>
# <td style="text-align: right">3</td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP) → <b>Dep</b>: Fluid (PP)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;For a moment she looked furiously at Donald , her teeth bared like a cat &#39;s , then she shook her hair out , spattering Donald with bree and barley , and hauled him back into the dance .&lt;/li&gt;&lt;li&gt;She came down heavily , spattering her nightdress with earth , shards of flowerpot , dark streaks of water from spilled asters .&lt;/li&gt;&lt;li&gt;His friends carry his rigid , moaning body to one side and an

# %%
cfm_patterns.display()
# Out:
# <style>
#   .popover {
#     /*width: 800px;*/
#     max-width: 800px;
#     /*max-height: 600px;*/
#     /*overflow: scroll;*/
#     z-index: 3500;
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
#
#   .popover.in {
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
# </style>
#
# <script type="text/javascript">
#   $(function () {
#     $('[data-toggle="popover"]').popover()
#   })
# </script><div>Total count: 143</div><table><tr><th></th><th>freq.</th><th>Patterns</th><th></th></tr><tr><td style="text-align: right">1</td>
# <td style="text-align: right">42</td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Goal (PP)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;Brandon then told one of the other group : ` Order your food and leave if you do n&#39;t want trouble , or I &#39;ll splatter your face across the road . &#34;&lt;/li&gt;&lt;li&gt;` Bastard ! &#34; cried Bernard , belabouring Jed with his fists , splattering cheap red wine over books and walls .&lt;/li&gt;&lt;li&gt;The priest took the basin of blood and spattered it against the altar .&lt;/li&gt;&lt;li&gt;However , its task is made much more difficult by the fact that derogations granted to the Welsh water authority allow it to pump raw sewage into both those rivers .&lt;/li&gt;&lt;li&gt;The
td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Fluid (NP) → v → <b>Dep</b>: Goal (PP) → <b>CNI</b>: Agent (None)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;` Another scene cut was one where a man &#39;s brains are splattered over a window . &#34;&lt;/li&gt;&lt;li&gt;During the re-entry and completion of BA-1 a large amount of brine was pumped into the well , carrying fines with it and plugging the pores around the well bore .&lt;/li&gt;&lt;li&gt;This amplification is produced at the expense of energy pumped into the medium via the population inversion of its atoms or

# %% [markdown]
# ## Fifth: flow diagrams!
#
# The method `select` takes a pattern (as described above), and `diagram` takes an optional keyword argument to select noncore `FE`s. The default value is `True`.

# %%
cfm_patterns.select(p1_actually, negative=True).diagram(noncore=True)
# Out:
# Written 77 records.

# %% [markdown]
# ## More examples we worked on
#
# ### The `Filling` frame
#
# Comment here.

# %%
filling_groups = Groups('Filling')

filling_pattern = Patterns(filling_groups)
filling_pattern.display(pattern_matcher=p1, min_count=0, negative=True)
# Out:
# <style>
#   .popover {
#     /*width: 800px;*/
#     max-width: 800px;
#     /*max-height: 600px;*/
#     /*overflow: scroll;*/
#     z-index: 3500;
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
#
#   .popover.in {
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
# </style>
#
# <script type="text/javascript">
#   $(function () {
#     $('[data-toggle="popover"]').popover()
#   })
# </script><div>Total count: 387</div><table><tr><th></th><th>freq.</th><th>Patterns</th><th></th></tr><tr><td style="text-align: right">1</td>
# <td style="text-align: right">111</td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Goal (NP) → v → <b>Dep</b>: Theme (PP) → <b>CNI</b>: Agent (None)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;Its windows are plastered with posters proclaiming the girls &#39; innocence , as are those of their neighbours .&lt;/li&gt;&lt;li&gt;It showed a group of legionnaires sitting on a wall in a wrecked and burning tropical town ; the soldiers were filthy , looked exhausted and were draped with hand grenades and belts of machine gun ammunition .&lt;/li&gt;&lt;li&gt;The funeral of two IRA men shot dead by soldiers in Northern Ireland was delayed after the priest initially refused to allow the coffins into the church becuase they were draped with the Irish Tricolour .&lt;/li&gt;&lt;li&gt;And from somewhere beneath a cupboard she produced an enormous canvas draped in a sheet and showed it to me .&lt;/li&gt;&lt;li&gt;The guards were clad in tough green leather from some jungle beast and draped in weapons .&lt;/li&gt;&lt;li&gt;Rusted hooks hung from antiquated iron girders above him , the windows had long since been vandalized and the faded walls were daubed with obscene graffiti .&lt;/li&gt;&lt;li&gt;The walls were daubed with splashes of paint , and here and there large eyes were drawn , with daggers sticking out of them .&lt;/li&gt;&lt;li&gt;Her face was always carefully rouged , her mouth daubed generously with salve .&lt;/li&gt;&lt;li&gt;Before it gets there a barricade of grey concrete blocks daubed with ` Free Lithuania &#34; and ` Independence for Baltic Countries &#34; has been drawn across the street .&lt;/li&gt;&lt;li&gt;The ministry revealed that in experiments one pig had developed spongiform encephalopathy after its brain had been injected with BSE-infected tissue from a cow brain .&lt;/li&gt;&lt;li&gt;They have been injected with an insoluble luminous dye to help sell the fish .&lt;/li&gt;&lt;li&gt;Some of the males were injected with morphine for a few days and some were given other drugs .&lt;/li&gt;&lt;li&gt;The ministry has faced criticism for permitting the sale of milk produced by cows injected with the experimental , genetically engineered drug BST as the identity of farms and dairies taking part in the experiments is kept secret .&lt;/li&gt;&lt;li&gt;The time mice injected with material from the trained rats take to enter the dark box is compared with that for animals injected with ‘ naïve ’ material .&lt;/li&gt;&lt;li&gt;To demonstrate that learning and memory retention can be improved in animals injected with peptides and tested under highly contrived laboratory conditions is very different from showing that human memory can be helped by popping a pill .&lt;/li&gt;&lt;li&gt;Supermice have been grown , injected with rat growth hormone ; and similar transfer of human genes , for quick growth , to cattle , sheep and pigs became a possibility .&lt;/li&gt;&lt;li&gt;Two female New Zealand White rabbits were each injected with approximately 100µg of RAP74 or 300µg of RAP30 a week after preimmune serum had been bled .&lt;/li&gt;&lt;li&gt;It was crammed with unpaid bills for food and clothing .&lt;/li&gt;&lt;li&gt;Around Christmas Fayre , when the Food Hall was crammed with food you did n&#39;t normally see in the other seasons , they made a nice end to a meal .&lt;/li&gt;&lt;li&gt;It was crammed with notebooks filled with Parkin &#39;s bold scribble as well as copies of various scripts in loose folders .&lt;/li&gt;&lt;li&gt;Their store rooms were crammed with piles of objects , from furniture to fencing , and some of the corridors were blocked with the mounds of things they had made over the years .&lt;/li&gt;&lt;li&gt;His trolley stood forlornly a few yards away , crammed with food for the dinner party .&lt;/li&gt;&lt;li&gt;In the warren of lanes and alleys , barefoot traders sit cross-legged in tiny shops crammed with strange goods .&lt;/li&gt;&lt;li&gt;Round the corner and again a transformation , this time the decor is that of a university study with huge creaking bookcases crammed with dusty volumes .&lt;/li&gt;&lt;li&gt;Then he moved on , stepping carefully in &#34; his h ...

# %%
filling_pattern.select(p1).diagram(noncore=True)
# Out:
# Written 7 records.

# %%
cfm_patterns.display(pattern_matcher=p1)
# Out:
# <style>
#   .popover {
#     /*width: 800px;*/
#     max-width: 800px;
#     /*max-height: 600px;*/
#     /*overflow: scroll;*/
#     z-index: 3500;
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
#
#   .popover.in {
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
# </style>
#
# <script type="text/javascript">
#   $(function () {
#     $('[data-toggle="popover"]').popover()
#   })
# </script><div>Total count: 54</div><table><tr><th></th><th>freq.</th><th>Patterns</th><th></th></tr><tr><td style="text-align: right">1</td>
# <td style="text-align: right">42</td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Goal (PP)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;Brandon then told one of the other group : ` Order your food and leave if you do n&#39;t want trouble , or I &#39;ll splatter your face across the road . &#34;&lt;/li&gt;&lt;li&gt;` Bastard ! &#34; cried Bernard , belabouring Jed with his fists , splattering cheap red wine over books and walls .&lt;/li&gt;&lt;li&gt;The priest took the basin of blood and spattered it against the altar .&lt;/li&gt;&lt;li&gt;However , its task is made much more difficult by the fact that derogations granted to the Welsh water authority allow it to pump raw sewage into both those rivers .&lt;/li&gt;&lt;li&gt;The longer we continue to pump lead into the atmosphere , the more it will accumulate .&lt;/li&gt;&lt;li&gt;The Suffolk Water Company is pumping specially dechlorinated water into the habitat of the fen raft spider , Britain &#39;s largest and rarest , to save it from extinction .&lt;/li&gt;&lt;li&gt;However , once the salt fingers are formed , they are pumping salty fluid into the top of the bottom layer and less salty fluid into the bottom of the top layer .&lt
PP)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;For a moment she looked furiously at Donald , her teeth bared like a cat &#39;s , then she shook her hair out , spattering Donald with bree and barley , and hauled him back into the dance .&lt;/li&gt;&lt;li&gt;She came down heavily , spattering her nightdress with earth , shards of flowerpot , dark streaks of water from spilled asters .&lt;/li&gt;&lt;li&gt;His friends carry his rigid , moaning body to one side and an

# %%
cfm_patterns.select(p1_actually).diagram(noncore=False)
# Out:
# Written 13 records.

# %%
cfm_patterns.select(p1_actually).diagram(noncore=False)
# Out:
# Written 13 records.

# %%
cm_groups   = Groups('Cause_motion')
cm_patterns = Patterns(cm_groups)

cm_patterns.display(pattern_matcher=p1_actually)
# Out:
# <style>
#   .popover {
#     /*width: 800px;*/
#     max-width: 800px;
#     /*max-height: 600px;*/
#     /*overflow: scroll;*/
#     z-index: 3500;
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
#
#   .popover.in {
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
# </style>
#
# <script type="text/javascript">
#   $(function () {
#     $('[data-toggle="popover"]').popover()
#   })
# </script><div>Total count: 453</div><table><tr><th></th><th>freq.</th><th>Patterns</th><th></th></tr><tr><td style="text-align: right">1</td>
# <td style="text-align: right">178</td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Theme (NP) → <b>Dep</b>: Goal (PP)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;Anything too technical might catapult him into orbit again .&lt;/li&gt;&lt;li&gt;On one occasion William catapulted a lump of metal into a classroom full of pupils and a girl was quite badly injured .&lt;/li&gt;&lt;li&gt;Divorce or the death of a husband is enough to catapult a middle-class white woman and her children into poverty .&lt;/li&gt;&lt;li&gt;She chucks a bath towel to me .&lt;/li&gt;&lt;li&gt;` Wilhelm wo n&#39;t speak to me since I chucked his Filofax in the jacuzzi .&lt;/li&gt;&lt;li&gt;You can chuck me in the river , if you like , for all the good I am to meself .&lt;/li&gt;&lt;li&gt;We chucked their livers into a large barrel fastened to the mast ; these were sold for cod-liver oil and the money they fetched was the perquisite of the crew .&lt;/li&gt;&lt;li&gt;He chucks it into the sea .&lt;/li&gt;&lt;li&gt;The modern manager establishes his machismo , not by creating a business that can employ thousands , but by buying a business and then chucking all his supposedly supernumerary workers on the dole .&lt;/li&gt;&lt;li&gt;If you just chuck it on the floor , then someone s got to come round alter you and pick it up .&lt;/li&gt;&lt;li&gt;In Ancient Rome they &#39;d have chucked him to the lions .&lt;/li&gt;&lt;li&gt;Dolly chucked the pack at him .&lt;/li&gt;&lt;li&gt;Marie yelled after me to wait but I did n&#39;t want to talk to her about it so I chucked my sandwich-box over to her and told her she could eat them for me .&lt;/li&gt;&lt;li&gt;You ca n&#39;t run with a baby , and I &#39;m not going to drag my kids into the sort of life I &#39;ve been living .&lt;/li&gt;&lt;li&gt;Then I got up and took the two rugs by their corners and dragged them outside the door .&lt;/li&gt;&lt;li&gt;Lucenzo swept over to her , caught her arm and dragged her to the entrance of the ballroom .&lt;/li&gt;&lt;li&gt;He was looking pleased with himself as he dragged the table to the side of the room to make space to work in .&lt;/li&gt;&lt;li&gt;Cornelius dragged the portmanteau towards the inn door .&lt;/li&gt;&lt;li&gt;With a sob , Theda flung her arms about his neck and buried her face in his shoulder .&lt;/li&gt;&lt;li&gt;One of the group then grabbed the boy and flung him against a wall .&lt;/li&gt;&lt;li&gt;Robbie screamed and flung herself against the protective width of Fen &#39;s chest .&lt;/li&gt;&lt;li&gt;Kate flung her arms around him and wept for joy .&lt;/li&gt;&lt;li&gt;Milton flung himself in his chair and buried his head in his hands .&lt;/li&gt;&lt;li&gt;Then , in the very same breath , she snatched up the toppled coffee-cup and flung the lukewarm contents in his face .&lt;/li&gt;&lt;li&gt;Barton scooped up all the bits of paper and flung them into the air .&lt;/li&gt;&lt;li&gt;Suddenly they all surged towards me and flung their coins into the canvas sheet I was guarding and one old codger decided to go home .&lt;/li&gt;&lt;li&gt;He unzipped his black jacket and flung it on a chair .&lt;/li&gt;&lt;li&gt;The customers in return sneered at the clothing offered to them , and flung it on the ground .&lt;/li&gt;&lt;li&gt;He flung the helmet on the ground and Philip grabbed it .&lt;/li&gt;&lt;li&gt;In we would climb , rolling up hats and coats and flinging them onto the back seat .&lt;/li&gt;&lt;li&gt;The men flung a net over me .&lt;/li&gt;&lt;li&gt;She flung herself to the floor and rolled to safety behind the half-opened door , the Beretta clenched tightly in her gloved hand .&lt;/li&gt;&lt;li&gt;` Oh , yer swine , &#34; breathed the young woman as he flung the handbag to the ground .&lt;/li&gt;&lt;li&gt;She flung the tape at him .&lt;/li&gt;&lt;li&gt;JUST AS THE PANTING CYCLIST drew ahead of the London to St Alban &#39;s coach the guard hurled an iron ball on a rope into the spokes of the bicycle wheel and felled the rider .&lt;/li&gt;&lt;li&gt;Two fiesty little Yorkshire terriers leap off his lap and hurl their combined body weight of two grapefruits against my legs .&lt;/li&g ...

# %%
cm_patterns.select(p1_actually).diagram(noncore=False)
# Out:
# Written 22 records.

# %%
p1_NI = Ext & x & Obj & Many1(Dep) & Many(x)
cm_patterns.display(pattern_matcher=p1_NI, min_count=0)
# Out:
# <style>
#   .popover {
#     /*width: 800px;*/
#     max-width: 800px;
#     /*max-height: 600px;*/
#     /*overflow: scroll;*/
#     z-index: 3500;
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
#
#   .popover.in {
#     opacity: 1 !important;
#     filter: alpha(opacity=100);
#   }
# </style>
#
# <script type="text/javascript">
#   $(function () {
#     $('[data-toggle="popover"]').popover()
#   })
# </script><div>Total count: 458</div><table><tr><th></th><th>freq.</th><th>Patterns</th><th></th></tr><tr><td style="text-align: right">1</td>
# <td style="text-align: right">178</td>
# <td style="vertical-align: top ; white-space: nowrap"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Theme (NP) → <b>Dep</b>: Goal (PP)</td>
# <td><button type="button"
#         class="btn btn-default"
#         container="body"
#         data-toggle="popover"
#         data-placement="auto"
#         data-trigger="click"
#         data-html="true"
#         data-content="&lt;ul&gt;&lt;li&gt;Anything too technical might catapult him into orbit again .&lt;/li&gt;&lt;li&gt;On one occasion William catapulted a lump of metal into a classroom full of pupils and a girl was quite badly injured .&lt;/li&gt;&lt;li&gt;Divorce or the death of a husband is enough to catapult a middle-class white woman and her children into poverty .&lt;/li&gt;&lt;li&gt;She chucks a bath towel to me .&lt;/li&gt;&lt;li&gt;` Wilhelm wo n&#39;t speak to me since I chucked his Filofax in the jacuzzi .&lt;/li&gt;&lt;li&gt;You can chuck me in the river , if you like , for all the good I am to meself .&lt;/li&gt;&lt;li&gt;We chucked their livers into a large barrel fastened to the mast ; these were