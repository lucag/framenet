# %% [markdown]
# # DEMO notebook

# %%
from framenet.data.annotation import get_frame_df, Frame, to_layers, gf_or_target, Groups
from framenet.data.pattern    import *
import pandas as pd, qgrid

# %% [markdown]
# ## Overview
#
# This notebook contains:
#
# * a set of patterns used in the pattern-matching process
# * Displays of valence patterns for a given FrameNet frame, filtered in various ways, and displayed as:
#        * tables of valence patterns, with sentence examples
#        * San-Key flow diagrams

# %% [markdown]
# ## Patterns used for pattern-matching process
#
# We need to do this only once per Notebook. We need those becuase we describe the patterns we look for as Python expressions. The following applies the constructor `Lit` to the strings `'Ext'`, `'Obj'`, `'Dep'`, and `'_'` (our wildcard) and assigns the result to the corresponding Python variables. This way `Ext`, `Obj`, `Dep` and `x` can be combined in the patterns below.
#
#
#    ### The symbols that are used in the pattern definitions:
#
# <table>
# <tr><th>Symbol</th><th>Meaning</th><th>Category</th></tr>
# <tr><td>Ext</td><td>external argument (e.g. subject)</td><td>GF</td></tr>
# <tr><td>x<td>wildcard element (e.g. verb)</td><td>Target</td></tr>
# <tr><td>Obj</td><td>direct object</td><td>GF</td></tr>
# <tr><td>Dep</td><td>dependent</td><td>GF</td></tr>
# <tr><td>CNI</td><td>Constructional Null Instantiation</td><td>NI</td></tr>
# <tr><td>DNI</td><td>Definite Null Instantiation</td><td>NI</td></tr>
# <tr><td>INI</td><td>Indefinite Null Instantiation</td><td>NI</td></tr>
# </table>
#
#
#
#
# ### The operators used to create patterns:
#
# <table>
# <tr><th>The operator</th><th>means</th></tr>
# <tr><td>&amp;</td><td>_followed by_</td></tr>
# <tr><td>`|`</td><td>_one or the other_</td></tr>
# <tr><td>`Many1(...)`</td><td>_one or more of ..._</td></tr>
# <tr><td>`Many(...)`</td><td>_zero or more of ..._</td></tr>
# <tr><td>`Opt(...)`</td><td>_optionally ..._</td></tr>
# </table>

# %%
Ext, Obj, Dep, x, CNI, DNI, INI = map(Lit, 'Ext Obj Dep _ CNI DNI INI'.split())

# %% [markdown]
# ### Active transitive, no dependents

# %%
p1 = Ext & x & Obj 
p1_NI = Ext & x & Obj & Opt(CNI|DNI|INI)

# %% [markdown]
# ### Active transitive, plus one or more dependents

# %%
p1_dep = Ext & x & Obj & Many1(Dep)
p1_dep_NI = Ext & x & Obj & Many1(Dep) & Opt(CNI|DNI|INI)

# %% [markdown]
# ### Intransitive or Passive transitive

# %%
p2 =  Ext & x 
p2_dep = Ext & x & Many1(Dep)
p2_dep_NI = Ext & x & Many1(Dep) & Opt(CNI|DNI|INI)

# %% [markdown]
# ### Imperative for 'full' active transitive
#
# This is pattern 'p1_dep_NI', minus the Ext argument

# %%
p3 = x & Obj & Many1(Dep) & Opt(CNI|DNI|INI)

# %% [markdown]
# ### Active Transitive with Dep FE immediately following the verb
# * E.g.
# Note that in FN annotation, bare prepositions are given the same PT as full prepositional phrases.

# %%
p4 = Ext & x & Dep & Obj & Many(Dep) & Opt(CNI|DNI|INI)

# %% [markdown]
# ### Active transitive in relative clauses

# %%
p5_rel_subj = Ext & Ext & x & Obj & Many1(Dep) & Opt(CNI|DNI|INI)
p5_rel_obj  = Obj & (Obj) & Ext & x & Many1(Dep) & Opt(CNI|DNI|INI)

# %% [markdown]
# ## TODO:
# ### 1. add sentence examples for the different patterns?

# %% [markdown]
# ## A table showing the patterns defined in this notebook:
#
# <table>
# <tr><th>Name</th><th>Desciption</th><th>Pattern</th><th>Finds</th></tr>
# <tr><td>p1</td><td>active transitive</td><td>Ext & x & Obj</td><td>Ext > V > Obj </td></tr>
# <tr><td>p1_NI<td>active transitive plus optional NI FEs</td><td>Ext & x & Obj & Opt(CNI|DNI|INI)</td><td>Ext > V > Obj + (NI)</td></tr>
# <tr><td>p1_dep</td><td>active transitive with dependent(s)</td><td>Ext & x & Obj & Many1(Dep)</td><td>Ext > V > Obj > Dep</td></tr>
# <tr><td>p1_dep_NI</td><td>active transitive with dep(s), plus optional NI FEs</td><td>Ext & x & Obj & Many1(Dep) & Opt(CNI|DNI|INI)</td><td>Ext > V > Obj > Dep + (NI)</td></tr>
# <tr><td>p2</td><td>intransitive/active passive</td><td>Ext & x </td><td>Ext > Verb</td></tr>
# <tr><td>p2_dep</td><td>intransitive/active passive with dep(s)</td><td>Ext & x & Many1(Dep)</td><td>Ext > Verb > Dep</td></tr>
# <tr><td>p2_dep_NI</td><td>intransitive/active passive, plus optional NI FEs</td><td>Ext & x & Many1(Dep) & Opt(CNI|DNI|INI)</td><td>Ext > Verb > Dep + (NI)</td></tr>
# <tr><td>p3</td><td>Imperative </td><td>x & Obj & Many1(Dep) & Opt(CNI|DNI|INI)</td><td>V > Obj > Dep</td></tr>
# <tr><td>p4</td><td>active trans with v > dep > obj </td><td>Ext & x & Dep & Obj & Many1(Dep) & Opt(CNI|DNI|INI)</td><td>Ext > Dep > Obj > Many(Dep) + (NI)</td></tr>
# <tr><td>p5_rel_subj</td><td>active trans in subj relative clause </td><td>Ext & Ext & x & Obj & Many1(Dep) & Opt(CNI|DNI|INI)</td><td>Ext > Ext> Obj > Many(Dep) + (NI)</td></tr>
# <tr><td>p5_rel_obj</td><td>active trans in 0bj relative clause </td><td>Obj & (Obj) & Ext & x & Many1(Dep) & Opt(CNI|DNI|INI)</td><td>Obj > Obj > Ext> Many(Dep) + (NI)</td></tr>
# </table>

# %% [markdown]
# # Select FrameNet `Frame`
#
# 'Frame` simply groups together the information related to a specific FN frame.

# %%
cfm = Frame('Cause_fluidic_motion')

# %% [markdown]
# ### Here are the lexical units for the selected frame:

# %%
cfm.groups.data_frame['annotationSet.LU'].unique()
# Out:
# array(['dribble.v', 'spill.v', 'spatter.v', 'splatter.v', 'splash.v',
#        'spray.v', 'squirt.v', 'pump.v'], dtype=object)

# %% [markdown]
# # Look at different patterns: two methods
#
# ## 1. Display method: show selected patterns as a table
#
# ### The `display` method understands the following keywords, all optional:
#
# * `pattern_matcher`: defined as the above expressions, or `None` / unspecified. E.g. pattern_matcher = p1
# * `min_count`: the minimum count for sentences matching a pattern; a nonnegative integer number
# * `negative`: a boolean specifying whether a pattern should be inverted (when set to 'True', picks up sentences that *do not* match)
#
# The display method also returns a total count of the sentences that meet the display criteria.
# One way to display all of the sentences annotated for a given frame is to use `display`without any parameters: `display()`

# %% [markdown]
# ### Display example 1:  Look at all of the sentences annotated for the selected frame:

# %%
cfm.display()
# Out:
# <style type="text/css" media="screen">
# a.link-hover:link { color: #000; text-decoration: none; }
# a.link-hover:visited { color: #000; text-decoration: none; }
# a.link-hover:hover { text-decoration: underline; }
# a.link-hover:active { color: #000; text-decoration: none; }
# </style><div>Total count: 143</div><table><tr><th></th><th>freq.</th><th>Patterns</th></tr><tr><td style="text-align: right">1</td><td style="text-align: right">42</td><td><a class="link-hover" data-toggle="collapse" href="#344bd4dd-c330-4d15-b113-97e8fd5fac1a"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Goal (P
><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>INI</b>: Area (None)</a><div id="de70ea94-f5bc-4280-bce9-bc163b8941e9" class="collapse"><ul><li>My hand jerked so that I almost spilled my wine .</li><li>Jenna jumped up , almost spilling her coffee , making a hasty grab for the delicate cup and amusing him even more .</li></ul></div></td></tr>
# <tr><td style="text-align: right">10</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#d66a8acb-1399-4043-ac0b-4267252e4434"><b>Ext</b>: Fluid (NP) → v → <b>Obj</b>: Goal (NP) → <b>CNI</b>: Agent (None)</a><div id="d66a8acb-1399-4043-ac0b-4267252e4434" class="collapse"><ul><li>RED ink is splattered all over Britain 's companies .</li></ul></div></td></tr>
# <tr><td style="text-align: right">11</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#b5dbb956-c62e-4b61-a52e-a2a7ef1dbfb7"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Path (PP) → <b>DNI</b>: Goal (None)</a><div id="b5dbb956-c62e-4b61-a52e-a2a7ef1dbfb7" class="collapse"><ul><li>At that moment a youth sprinted past , tipped over her glass and splattered the tomato juice across the concrete .</li></ul></div></t

# %% [markdown]
# ## 2. Flow diagram method: show selected patterns as a Sankey flow diagram
#
# ### The `select` method understands some of the same keywords as the  `display` method (above):
#
# * `pattern_matcher`: defined as the above expressions, or `None` / unspecified. E.g. pattern_matcher = p1
# * `negative`: a boolean specifying whether a pattern should be inverted (when set to 'True', picks up sentences that *do not* match)
#
# The select method also returns a total count of the sentences that meet the display criteria.
#
# ### It is also possible to specify whether 'noncore' FEs (frame elements) should be included in the flow diagram:
#
# * `diagram` method takes an optional keyword argument to select noncore `FE`s. The default value is `True`.
# * the `diagram` method also takes an optional argument to specify diagram size. E.g. size=(960, 768)
#
#
# ### Note: this method ignore phrase type (PT) distinctions in the annotated data.
#           E.g. it groups together Dep: Path" regardless of whether the phrase type is PP or AVP.

# %% [markdown]
# ### Flow diagram method example 1: Chart for the Active Transitive plus dependents' pattern (p1_dep), fo core FEs only

# %%
cfm.select(p1_dep_NI, negative=False).diagram(noncore=True, size=(960, 768))
# Out:
# Written 27 records.

# %% [markdown]
# ## More examples we worked on
#
# ### The `Filling` frame
#
# Comment here.

# %%
filling = Frame('Filling')
filling.display(pattern_matcher=p1, min_count=3, negative=False)
# Out:
# <style type="text/css" media="screen">
# a.link-hover:link { color: #000; text-decoration: none; }
# a.link-hover:visited { color: #000; text-decoration: none; }
# a.link-hover:hover { text-decoration: underline; }
# a.link-hover:active { color: #000; text-decoration: none; }
# </style><div>Total count: 18</div><table><tr><th></th><th>freq.</th><th>Patterns</th></tr><tr><td style="text-align: right">1</td><td style="text-align: right">18</td><td><a class="link-hover" data-toggle="collapse" href="#f9bdada4-3283-4bc1-bb60-f935d516ae99"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Goal (NP)</a><div id="f9bdada4-3283-4bc1-bb60-f935d516ae99" class="collapse"><ul><li>When she 'd cut sufficient slices she buttered them .</li><li>For example , I might butter a piece of bread and be unable to gauge whether the procedure was taking me seconds or days .</li><li>` Sixteen , " said Jimmy , buttering his toast .</li><li>You should n't have buttered her up when they had dinner here . "</li><li>In the rectory kitchen Lavinia and Mrs Blackham and Mrs Goff buttered buns and cut up sponge cake and ginger cake and fruitcake , and arranged oatmeal fingers on plates .</li><li>Mrs Blackham was buttering more buns .</li><li>Karen buttered toast , and put more bread in the machine .</li><li>Virginia buttered another roll , and sent up a silent vote of thanks for whoever had invented sun-glasses .</li><li>Leonora buttered toast with a steady hand .</li><li>It was a dream I had -- We were wallpapering a wall , Dad and Mum and Bri and me .</li><li>She had been halfway through wallpapering one room when the pull of the sun had grown too strong to resist a second longer .</li><li>Shall I varnish my n

# Out:
# <style type="text/css" media="screen">
# a.link-hover:link { color: #000; text-decoration: none; }
# a.link-hover:visited { color: #000; text-decoration: none; }
# a.link-hover:hover { text-decoration: underline; }
# a.link-hover:active { color: #000; text-decoration: none; }
# </style><div>Total count: 3</div><table><tr><th></th><th>freq.</th><th>Patterns</th></tr><tr><td style="text-align: right">1</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#ffd73be2-4169-4a97-a6a9-d8bacc6f47cc"><b>Ext</b>: Fluid (NP) → v → <b>Dep</b>: Manner (PP) → <b>Obj</b>: Area (NP) → <b>INI</b>: Cause (None)</a><div id="ffd73be2-4169-4a97-a6a9-d8bacc6f47cc" class="collapse"><ul><li>The rain , which had been coming and going , began to pour down again , spattering in big gobs all over the glass around them .</li></ul></div></td></tr>
# <tr><td style="text-align: right">2</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#43e1d621-e38a-48a6-b31f-12bad08f508f"><b>Ext</b>: Cause (NP) → v → <b>Dep</b>: Path (AVP) → <b>Obj</b>: Fluid (NP)</a><div id="43e1d621-e38a-48a6-b31f-12bad08f508f" class="collapse"><ul><li>This in turn helps your body to pump out toxins and excess fluid .</li></ul></div></td></tr>
# <tr><td style="text-align: right">3</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#8f6c6521-ab75-4ca4-8eb7-464259bdaf4a"><b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Goal (AVP) → <b>Obj</b>: Fluid (NP) → <b>Dep</b>: Time (PP)</a><div id="8f6c6521-ab75-4ca4-8eb7-464259bdaf4a" class="collapse"><ul><li>Surprisingly , it 's normal for some women to squirt out a fluid at the moment of orgasm .</li></ul></div></td></tr></table>

# %%
cfm.select(p1_dep_NI).diagram(noncore=False)
# Out:
# Written 14 records.

# %%
cfm.select(p1_dep_NI).diagram(noncore=False)
# Out:
# Written 14 records.

# %%
cm = Frame('Cause_motion')

# %%
cm.display(
    pattern_matcher=(p1_dep_NI) | (p2_dep_NI) | (p3) | (p4) | (p5_rel_subj) | (p5_rel_obj), 
    negative=True, 
    min_count=1,
)
# Out:
# <style type="text/css" media="screen">
# a.link-hover:link { color: #000; text-decoration: none; }
# a.link-hover:visited { color: #000; text-decoration: none; }
# a.link-hover:hover { text-decoration: underline; }
# a.link-hover:active { color: #000; text-decoration: none; }
# </style><div>Total count: 82</div><table><tr><th></th><th>freq.</th><th>Patterns</th></tr><tr><td style="text-align: right">1</td><td style="text-align: right">7</td><td><a class="link-hover" data-toggle="collapse" href="#cbe3cc22-9cdb-49d5-9982-900aac8f83d7"><b>Ext</b>: Agent (NP) → v → <b>Obj</b>: Theme (NP) → <b>INI</b>: Goal (None)</a><div id="cbe3cc22-9cdb-49d5-9982-900aac8f83d7" class="collapse"><ul><li>When you chuck the arrow , gravity takes effect and it arches realistically in flight .</li><li>On duty she strode about looking as if she could not wait to get off duty and chuck a discus .</li><li>I go to funerals and chuck earth .</li><li>Morton went off with him and returned pushing a wide porter 's barrow , with empty sacks in it .</li><li>In other words , there will always be diesel and petrol , however much the proponents of each fuel push their own products .</li><li>She says he throws things without thinking about the damage it does .</li><li>When he told them how he had thrown the Bible , Mrs Wood gave a little scream .</li></ul></div></td></tr>
# <tr><td style="text-align: right">2</td><td style="text-align: right">7</td><td><a class="link-hover" data-toggle="collapse" href="#0f77bc30-c7c6-46bf-9c50-4b56dfd7aeeb">v → <b>Dep</b>: Goal (PP) → <b>Obj</b>: Theme (NP) → <b>CNI</b>: Agent (None)</a><div id="0f77bc30-c7c6-46bf-9c50-4b56dfd7aeeb" class="collapse"><ul><li>There 's a lot to be said for making the trench in autumn , chucking in household waste all winter and replacing the soil in spring .</li><li>Press down the edges to seal and trim off the excess pastry .</li><li>Push over those fried tomatoes , will you , James ? "</li><li>Simmer with plenty of fish sauce , of course , and perhaps some fresh ginger slices , and then remove them and throw in finely sliced lemon grass and kaffir lime leaf .</li><li>Throw over a covering of compost , peat , leaves or newspaper , wrap with sacking or cartons , and hardy plants will then be happy enough , for a few weeks if need be .</li><li>He reckoned he had done well to get away with two cups of tea and forty minutes of reminiscence before an opening arose to thrust in a question .</li><li>All they had to do was pile the earth back on top of the coffin and toss in a few bulbs of garlic just to be on the safe side .</li></ul></div></td></tr>
# <tr><td style="text-align: right">3</td><td style="text-align: right
buried his head in his hands .</li><li>Then , in the very same breath , she snatched up the toppled coffee-cup and flung the lukewarm contents in his face .</li><li>Barton scooped up all the bits of paper and flung them into the air .</li><li>Suddenly they all surged towards me and flung their coins into the canvas sheet I was guarding and one old codger decided to go home .</li><li>He unzipped his black jacket and flung it on a chair .</li><li>The customers in return sneered at the clothing offered to them , and flung it on the ground .</li><li>He flung the helmet on the ground and Philip grabbed it .</li><li>In we would climb , rolling up hats and coats and flinging them onto the back seat .</li><li>The men flung a net over me .</li><li>She flung herself to the floor and rolled to safety behind the half-opened door , the Beretta clenched tightly in her gloved hand .</li><li>` Oh , yer swine , " breathed the young woman as he flung the handbag to the ground .</li><li>She flung the tape at him .</li><li>JUST AS THE PANTING CYCLIST drew ahead of the London to St Alban 's coach the guard hurled an iron ball on a rope into the spokes of the bicycle wheel and felled the rider .</li><li>Two fiesty little Yorkshire terriers leap off his lap and hurl their combined body weight of two grapefruits against my legs .</li><li>He suddenly grabbed the beer can and hurled it against the wall then upturned the ta ...

# %%
    cm.display(pattern_matcher=(p5_rel_obj))
# Out:
# <style type="text/css" media="screen">
# a.link-hover:link { color: #000; text-decoration: none; }
# a.link-hover:visited { color: #000; text-decoration: none; }
# a.link-hover:hover { text-decoration: underline; }
# a.link-hover:active { color: #000; text-decoration: none; }
# </style><div>Total count: 9</div><table><tr><th></th><th>freq.</th><th>Patterns</th></tr><tr><td style="text-align: right">1</td><td style="text-align: right">5</td><td><a class="link-hover" data-toggle="collapse" href="#050c44fc-6e01-4602-8e75-8e60895a974b"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Goal (PP)</a><div id="050c44fc-6e01-4602-8e75-8e60895a974b" class="collapse"><ul><li>One of them picked up the rolled newspaper which Clasper had flung into the crowd .</li><li>He slurped as noisily as a ravenous dog , mopping up what was left with hard crusts of bread which Father Peter shoved before him on a wooden platter .</li><li>The Feldwebel took it into a corner and pulled out a large envelope which he threw onto the table .</li><li>He caught the pliers that she threw to him , and the ball of string , and then went to hold the step-ladder steady while Kitty descended .</li><li>` We 'll be more likely to get killed with them falling on us than anything what the Jerrys throw down , " Hetty said .</li></ul></div></td></tr>
# <tr><td style="text-align: right">2</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#8056c3d6-988c-41bd-98ac-6df85d16b7ad"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Source (PP)</a><div id="8056c3d6-988c-41bd-98ac-6df85d16b7ad" class="collapse"><ul><li>The next article that Zach dragged out was a stiff black circular object .</li></ul></div></td></tr>
# <tr><td style="text-align: right">3</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#537b9fe0-522d-4dc3-877b-fb7fdf678c3f"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Area (PP)</a><div id="537b9fe0-522d-4dc3-877b-fb7fdf678c3f" class="collapse"><ul><li>She was no longer a nervous little nineteen-year-old that he could push around as he pleased .</li></ul></div></td></tr>
# <tr><td style="text-align: right">4</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#d8edcf17-d515-48c0-8041-69f1edac31ff"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Manner (AVP) → <b>Dep</b>: Goal (PP)</a><div id="d8edcf17-d515-48c0-8041-69f1edac31ff" class="collapse"><ul><li>When she hurried out to the car , carrying her drawing materials which she had shoved hurriedly into a canvas bag , Julius was already sitting in the driving seat .</li></ul></div></td></tr>
# <tr><td style="text-align: right">5</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#62074083-f955-479a-a557-93b790113178"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Goal (AVP)</a><div id="62074083-f955-479a-a557-93b790113178" class="collapse"><ul><li>She sank down on to the bed and glanced at the writing pad that she 'd tossed there after a brief effort to write to Arnie .</li></ul></div></td></tr></table>

# %%
cm.select(
    pattern_matcher=(p1_dep_NI) | (p2_dep_NI) | (p3), 
    negative=True, 
).diagram(noncore=False)
# Out:
# Written 70 records.

# %%
cm.select(p1_dep_NI).diagram(noncore=False)
# Out:
# Written 22 records.

# %%
cm.display(
    pattern_matcher= None,
    negative=False, 
    min_count=8,
    include_sentences=False
)
# Out:
# <style type="text/css" media="screen">
# a.link-hover:link { color: #000; text-decoration: none; }
# a.link-hover:visited { color: #000; text-decoration: none; }
# a.link-hover:hover { text-decoration: underline; }
# a.link-hover:active { color: #000; text-decoration: none; }
# </style><div>Total count:
><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Goal (PP)</a><div id="1a821bf0-7509-49a3-8d63-e2c86b938c35" class="collapse"><ul><li>One of them picked up the rolled newspaper which Clasper had flung into the crowd .</li><li>He slurped as noisily as a ravenous dog , mopping up what was left with hard crusts of bread which Father Peter shoved before him on a wooden platter .</li><li>The Feldwebel took it into a corner and pulled out a large envelope which he threw onto the table .</li><li>He caught the pliers that she threw to him , and the ball of string , and then went to hold the step-ladder steady while Kitty descended .</li><li>` We 'll be more likely to get killed with them falling on us than anything what the Jerrys throw down , " Hetty said .</li></ul></div></td></tr>
# <tr><td style="text-align: right">2</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#7e37c4de-969e-4aad-9382-1cb9f4a32b7f"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Source (PP)</a><div id="7e37c4de-969e-4aad-9382-1cb9f4a32b7f" class="collapse"><ul><li>The next article that Zach dragged out was a stiff black circular object .</li></ul></div></td></tr>
# <tr><td style="text-align: right">3</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#f670f288-6a40-43d6-ac68-cf4cbd7e2884"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Area (PP)</a><div id="f670f288-6a40-43d6-ac68-cf4cbd7e2884" class="collapse"><ul><li>She was no longer a nervous little nineteen-year-old that he could push around as he pleased .</li></ul></div></td></tr>
# <tr><td style="text-align: right">4</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#379d3d8a-53b8-4432-a88e-d786e38871c1"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Manner (AVP) → <b>Dep</b>: Goal (PP)</a><div id="379d3d8a-53b8-4432-a88e-d786e38871c1" class="collapse"><ul><li>When she hurried out to the car , carrying her drawing materials which she had shoved hurriedly into a canvas bag , Julius was already sitting in the driving seat .</li></ul></div></td></tr>
# <tr><td style="text-align: right">5</td><td style="text-align: right">1</td><td><a class="link-hover" data-toggle="collapse" href="#fe64a145-074c-4107-b3aa-0fc21ce1bd29"><b>Obj</b>: Theme (NP) → <b>Obj</b>: Theme (NP) → <b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Goal (AVP)</a><div id="fe64a145-074c-4107-b3aa-0fc21ce1bd29" class="collapse"><ul><li>She sank down on to the bed and glanced at the writing pad that she 'd tossed there after a brief effort to write to Arnie .</li></ul></div></td></tr></table>

# %%
cm.display(pattern_matcher=p4, min_count=0)
# Out:
# <style type="text/css" media="screen">
# a.link-hover:link { color: #000; text-decoration: none; }
# a.link-hover:visited { color: #000; text-decoration: none; }
# a.link-hover:hover { text-decoration: underline; }
# a.link-hover:active { color: #000; text-decoration: none; }
# </style><div>Total count: 57</div><table><tr><th></th><th>freq.</th><th>Patterns</th></tr><tr><td style="text-align: right">1</td><td style="text-align: right">18</td><td><a class="link-hover" data-toggle="collapse" href="#dd49e6e9-913e-4cd5-a581-6c86007013df"><b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Goal (PP) → <b>Obj</b>: Theme (NP)</a><div id="dd49e6e9-913e-4cd5-a581-6c86007013df" class="collapse"><ul><li>Dexter dragged over a chair and sat down at the desk .</li><li>` She bit me last night , " he said , dragging up his trouser-leg and showing her the line of tiny red marks .</li><li>Finn flung down his paintbrush .</li><li>Denis flung down his gun in disgust .</li><li>Helen flung down her knife .</li><li>Angus and Sawney flung down their weapons .</li><li>Any engine machining company should be able to bore out your head and press in the valve seat inserts ( ETC 6278 ) and recut them .</li><li>They tipped the contents of one oil drum into the car and threw in a burning rag .</li><li>If it looks good he throws on more wood , if it looks bad he throws on more paraffin .</li><li>He threw down his goose quill and grasped the clerk 's hands , pumping them up and down vigorously .</li><li>The PLAYER tosses down his last coin by way of paying up , and turns away .</li><li>He broke eye-contact , lifting his glass to his mouth , throwing his head back and tossing down the contents of the glass with one smooth action
><b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Path (PP) → <b>Obj</b>: Theme (NP)</a><div id="21f81eca-c93d-4c04-bdcd-d96a3edaad27" class="collapse"><ul><li>They had consistently failed to push through reforms when governing alone .</li><li>They claim that the huge crop will push down prices , and this , coupled with cheap imported plums from Spain will mean it simply wo n't be worth picking the fruits .</li><li>That would push up mortgage interest rates and have a catastrophic effect on the prospects for recovery , Mr Mellor said .</li><li>Shiona thrust up her chin and looked straight at him .</li><li>His first experience of the conflict between two powerful men , tossing between them the idea of war .</li></ul></div></td></tr>
# <tr><td style="text-align: right">5</td><td style="text-align: right">3</td><td><a class="link-hover" data-toggle="collapse" href="#1b9a1fb0-2090-4e58-be4a-2893fd4ad506"><b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Path (AVP) → <b>Obj</b>: Theme (NP)</a><div id="1b9a1fb0-2090-4e58-be4a-2893fd4ad506" class="collapse"><ul><li>He pushed forward the safety catch of his pistol .</li><li>Firms that should be investing and preparing are throwing overboard , just to survive , research , design and everything , including model changes and investment , to struggle through a depression that the Government have created .</li><li>The more you thrust forward your ideas , your solutions , your methods , the less the subordinate will feel responsible for his own actions , and hence committed .</li></ul></div></td></tr>
# <tr><td style="text-align: right">6</td><td style="text-align: right">2</td><td><a class="link-hover" data-toggle="collapse" href="#76731c76-730c-41cf-b444-9f99f5d20c63"><b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Source (AVP) → <b>Obj</b>: Theme (NP)</a><div id="76731c76-730c-41cf-b444-9f99f5d20c63" class="collapse"><ul><li>The last of the mercenaries were running , flinging away their weapons as they went .</li><li>But he also knew the moment he threw away the shotgun , he was also throwing away his last hope of survival .</li></ul></div></td></tr>
# <tr><td style="text-align: right">7</td><td style="text-align: right">2</td><td><a class="link-hover" data-toggle="collapse" href="#1658c376-61bb-42c6-bdcf-4a83916a6a2e"><b>Ext</b>: Agent (NP) → v → <b>Dep</b>: Result (AJP) → <b>Obj</b>: Theme (NP)</a><div id="1658c376-61bb-42c6-bdcf-4a83916a6a2e" class="collapse"><ul><li>He thrust open his bedroom door , turned , hands in the pockets of that immaculate dark blue suit .</li><li>She turned back

# %%
cm.select(p4).diagram(size=(960, 768))
# Out:
# Written 13 records.

# %%
giving = Frame('Giving')

# %%
giving.display(min_count=10)
# Out:
# 'Problem with group'
# [[{'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': 8.0,
#    'label.feID': 1052.0,
#    'label.itype': nan,
#    'label.name': 'Donor',
#    'label.start': 0.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 8.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Ext',
#    'label.start': 0.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 8.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'NP',
#    'label.start': 0.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557670,
#    'annotationSet.LU': 'gift.n',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': 3.0,
#    'label.feID': 1052.0,
#    'label.itype': nan,
#    'label.name': 'Donor',
#    'label.start': 0.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557670,
#    'annotationSet.LU': 'gift.n',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 3.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Gen',
#    'label.start': 0.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557670,
#    'annotationSet.LU': 'gift.n',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 3.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Poss',
#    'label.start': 0.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557670,
#    'annotationSet.LU': 'gift.n',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 8.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'gift.n',
#    'label.start': 5.0,
#    'layer.name': 'Target',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 18.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'give.v',
#    'label.start': 15.0,
#    'layer.name': 'Target',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': 40.0,
#    'label.feID': 1053.0,
#    'label.itype': nan,
#    'label.name': 'Recipient',
#    'label.start': 20.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 40.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Dep',
#    'label.start': 20.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 40.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'NP',
#    'label.start': 20.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': 68.0,
#    'label.feID': 1054.0,
#    'label.itype': nan,
#    'label.name': 'Theme',
#    'label.start': 42.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 68.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Obj',
#    'label.start': 42.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'},
#   {'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 68.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'NP',
#    'label.start': 42.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Other',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Sent',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557671,
#    'annotationSet.LU': 'give.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Verb',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557670,
#    'annotationSet.LU': 'gift.n',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': nan,
#    'label.feID': 1053.0,
#    'label.itype': 'DNI',
#    'label.name': 'Recipient',
#    'label.start': nan,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557670,
#    'annotationSet.LU': 'gift.n',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Other',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557670,
#    'annotationSet.LU': 'gift.n',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Sent',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}],
#  [{'annotationSet.ID': 6557670,
#    'annotationSet.LU': 'gift.n',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Noun',
#    'layer.rank': 1,
#    'sentence.ID': 4106613,
#    'sentence.aPos': 0,
#    'sentence.corpID': 195.0,
#    'sentence.docID': 23811.0,
#    'sentence.paragNo': 8.0,
#    'sentence.sentNo': 4,
#    'text.contents': 'Your gift will give children and families hope for '
#                     'improved tomorrows .'}]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9f6d183a2a92> in <module>()
# ----> 1 giving.display(min_count=10)
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in display(self, pattern_matcher, negative, min_count, include_sentences)
#     483
#     484         gts   = [(tuple(gf_pt_or_(l) for l in to_layers(g)), text(g))
# --> 485                  for g in self.groups.groups if pred(to_layers(g))]
#     486
#     487         p_to_ss  = defaultdict(list)
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in <listcomp>(.0)
#     483
#     484         gts   = [(tuple(gf_pt_or_(l) for l in to_layers(g)), text(g))
# --> 485                  for g in self.groups.groups if pred(to_layers(g))]
#     486
#     487         p_to_ss  = defaultdict(list)
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in to_layers(dss, layer_names)
#     166
#     167     try:
# --> 168         ls = [p(ds) for ds in dss if p(ds)]
#     169         return ls
#     170     except ValueError:
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in <listcomp>(.0)
#     166
#     167     try:
# --> 168         ls = [p(ds) for ds in dss if p(ds)]
#     169         return ls
#     170     except ValueError:
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in p(ds)
#     162
#     163     def p(ds):
# --> 164         return merge(dict(), [i for d in ds for i in pivot(d)
#     165                               if d['layer.name'] in layer_names and d['layer.rank'] == 1])
#     166
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/util.py in merge(m, items)
#     654     for k, v in items:
#     655         if k in m and m[k] != v:
# --> 656             raise ValueError('Item (%s -> %s) already in dictionary %s (%s)' % (k, v, m, items))
#     657         else:
#     658             m[k] = v
#
# ValueError: Item (GF -> Gen) already in dictionary {'FE': 'Donor', 'core': True, 'GF': 'Ext', 'PT': 'NP'} ([('FE', 'Donor'), ('core', True), ('GF', 'Ext'), ('PT', 'NP'), ('FE', 'Donor'), ('core', True), ('GF', 'Gen'), ('PT', 'Poss')])

# %%
fm = Frame('Fluidic_motion')
fm.display(min_count=10)
# Out:
# 'Problem with group'
# [[{'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 0.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Metaphor',
#    'label.start': 0.0,
#    'layer.name': 'Sent',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 0.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Metaphor',
#    'label.start': 0.0,
#    'layer.name': 'Sent',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': 117.0,
#    'label.feID': 2983.0,
#    'label.itype': nan,
#    'label.name': 'Fluid',
#    'label.start': 13.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 117.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Ext',
#    'label.start': 13.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 117.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'NP',
#    'label.start': 13.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 117.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Rel',
#    'label.start': 13.0,
#    'layer.name': 'Other',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': 117.0,
#    'label.feID': 2983.0,
#    'label.itype': nan,
#    'label.name': 'Fluid',
#    'label.start': 13.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 117.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Ext',
#    'label.start': 13.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 117.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'NP',
#    'label.start': 13.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 125.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'spill.v',
#    'label.start': 119.0,
#    'layer.name': 'Target',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 125.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'spill.v',
#    'label.start': 119.0,
#    'layer.name': 'Target',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': 143.0,
#    'label.feID': 2979.0,
#    'label.itype': nan,
#    'label.name': 'Goal',
#    'label.start': 127.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 143.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Dep',
#    'label.start': 127.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 143.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'PP',
#    'label.start': 127.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 143.0,
#    'label.feID': 2988.0,
#    'label.itype': nan,
#    'label.name': 'Configuration',
#    'label.start': 127.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 143.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Dep',
#    'label.start': 127.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 143.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'PP',
#    'label.start': 127.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 149.0,
#    'label.feID': 2984.0,
#    'label.itype': nan,
#    'label.name': 'Time',
#    'label.start': 145.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 149.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Dep',
#    'label.start': 145.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 149.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'NP',
#    'label.start': 145.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 149.0,
#    'label.feID': 2984.0,
#    'label.itype': nan,
#    'label.name': 'Time',
#    'label.start': 145.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 149.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Dep',
#    'label.start': 145.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 169.0,
#    'label.feID': 4842.0,
#    'label.itype': nan,
#    'label.name': 'Place',
#    'label.start': 151.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 169.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Dep',
#    'label.start': 151.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 169.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'PP',
#    'label.start': 151.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547982,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Verb',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 149.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'NP',
#    'label.start': 145.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': True,
#    'label.end': 169.0,
#    'label.feID': 2979.0,
#    'label.itype': nan,
#    'label.name': 'Goal',
#    'label.start': 151.0,
#    'layer.name': 'FE',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 169.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'Dep',
#    'label.start': 151.0,
#    'layer.name': 'GF',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'},
#   {'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': 169.0,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': 'PP',
#    'label.start': 151.0,
#    'layer.name': 'PT',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Other',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}],
#  [{'annotationSet.ID': 6547992,
#    'annotationSet.LU': 'spill.v',
#    'annotationSet.status': 'MANUAL',
#    'label.coreFE': nan,
#    'label.end': nan,
#    'label.feID': nan,
#    'label.itype': nan,
#    'label.name': nan,
#    'label.start': nan,
#    'layer.name': 'Verb',
#    'layer.rank': 1,
#    'sentence.ID': 4102337,
#    'sentence.aPos': 0,
#    'sentence.corpID': 205.0,
#    'sentence.docID': 23733.0,
#    'sentence.paragNo': 1.0,
#    'sentence.sentNo': 1,
#    'text.contents': 'Paula_Zahn : Questions about the facts or what were '
#                     'presented as facts that led the United States into the '
#                     'war in Iraq spilled into open warfare today on the Senate '
#                     'floor .'}]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-11c6bca0bd7b> in <module>()
#       1 fm = Frame('Fluidic_motion')
# ----> 2 fm.display(min_count=10)
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in display(self, pattern_matcher, negative, min_count, include_sentences)
#     483
#     484         gts   = [(tuple(gf_pt_or_(l) for l in to_layers(g)), text(g))
# --> 485                  for g in self.groups.groups if pred(to_layers(g))]
#     486
#     487         p_to_ss  = defaultdict(list)
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in <listcomp>(.0)
#     483
#     484         gts   = [(tuple(gf_pt_or_(l) for l in to_layers(g)), text(g))
# --> 485                  for g in self.groups.groups if pred(to_layers(g))]
#     486
#     487         p_to_ss  = defaultdict(list)
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in to_layers(dss, layer_names)
#     166
#     167     try:
# --> 168         ls = [p(ds) for ds in dss if p(ds)]
#     169         return ls
#     170     except ValueError:
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in <listcomp>(.0)
#     166
#     167     try:
# --> 168         ls = [p(ds) for ds in dss if p(ds)]
#     169         return ls
#     170     except ValueError:
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/data/annotation.py in p(ds)
#     162
#     163     def p(ds):
# --> 164         return merge(dict(), [i for d in ds for i in pivot(d)
#     165                               if d['layer.name'] in layer_names and d['layer.rank'] == 1])
#     166
#
# /Users/lucag/Documents/Sources/framenet/src/main/framenet/util.py in merge(m, items)
#     654     for k, v in items:
#     655         if k in m and m[k] != v:
# --> 656             raise ValueError('Item (%s -> %s) already in dictionary %s (%s)' % (k, v, m, items))
#     657         else:
#     658             m[k] = v
#
# ValueError: Item (FE -> Configuration) already in dictionary {'FE': 'Goal', 'core': True, 'GF': 'Dep', 'PT': 'PP'} ([('FE', 'Goal'), ('core', True), ('GF', 'Dep'), ('PT', 'PP'), ('FE', 'Configuration'), ('GF', 'Dep'), ('PT', 'PP')])

# %% [markdown]
# The end.
