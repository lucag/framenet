# %%
import xml.etree.ElementTree as et, os
import collections.abc       as abc
import pandas                as pd
import qgrid

from os.path                 import join
from framenet.util           import flatten, curry, flatmap, take
from framenet.builder        import build
from glob                    import iglob
from collections             import OrderedDict
from typing                  import Callable, List, Sequence
from multipledispatch        import dispatch
from framenet.util           import cata
from pprint                  import pformat, pprint
from framenet.ecg.generation import (root_for, base_for, Tree, 
                                     T, unstack, 
                                     EtTree, TestTree as TT)

# For Pandas
pd.options.display.max_rows    = 99
pd.options.display.max_columns = 199


tagify = lambda tag, item: '%sID' % tag if item == 'ID' else item

# The ICSI namespace we use below, as in 'fn:sentence'
fn = {'fn': 'http://framenet.icsi.berkeley.edu'}

lu10  = root_for['lu']('lu10')
asets = lu10.findall('.//fn:sentence', fn)

# %% [markdown]
# # Test: unstacking one XML file

# %%
# The ICSI namespace we use below, as in 'fn:sentence'
fn = {'fn': 'http://framenet.icsi.berkeley.edu'}

# This creates a loader for file 'lu10.xml' from the 'lu' folder 
lu10           = root_for['lu']('lu10')

# Find all <sentence ...> tags
lu10_sentences = lu10.findall('.//fn:sentence', fn)

def unstack_one(elem):
    "Unstack the whole XML subtree at `elem`."
    return [dict(flatten(vs)) for vs in unstack(2, EtTree(elem))]

lu10_df = pd.DataFrame(flatmap(unstack_one, asets))
# qgrid.nbinstall(overwrite=True)

# %%
qgrid.show_grid(lu10_df, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 100})

# %% [markdown]
# ## Now, let's define a function that does the above:
#
# Concretely, given an XML element, return a list of dictionaries. We need the list of dictionaries to finally create the `DataFrame` object.

# %%
unstack_all = lambda elements: flatmap(unstack_one, elements)

# %% [markdown]
# ## Next:
#
# 1. Gather all the LU files by creating loaders for each one;
# 1. Extract the <sentence...> elements;
# 1. Apply the above to each one;
# 1. There's no 4!!!

# %%
from glob    import iglob 
from os.path import join

lu_roots = map(root_for['lu'], iglob(join(base_for['lu'], '*.xml')))
lu_sents = flatten(r.findall('.//fn:sentence', fn) for r in lu_roots)

# %%
# Warning: this will take a long time. Only need to do this once!

LU_PICKLE = 'lu.pkl'

if os.access(LU_PICKLE, os.R_OK):
    # Read lu_df back in
    lu_df = pd.read_pickle(LU_PICKLE)
else:
    # Save to a file in the current directory
    lu_df = pd.DataFrame(list(unstack_all(lu_sents)))
    # %time lu_df.to_pickle(LU_PICKLE)
# Out:
# CPU times: user 5.8 s, sys: 2.08 s, total: 7.88 s
# Wall time: 8.62 s

# %% [markdown]
# ## Let's do the same for the full text annotations

# %%
ft_roots = map(root_for['fulltext'], iglob(join(base_for['fulltext'], '*.xml')))
ft_sents = flatten(r.findall('.//fn:sentence', fn) for r in ft_roots)

# %%
# Same as above
FT_PICKLE = 'fulltext.pkl'

if os.access(FT_PICKLE, os.R_OK):
    # Read lu_df back in
    ft_df = pd.read_pickle(FT_PICKLE)
else:
    # Save to a file in the current directory
    ft_df = pd.DataFrame(list(unstack_all(ft_sents)))
    # %time ft_df.to_pickle(FT_PICKLE)
# Out:
# CPU times: user 481 ms, sys: 196 ms, total: 677 ms
# Wall time: 714 ms

# %% [markdown]
# ## TODO
#
# 1. function :: Frame -> Core FEs
# 1. Use them to select records

# %%
# Read FN data in 
fn, fnb = build()

# %%
Cause_motion   = fn.get_frame('Cause_motion')
cm_core_fe_ids = [int(e.ID) for e in Cause_motion.elements if e.coreType == 'Core']
cm_nc_fe_ids   = [int(e.ID) for e in Cause_motion.elements if e.coreType != 'Core']

# %%
len(Cause_motion.lexicalUnits)
# Out:
# 38

# %%
cm_core_fe_ids
# Out:
# [228, 229, 230, 231, 232, 234, 4991, 5532, 7031]

# %%
# LUs for Cause_motion
fnb.build_lus_for_frame('Cause_motion', fn)

# %%
# Pick annotation IDs for Cause_motion
cm_aset_ids  = [int(ann.ID) for ann in Cause_motion.annotations]

# %%
cm_df = lu_df.loc[
    lu_df['annotationSet.ID'].isin(cm_aset_ids) 
    & ~ lu_df['label.feID'].isin(cm_nc_fe_ids)
]
len(cm_df)
# Out:
# 10689

# %%
qgrid.show_grid(cm_df, grid_options={'forceFitColumns': False, 'defaultColumnWidth': 100})

# %% [markdown]
# ### Note: Let's verify none the records in cm_df involve noncore FEs!

# %%
assert len(cm_df[cm_df['label.feID'].isin(cm_nc_fe_ids)]) == 0

# %%
cm_ext_df = pd.concat([cm_df, 
                       pd.get_dummies(cm_df.loc[:, ['label.name']], prefix_sep=':')], 
                      axis=1)

# %%
pd.options.display.max_rows=500

cols1 = ['sentence.ID', 'label.start', 
         'label.itype', 'label.name', 'label.feID', 'layer.name']

cols2 = ['sentence.ID', 'label.start', 
         'label.name', 'layer.name']

cols3 = ['sentence.ID', 'label.start', 'label.name', 
         'label.name:Ext', 'label.name:Dep', 'label.name:Obj']

cols4 = ['sentence.ID', 'label.start', 
         'label.name:Ext', 'label.name:Dep', 'label.name:Obj']

# %%
gs = cm_ext_df.loc[:, cols2].groupby(cols2[:3])
gs.first()
# Out:
#                                    layer.name
# sentence.ID label.start label.name
# 580494      0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             2.0         Target         Target
#             13.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             29.0        Dep                GF
#                         PP                 PT
#                         Path               FE
#             50.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580498      0.0         Agent              FE
#                         Ext                GF
#                         Metaphor         Sent
#                         NP                 PT
#             29.0        Target         Target
#             38.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             42.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580507      0.0         Metaphor         Sent
#             83.0        Agent              FE
#                         Ant             Other
#                         Ext                GF
#                         NP                 PT
#             143.0       Agent              FE
#                         Ext                GF
#                         NP                 PT
#                         Rel             Other
#             148.0       Target         Target
#             159.0       NP                 PT
#                         Obj                GF
#                         Theme              FE
#             164.0       Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580517      0.0         Metaphor         Sent
#             23.0        Agent              FE
#                         Ant             Other
#                         Ext                GF
#                         NP                 PT
#             43.0        Agent              FE
#                         Ext                GF
#                         NP                 PT
#                         Rel             Other
#             55.0        Target         Target
#             64.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             72.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580527      0.0         Ext                GF
#                         NP                 PT
#                         Theme              FE
#             30.0        Target         Target
#             41.0        Dep                GF
#                         PP                 PT
#                         Source             FE
# 580529      0.0         Metaphor         Sent
#             28.0        Ext                GF
#                         NP                 PT
#                         Theme              FE
#             35.0        Target         Target
#             46.0        Dep                GF
#                         Goal               FE
#                         PPing              PT
# 580533      55.0        Ext                GF
#                         NP                 PT
#                         Theme              FE
#             116.0       Target         Target
#             127.0       Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580537      0.0         Ext                GF
#                         NP                 PT
#                         Theme              FE
#             57.0        Target         Target
#             68.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
#             105.0       Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580538      8.0         Ext                GF
#                         NP                 PT
#                         Theme              FE
#             36.0        Target         Target
#             47.0        Dep                GF
#                         PP                 PT
#                         Source             FE
#             51.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580539      0.0         Ext                GF
#                         NP                 PT
#                         Theme              FE
#             10.0        Target         Target
#             21.0        Dep                GF
#                         PP                 PT
#                         Source             FE
# 580541      50.0        Ext                GF
#                         NP                 PT
#                         Theme              FE
#             109.0       Target         Target
#             120.0       Dep                GF
#                         PP                 PT
#                         Source             FE
# 580545      0.0         Ext                GF
#                         Metaphor         Sent
#                         NP                 PT
#                         Theme              FE
#             12.0        Target         Target
#             23.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580550      0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             3.0         Target         Target
#             13.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             28.0        Dep                GF
#                         Goal               FE
#                         PPing              PT
# 580551      16.0        Agent              FE
#                         Ext                GF
#                         NP                 PT
#             24.0        Target         Target
#             35.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             51.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580554      0.0         Agent              FE
#                         Ext                GF
#                         Metaphor         Sent
#                         NP                 PT
#             47.0        Target         Target
#             56.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             100.0       Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580555      0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             20.0        Target         Target
#             30.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             34.0        Dep                GF
#                         PP                 PT
#             44.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580581      0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             4.0         Target         Target
#             11.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             24.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580587      21.0        Target         Target
#             30.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             45.0        AVP                PT
#                         Dep                GF
#                         Goal               FE
# 580588      0.0         Agent              FE
#                         Ext                GF
#                         Metaphor         Sent
#                         NP                 PT
#             17.0        Target         Target
#             26.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             51.0        Dep                GF
#                         PP                 PT
#                         Path               FE
# 580596      2.0         Target         Target
#             8.0         Goal               FE
#                         NP                 PT
#                         Obj                GF
#             11.0        Dep                GF
#                         NP                 PT
#                         Theme              FE
# 580599      2.0         Target         Target
#             8.0         Goal               FE
#                         NP                 PT
#                         Obj                GF
#             11.0        Dep                GF
#                         NP                 PT
#                         Theme              FE
# 580605      71.0        Target         Target
#             77.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             88.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580616      35.0        Agent              FE
#                         Ext                GF
#                         NP                 PT
#             37.0        Target         Target
#             45.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             57.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580617      0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             8.0         Target         Target
#             14.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             17.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580622      0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             3.0         Target         Target
#             11.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             24.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 580623      0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             3.0         Target         Target
#             10.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             13.0        Dep                GF
# ...                                       ...
# 4100637     0.0         Ext                GF
#                         NP                 PT
#             17.0        Target         Target
#             25.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             34.0        Dep                GF
#                         PP                 PT
#                         Source             FE
# 4101050     0.0         Cause              FE
#                         Ext                GF
#                         Metaphor         Sent
#                         NP                 PT
#             42.0        Target         Target
#             49.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             75.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4101126     108.0       Ant             Other
#                         Ext                GF
#                         NP                 PT
#                         Theme              FE
#             128.0       Target         Target
#             134.0       Cause              FE
#                         Dep                GF
#                         PP                 PT
# 4101141     29.0        Ext                GF
#                         NP                 PT
#                         Theme              FE
#             41.0        AVP                PT
#                         Dep                GF
#             48.0        Target         Target
#             55.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4101253     0.0         Dep                GF
#                         PP                 PT
#             53.0        Ext                GF
#                         NP                 PT
#                         Theme              FE
#             75.0        Target         Target
#             82.0        Dep                GF
#                         PP                 PT
#                         Source             FE
# 4101580     3.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             108.0       Target         Target
#             115.0       Dep                GF
#                         Goal               FE
#                         PP                 PT
#             126.0       NP                 PT
#                         Obj                GF
#                         Theme              FE
# 4102258     3.0         Target         Target
#             10.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             13.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4102260     5.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             21.0        Target         Target
#             26.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             29.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4102403     0.0         Agent              FE
#                         Ext                GF
#                         Metaphor         Sent
#                         NP                 PT
#             10.0        Target         Target
#             17.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             28.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4103890     12.0        Ext                GF
#                         NP                 PT
#                         Theme              FE
#             18.0        AJP                PT
#                         Dep                GF
#             27.0        Target         Target
#             33.0        AVP                PT
#                         Dep                GF
#                         Path               FE
#             38.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4105928     35.0        Ext                GF
#                         NP                 PT
#                         Theme              FE
#             62.0        Target         Target
#             72.0        Dep                GF
#                         PP                 PT
#             80.0        Agent              FE
#                         Dep                GF
#                         PP                 PT
# 4105984     0.0         Dep                GF
#                         Metaphor         Sent
#                         PP                 PT
#             15.0        Cause              FE
#                         Ext                GF
#                         NP                 PT
#             47.0        Target         Target
#             56.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             73.0        Cause              FE
#                         Ext                GF
#                         NP                 PT
#             82.0        Target         Target
#             91.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
# 4106009     46.0        Agent              FE
#                         Ext                GF
#                         NP                 PT
#             55.0        Target         Target
#             60.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
#             63.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
# 4106054     54.0        Target         Target
#             62.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
# 4106072     75.0        Ant             Other
#                         Ext                GF
#                         NP                 PT
#                         Theme              FE
#             85.0        Target         Target
#             95.0        Cause              FE
#                         Dep                GF
#                         PP                 PT
# 4106188     50.0        Agent              FE
#                         Ext                GF
#                         NP                 PT
#             63.0        Target         Target
#             70.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             81.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4106232     16.0        Ext                GF
#                         Goal               FE
#                         NP                 PT
#             93.0        Target         Target
#             103.0       NP                 PT
#                         Obj                GF
#                         Theme              FE
#             144.0       Dep                GF
#                         NP                 PT
# 4106556     113.0       Ant             Other
#                         Ext                GF
#                         NP                 PT
#                         Theme              FE
#             127.0       Ext                GF
#                         NP                 PT
#                         Rel             Other
#                         Theme              FE
#             141.0       Target         Target
#             151.0       Area               FE
#                         Dep                GF
#                         PP                 PT
# 4122400     0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             38.0        Target         Target
#             47.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             50.0        Dep                GF
#                         PP                 PT
#             61.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4122436     0.0         Metaphor         Sent
#             25.0        Cause              FE
#                         Ext                GF
#                         NP                 PT
#             41.0        Target         Target
#             48.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             52.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4122453     0.0         Metaphor         Sent
#             36.0        Cause              FE
#                         Ext                GF
#                         NP                 PT
#             125.0       Target         Target
#             132.0       NP                 PT
#                         Obj                GF
#                         Theme              FE
#             135.0       Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4126456     0.0         Agent              FE
#                         Ext                GF
#                         NP                 PT
#             19.0        AVP                PT
#                         Dep                GF
#             31.0        Target         Target
#             40.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             51.0        Dep                GF
#                         PP                 PT
#                         Source             FE
# 4126472     30.0        Ext                GF
#                         NP                 PT
#                         Theme              FE
#             48.0        Target         Target
#             57.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4126502     35.0        Target         Target
#             42.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             59.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
# 4165603     0.0         Agent              FE
#                         Ant             Other
#                         Ext                GF
#                         NP                 PT
#             33.0        Agent              FE
#                         Ext                GF
#                         NP                 PT
#                         Rel             Other
#             47.0        Target         Target
#             52.0        NP                 PT
#                         Obj                GF
#                         Theme              FE
#             58.0        Dep                GF
#                         Goal               FE
#                         PP                 PT
#
# [8109 rows x 1 columns]
